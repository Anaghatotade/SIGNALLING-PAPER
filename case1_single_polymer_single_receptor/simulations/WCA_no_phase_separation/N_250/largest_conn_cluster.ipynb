# %%
import MDAnalysis as mda
import numpy as np
import re
import matplotlib.pyplot as plt
import pandas as pd
from MDAnalysis.lib.nsgrid import FastNS
from MDAnalysis.lib import mdamath 
from collections import defaultdict
from scipy.spatial import cKDTree
import math
import os
import matplotlib.pyplot as plt

lammps_data = '/home/user/Desktop/Anagha/Shin_Colab/Linker_2/No_interaction/N_250/lammps.data'
trajectory_file = '/home/user/Desktop/Anagha/Shin_Colab/Linker_2/No_interaction/N_250/traj.lammpstrj'
u = mda.Universe(lammps_data, trajectory_file, format='LAMMPSDUMP')
# Out:
# /home/user/anaconda3/lib/python3.12/site-packages/MDAnalysis/coordinates/LAMMPS.py:749: UserWarning: Reader has no dt information, set to 1.0 ps
#   ts.data["time"] = step_num * ts.dt

# %%
total_chains = 650              # Set to actual polymer chain count in your system
polymer_type = 1                # Atom type for polymer
receptor_type = 2               # Atom type for receptor

num_bins = 50
max_distance = 50               # Maximum distance sphere radius (Angstrom)
bins = np.linspace(0, max_distance, num_bins + 1)
bin_centers = 0.5 * (bins[:-1] + bins[1:])

z_slab = 115.0                  # z where slab starts t(set for your system)
buffer = 0.0   
# Slab region definition
x_min, x_max = -30, 30
y_min, y_max = -30, 30
z_min, z_max = 32.2, 34.# Optionally set >0 to avoid near-boundary artifacts

# %%
def any_common_elements(list1, list2):
    set1 = set(list1)
    for element in set1:
        if element in list2:
            return True
    return False

def partner_array(resid_interest, cutoff, universe):
    array_partner = [resid_interepolymer_type = 1
cutoff = 2.5
bin_width = 1.0
max_radius = 30 * math.sqrt(3)

u = mda.Universe(lammps_data, trajectory_file, format='LAMMPSDUMP')
polymers = u.select_atoms(f"type {polymer_type}")
total_polymers = len(polymers)

class UnionFind:
    def __init__(self, n):
        self.parent = list(range(n))
        self.rank = [0]*n
    def find(self, x):
        while self.parent[x]!=x:
            self.parent[x]=self.parent[self.parent[x]]
            x=self.parent[x]
        return x
    def union(self, a, b):
        ra, rb = self.find(a), self.find(b)
        if ra==rb: return
        if self.rank[ra]<self.rank[rb]:
            self.parent[ra]=rb
        else:
            self.parent[rb]=ra
            if self.rank[ra]==self.rank[rb]:
                self.rank[ra]+=1

def get_cell_index(pos, cell_size, box):
    return tuple((pos // cell_size).astype(int))

bins = np.arange(0, max_radius+bin_width, bin_width)
V_r = [(4/3)*np.pi*b**3 for b in bins]
shell_volumes = np.array([V_r[i+1]-V_r[i] for i in range(len(V_r)-1)])st]
    atom_list = universe.select_atoms(f"around {cutoff:.2f} (resid {resid_interest})")
    for atom in atom_list:
        array_partner.append(atom.resid)
    return list(set(array_partner))

def max_clu(u, total_chains):
    partners_list = [partner_array(ele, 3.0, u) for ele in range(1, total_chains + 1)]
    max_length, max_list = 0, []
    for lst in partners_list:
        if len(lst) > max_length:
            max_length = len(lst)
            max_list = lst
    chain_in_cluster = max_list
    for chains in range(total_chains):
        if any_common_elements(chain_in_cluster, partners_list[chains]):
            chain_in_cluster += partners_list[chains]
            chain_in_cluster = list(set(chain_in_cluster))
    return chain_in_cluster

def is_chain_inside_box(chain, box, buffer=0.):
    for atom in chain.atoms:
        x, y, z = atom.position
        if not (buffer < x < box[0] - buffer and buffer < y < box[1] - buffer and buffer < z < box[2] - buffer):
            return False
    return True
# Out:
#   Cell In[3], line 9
#     array_partner = [resid_interepolymer_type = 1
#                      ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
output_csv = '/home/user/Desktop/Anagha/Shin_Colab/Linker_2/No_interaction/N_250/polymer_cluster_analysis_sphere.csv'
output_table_csv = '/home/user/Desktop/Anagha/Shin_Colab/Linker_2/No_interaction/N_250/polymer_radial_density_table_sphere.csv'
output_plot = '/home/user/Desktop/Anagha/Shin_Colab/Linker_2/No_interaction/N_250/radialdensity_polymer_sphere.png'


from MDAnalysis.lib.distances import distance_array

polymer_type = 1
cutoff = 2.5
bin_width = 1.0
max_radius = 30 * math.sqrt(3)

polymers = u.select_atoms(f"type {polymer_type}")

#polymer = fragment
fragments = polymers.fragments
n_polymers = len(fragments)

print(f"Total polymers (fragments): {n_polymers}")

class UnionFind:
    def __init__(self, n):
        self.parent = list(range(n))
        self.rank = [0]*n

    def find(self, x):
        if self.parent[x] != x:
            self.parent[x] = self.find(self.parent[x])
        return self.parent[x]

    def union(self, a, b):
        ra, rb = self.find(a), self.find(b)
        if ra == rb:
            return
        if self.rank[ra] < self.rank[rb]:
            self.parent[ra] = rb
        else:
            self.parent[rb] = ra
            if self.rank[ra] == self.rank[rb]:
                self.rank[ra] += 1

bins = np.arange(0, max_radius + bin_width, bin_width)
V_r = [(4/3) * np.pi * r**3 for r in bins]
shell_volumes = np.array([V_r[i+1] - V_r[i] for i in range(len(V_r)-1)])
bin_centers = 0.5 * (bins[:-1] + bins[1:])

radial_density_cluster = np.zeros(len(shell_volumes))
radial_density_all = np.zeros(len(shell_volumes))
results = []


for ts in u.trajectory[250:399]:

    polymers.wrap(compound='fragments')

    uf = UnionFind(n_polymers)

#polymer polymer neighbor check
    for i in range(n_polymers):
        frag_i = fragments[i]
        for j in range(i+1, n_polymers):
            frag_j = fragments[j]

            dists = distance_array(
                frag_i.positions,
                frag_j.positions,
                box=ts.dimensions
            )

            if np.any(dists <= cutoff):
                uf.union(i, j)

    #Build clusters
    groups = defaultdict(list)
    for i in range(n_polymers):
        groups[uf.find(i)].append(i)

    largest_cluster_polymers = max(groups.values(), key=len)
    largest_cluster_size = len(largest_cluster_polymers)
    fraction = largest_cluster_size / n_polymers

    print(f"Frame {ts.frame}: Largest cluster = {largest_cluster_size} polymers, fraction = {fraction:.3f}")
    results.append([ts.frame, largest_cluster_size, fraction])

    largest_cluster_atoms = mda.AtomGroup(
        np.concatenate([fragments[i].indices for i in largest_cluster_polymers]),
        u
    )

    #cluster
    ref_com_cluster = largest_cluster_atoms.center_of_mass()
    distances_cluster = np.linalg.norm(
        largest_cluster_atoms.positions - ref_com_cluster,
        axis=1
    )
    hist_cluster, _ = np.histogram(distances_cluster, bins=bins)
    radial_density_cluster += hist_cluster

    # all polymers
    ref_com_all = polymers.center_of_mass()
    distances_all = np.linalg.norm(
        polymers.positions - ref_com_all,
        axis=1
    )
    hist_all, _ = np.histogram(distances_all, bins=bins)
    radial_density_all += hist_all

df = pd.DataFrame(results, columns=["Frame", "LargestClusterSize", "Fraction"])
df.to_csv(output_csv, index=False)

n_frames = len(range(0, 399))
radial_density_cluster /= (n_frames * shell_volumes)
radial_density_all /= (n_frames * shell_volumes)

density_df = pd.DataFrame({
    "Radius(Å)": bin_centers,
    "ClusterDensity(atoms/Å³)": radial_density_cluster,
    "AllPolymerDensity(atoms/Å³)": radial_density_all
})
density_df.to_csv(output_table_csv, index=False)

plt.figure(figsize=(8,6))
plt.plot(bin_centers, radial_density_cluster, label="Largest Polymer Cluster", color='r')
plt.plot(bin_centers, radial_density_all, label="All Polymers", color='b', linestyle='--')
plt.xlabel("Radius (Å)", fontsize=12)
plt.ylabel("Density (atoms/Å³)", fontsize=12)
plt.title("Radial Density Profile (Polymer-Level Clustering)", fontsize=13)
plt.legend()
plt.tight_layout()
plt.savefig(output_plot, dpi=300, bbox_inches='tight')
plt.show()
# Out:
# Total polymers (fragments): 650
# Frame 250: Largest cluster = 643 polymers, fraction = 0.989
# Frame 251: Largest cluster = 638 polymers, fraction = 0.982
# Frame 252: Largest cluster = 630 polymers, fraction = 0.969
# Frame 253: Largest cluster = 632 polymers, fraction = 0.972
# Frame 254: Largest cluster = 642 polymers, fraction = 0.988
# Frame 255: Largest cluster = 639 polymers, fraction = 0.983
# Frame 256: Largest cluster = 635 polymers, fraction = 0.977
# Frame 257: Largest cluster = 644 polymers, fraction = 0.991
# Frame 258: Largest cluster = 638 polymers, fraction = 0.982
# Frame 259: Largest cluster = 645 polymers, fraction = 0.992
# Frame 260: Largest cluster = 640 polymers, fraction = 0.985
# Frame 261: Largest cluster = 639 polymers, fraction = 0.983
# Frame 262: Largest cluster = 642 polymers, fraction = 0.988
# Frame 263: Largest cluster = 639 polymers, fraction = 0.983
# Frame 264: Largest cluster = 644 polymers, fraction = 0.991
# Frame 265: Largest cluster = 639 polymers, fraction = 0.983
# Frame 266: Largest cluster = 647 polymers, fraction = 0.995
# Frame 267: Largest cluster = 641 polymers, fraction = 0.986
# Frame 268: Largest cluster = 640 polymers, fraction = 0.985
# Frame 269: Largest cluster = 641 polymers, fraction = 0.986
# Frame 270: Largest cluster = 638 polymers, fraction = 0.982
# Frame 271: Largest cluster = 642 polymers, fraction = 0.988
# Frame 272: Largest cluster = 639 polymers, fraction = 0.983
# Frame 273: Largest cluster = 643 polymers, fraction = 0.989
# Frame 274: Largest cluster = 634 polymers, fraction = 0.975
# Frame 275: Largest cluster = 641 polymers, fraction = 0.986
# Frame 276: Largest cluster = 647 polymers, fraction = 0.995
# Frame 277: Largest cluster = 644 polymers, fraction = 0.991
# Frame 278: Largest cluster = 643 polymers, fraction = 0.989
# Frame 279: Largest cluster = 641 polymers, fraction = 0.986
# Frame 280: Largest cluster = 638 polymers, fraction = 0.982
# Frame 281: Largest cluster = 636 polymers, fraction = 0.978
# Frame 282: Largest cluster = 641 polymers, fraction = 0.986
# Frame 283: Largest cluster = 640 polymers, fraction = 0.985
# Frame 284: Largest cluster = 638 polymers, fraction = 0.982
# Frame 285: Largest cluster = 646 polymers, fraction = 0.994
# Frame 286: Largest cluster = 643 polymers, fraction = 0.989
# Frame 287: Largest cluster = 646 polymers, fraction = 0.994
# Frame 288: Largest cluster = 639 polymers, fraction = 0.983
# Frame 289: Largest cluster = 642 polymers, fraction = 0.988
# Frame 290: Largest cluster = 640 polymers, fraction = 0.985
# Frame 291: Largest cluster = 639 polymers, fraction = 0.983
# Frame 292: Largest cluster = 647 polymers, fraction = 0.995
# Frame 293: Largest cluster = 641 polymers, fraction = 0.986
# Frame 294: Largest cluster = 638 polymers, fraction = 0.982
# Frame 295: Largest cluster = 640 polymers, fraction = 0.985
# Frame 296: Largest cluster = 640 polymers, fraction = 0.985
# Frame 297: Largest cluster = 643 polymers, fraction = 0.989
# Frame 298: Largest cluster = 639 polymers, fraction = 0.983
# Frame 299: Largest cluster = 638 polymers, fraction = 0.982
# Frame 300: Largest cluster = 643 polymers, fraction = 0.989
# Frame 301: Largest cluster = 636 polymers, fraction = 0.978
# Frame 302: Largest cluster = 647 polymers, fraction = 0.995
# Frame 303: Largest cluster = 636 polymers, fraction = 0.978
# Frame 304: Largest cluster = 641 polymers, fraction = 0.986
# Frame 305: Largest cluster = 647 polymers, fraction = 0.995
# Frame 306: Largest cluster = 644 polymers, fraction = 0.991
# Frame 307: Largest cluster = 643 polymers, fraction = 0.989
# Frame 308: Largest cluster = 636 polymers, fraction = 0.978
# Frame 309: Largest cluster = 644 polymers, fraction = 0.991
# Frame 310: Largest cluster = 640 polymers, fraction = 0.985
# Frame 311: Largest cluster = 645 polymers, fraction = 0.992
# Frame 312: Largest cluster = 644 polymers, fraction = 0.991
# Frame 313: Largest cluster = 645 polymers, fraction = 0.992
# Frame 314: Largest cluster = 635 polymers, fraction = 0.977
# Frame 315: Largest cluster = 639 polymers, fraction = 0.983
# Frame 316: Largest cluster = 641 polymers, fraction = 0.986
# Frame 317: Largest cluster = 639 polymers, fraction = 0.983
# Frame 318: Largest cluster = 642 polymers, fraction = 0.988
# Frame 319: Largest cluster = 640 polymers, fraction = 0.985
# Frame 320: Largest cluster = 644 polymers, fraction = 0.991
# Frame 321: Largest cluster = 639 polymers, fraction = 0.983
# Frame 322: Largest cluster = 644 polymers, fraction = 0.991
# Frame 323: Largest cluster = 638 polymers, fraction = 0.982
# Frame 324: Largest cluster = 636 polymers, fraction = 0.978
# Frame 325: Largest cluster = 643 polymers, fraction = 0.989
# Frame 326: Largest cluster = 641 polymers, fraction = 0.986
# Frame 327: Largest cluster = 641 polymers, fraction = 0.986
# Frame 328: Largest cluster = 636 polymers, fraction = 0.978
# Frame 329: Largest cluster = 637 polymers, fraction = 0.980
# Frame 330: Largest cluster = 643 polymers, fraction = 0.989
# Frame 331: Largest cluster = 639 polymers, fraction = 0.983
# Frame 332: Largest cluster = 644 polymers, fraction = 0.991
# Frame 333: Largest cluster = 645 polymers, fraction = 0.992
# Frame 334: Largest cluster = 646 polymers, fraction = 0.994
# Frame 335: Largest cluster = 642 polymers, fraction = 0.988
# Frame 336: Largest cluster = 643 polymers, fraction = 0.989
# Frame 337: Largest cluster = 641 polymers, fraction = 0.986
# Frame 338: Largest cluster = 641 polymers, fraction = 0.986
# Frame 339: Largest cluster = 647 polymers, fraction = 0.995
# Frame 340: Largest cluster = 645 polymers, fraction = 0.992
# Frame 341: Largest cluster = 631 polymers, fraction = 0.971
# Frame 342: Largest cluster = 634 polymers, fraction = 0.975
# Frame 343: Largest cluster = 640 polymers, fraction = 0.985
# Frame 344: Largest cluster = 641 polymers, fraction = 0.986
# Frame 345: Largest cluster = 644 polymers, fraction = 0.991
# Frame 346: Largest cluster = 636 polymers, fraction = 0.978
# Frame 347: Largest cluster = 644 polymers, fraction = 0.991
# Frame 348: Largest cluster = 645 polymers, fraction = 0.992
# Frame 349: Largest cluster = 644 polymers, fraction = 0.991
# Frame 350: Largest cluster = 640 polymers, fraction = 0.985
# Frame 351: Largest cluster = 642 polymers, fraction = 0.988
# Frame 352: Largest cluster = 637 polymers, fraction = 0.980
# Frame 353: Largest cluster = 643 polymers, fraction = 0.989
# Frame 354: Largest cluster = 639 polymers, fraction = 0.983
# Frame 355: Largest cluster = 640 polymers, fraction = 0.985
# Frame 356: Largest cluster = 643 polymers, fraction = 0.989
# Frame 357: Largest cluster = 636 polymers, fraction = 0.978
# Frame 358: Largest cluster = 642 polymers, fraction = 0.988
# Frame 359: Largest cluster = 640 polymers, fraction = 0.985
# Frame 360: Largest cluster = 645 polymers, fraction = 0.992
# Frame 361: Largest cluster = 645 polymers, fraction = 0.992
# Frame 362: Largest cluster = 640 polymers, fraction = 0.985
# Frame 363: Largest cluster = 635 polymers, fraction = 0.977
# Frame 364: Largest cluster = 639 polymers, fraction = 0.983
# Frame 365: Largest cluster = 642 polymers, fraction = 0.988
# Frame 366: Largest cluster = 645 polymers, fraction = 0.992
# Frame 367: Largest cluster = 645 polymers, fraction = 0.992
# Frame 368: Largest cluster = 647 polymers, fraction = 0.995
# Frame 369: Largest cluster = 638 polymers, fraction = 0.982
# Frame 370: Largest cluster = 646 polymers, fraction = 0.994
# Frame 371: Largest cluster = 644 polymers, fraction = 0.991
# Frame 372: Largest cluster = 639 polymers, fraction = 0.983
# Frame 373: Largest cluster = 638 polymers, fraction = 0.982
# Frame 374: Largest cluster = 642 polymers, fraction = 0.988
# Frame 375: Largest cluster = 637 polymers, fraction = 0.980
# Frame 376: Largest cluster = 639 polymers, fraction = 0.983
# Frame 377: Largest cluster = 643 polymers, fraction = 0.989
# Frame 378: Largest cluster = 643 polymers, fraction = 0.989
# Frame 379: Largest cluster = 639 polymers, fraction = 0.983
# Frame 380: Largest cluster = 643 polymers, fraction = 0.989
# Frame 381: Largest cluster = 643 polymers, fraction = 0.989
# Frame 382: Largest cluster = 647 polymers, fraction = 0.995
# Frame 383: Largest cluster = 645 polymers, fraction = 0.992
# Frame 384: Largest cluster = 649 polymers, fraction = 0.998
# Frame 385: Largest cluster = 643 polymers, fraction = 0.989
# Frame 386: Largest cluster = 634 polymers, fraction = 0.975
# Frame 387: Largest cluster = 638 polymers, fraction = 0.982
# Frame 388: Largest cluster = 643 polymers, fraction = 0.989
# Frame 389: Largest cluster = 642 polymers, fraction = 0.988
# Frame 390: Largest cluster = 645 polymers, fraction = 0.992
# Frame 391: Largest cluster = 648 polymers, fraction = 0.997
# Frame 392: Largest cluster = 643 polymers, fraction = 0.989
# Frame 393: Largest cluster = 642 polymers, fraction = 0.988
# Frame 394: Largest cluster = 633 polymers, fraction = 0.974
# Frame 395: Largest cluster = 643 polymers, fraction = 0.989
# Frame 396: Largest cluster = 637 polymers, fraction = 0.980
# Frame 397: Largest cluster = 635 polymers, fraction = 0.977
# Frame 398: Largest cluster = 637 polymers, fraction = 0.980

# %%
output_csv = '/home/user/Desktop/Anagha/Shin_Colab/Linker_2/No_interaction/N_250/polymer_cluster_analysis_sphere.csv'
output_table_csv = '/home/user/Desktop/Anagha/Shin_Colab/Linker_2/No_interaction/N_250/polymer_radial_density_table_sphere.csv'
output_plot = '/home/user/Desktop/Anagha/Shin_Colab/Linker_2/No_interaction/N_250/radialdensity_polymer_sphere.png'

polymer_type = 1
cutoff = 2.5
bin_width = 1.0

polymers = u.select_atoms(f"type {polymer_type}")
total_polymers = len(polymers)

class UnionFind:
    def __init__(self, n):
        self.parent = list(range(n))
        self.rank = [0]*n

    def find(self, x):
        while self.parent[x] != x:
            self.parent[x] = self.parent[self.parent[x]]
            x = self.parent[x]
        return x

    def union(self, a, b):
        ra, rb = self.find(a), self.find(b)
        if ra == rb:
            return
        if self.rank[ra] < self.rank[rb]:
            self.parent[ra] = rb
        else:
            self.parent[rb] = ra
            if self.rank[ra] == self.rank[rb]:
                self.rank[ra] += 1

def get_cell_index(pos, cell_size):
    return tuple((pos // cell_size).astype(int))

max_radius = 30 * math.sqrt(3)
bins = np.arange(0, max_radius + bin_width, bin_width)

V_r = [(4/3)*math.pi*r**3 for r in bins]
shell_volumes = np.array([V_r[i+1] - V_r[i] for i in range(len(V_r)-1)])
bin_centers = 0.5 * (bins[:-1] + bins[1:])

radial_density_cluster = np.zeros(len(shell_volumes))
radial_density_all = np.zeros(len(shell_volumes))

results = []


for ts in u.trajectory[0:399]:

    polymers.wrap(compound='fragments')
    positions = polymers.positions
    box = ts.dimensions[:3]

    cell_size = cutoff
    ncell = (box / cell_size).astype(int)

    cell_dict = defaultdict(list)
    for i, pos in enumerate(positions):
        cell = get_cell_index(pos, cell_size)
        cell_dict[cell].append(i)

    neighbor_offsets = [(dx,dy,dz) 
                        for dx in [-1,0,1]
                        for dy in [-1,0,1]
                        for dz in [-1,0,1]]

    pairs = set()
    
    for cell, atom_ids in cell_dict.items():
        for dx,dy,dz in neighbor_offsets:
            neigh = ((cell[0]+dx) % ncell[0],
                     (cell[1]+dy) % ncell[1],
                     (cell[2]+dz) % ncell[2])
    
            for i in atom_ids:
                for j in cell_dict.get(neigh, []):
                    if i == j:
                        continue
    
                    a, b = min(i, j), max(i, j)
    
                    dx = positions[a][0] - positions[b][0]
                    dy = positions[a][1] - positions[b][1]
                    dz = positions[a][2] - positions[b][2]
    
                    dx -= box[0] * round(dx / box[0])
                    dy -= box[1] * round(dy / box[1])
                    dz -= box[2] * round(dz / box[2])
    
                    if dx*dx + dy*dy + dz*dz <= cutoff*cutoff:
                        pairs.add((a, b))

    # Cluster detection 
    uf = UnionFind(total_polymers)
    for i, j in pairs:
        uf.union(i, j)

    groups = defaultdict(list)
    for i in range(total_polymers):
        groups[uf.find(i)].append(i)

    largest_cluster = max(groups.values(), key=len)
    fraction = len(largest_cluster) / total_polymers

    print(f"Frame {ts.frame}: Largest cluster = {len(largest_cluster)} | Fraction = {fraction:.3f}")
    results.append([ts.frame, len(largest_cluster), fraction])


    cluster_positions = positions[largest_cluster]
    ref_com_cluster = cluster_positions.mean(axis=0)

    hist_cluster = np.zeros(len(bins)-1)
    for pos in cluster_positions:
        dx = pos[0] - ref_com_cluster[0]
        dy = pos[1] - ref_com_cluster[1]
        dz = pos[2] - ref_com_cluster[2]
        r = math.sqrt(dx*dx + dy*dy + dz*dz)

        bin_id = int(r // bin_width)
        if bin_id < len(hist_cluster):
            hist_cluster[bin_id] += 1

    radial_density_cluster += hist_cluster

    # ---- All polymers ----
    ref_com_all = polymers.center_of_mass()
    hist_all = np.zeros(len(bins)-1)

    for pos in positions:
        dx = pos[0] - ref_com_all[0]
        dy = pos[1] - ref_com_all[1]
        dz = pos[2] - ref_com_all[2]
        r = math.sqrt(dx*dx + dy*dy + dz*dz)

        bin_id = int(r // bin_width)
        if bin_id < len(hist_all):
            hist_all[bin_id] += 1

    radial_density_all += hist_all

df = pd.DataFrame(results, columns=["Frame", "LargestClusterSize", "Fraction"])
df.to_csv(output_csv, index=False)

n_frames = len(range(0,399))
radial_density_cluster /= (n_frames * shell_volumes)
radial_density_all /= (n_frames * shell_volumes)

density_df = pd.DataFrame({
    "Radius(Å)": bin_centers,
    "ClusterDensity(atoms/Å³)": radial_density_cluster,
    "AllPolymerDensity(atoms/Å³)": radial_density_all
})
density_df.to_csv(output_table_csv, index=False)

plt.figure(figsize=(8,6))
plt.plot(bin_centers, radial_density_cluster, label="Largest Polymer Cluster")
plt.plot(bin_centers, radial_density_all, '--', label="All Polymers")
plt.xlabel("Radius (Å)")
plt.ylabel("Density (atoms/Å³)")
plt.title("Radial Density Profile (Manual Distance)")
plt.legend()
plt.tight_layout()
plt.savefig(output_plot, dpi=300)
plt.show()
# Out:
# Frame 0: Largest cluster = 15900 | Fraction = 0.978
# Frame 1: Largest cluster = 16125 | Fraction = 0.992
# Frame 2: Largest cluster = 15825 | Fraction = 0.974
# Frame 3: Largest cluster = 16200 | Fraction = 0.997
# Frame 4: Largest cluster = 16150 | Fraction = 0.994
# Frame 5: Largest cluster = 15900 | Fraction = 0.978
# Frame 6: Largest cluster = 16125 | Fraction = 0.992
# Frame 7: Largest cluster = 16150 | Fraction = 0.994
# Frame 8: Largest cluster = 16100 | Fraction = 0.991
# Frame 9: Largest cluster = 16100 | Fraction = 0.991
# Frame 10: Largest cluster = 16025 | Fraction = 0.986
# Frame 11: Largest cluster = 15900 | Fraction = 0.978
# Frame 12: Largest cluster = 16100 | Fraction = 0.991
# Frame 13: Largest cluster = 16025 | Fraction = 0.986
# Frame 14: Largest cluster = 15950 | Fraction = 0.982
# Frame 15: Largest cluster = 15975 | Fraction = 0.983
# Frame 16: Largest cluster = 15950 | Fraction = 0.982
# Frame 17: Largest cluster = 16050 | Fraction = 0.988
# Frame 18: Largest cluster = 15975 | Fraction = 0.983
# Frame 19: Largest cluster = 15750 | Fraction = 0.969
# Frame 20: Largest cluster = 15950 | Fraction = 0.982
# Frame 21: Largest cluster = 16000 | Fraction = 0.985
# Frame 22: Largest cluster = 16150 | Fraction = 0.994
# Frame 23: Largest cluster = 16000 | Fraction = 0.985
# Frame 24: Largest cluster = 16125 | Fraction = 0.992
# Frame 25: Largest cluster = 16025 | Fraction = 0.986
# Frame 26: Largest cluster = 16000 | Fraction = 0.985
# Frame 27: Largest cluster = 16100 | Fraction = 0.991
# Frame 28: Largest cluster = 15900 | Fraction = 0.978
# Frame 29: Largest cluster = 15975 | Fraction = 0.983
# Frame 30: Largest cluster = 16050 | Fraction = 0.988
# Frame 31: Largest cluster = 16050 | Fraction = 0.988
# Frame 32: Largest cluster = 16125 | Fraction = 0.992
# Frame 33: Largest cluster = 16075 | Fraction = 0.989
# Frame 34: Largest cluster = 16175 | Fraction = 0.995
# Frame 35: Largest cluster = 16000 | Fraction = 0.985
# Frame 36: Largest cluster = 16000 | Fraction = 0.985
# Frame 37: Largest cluster = 16025 | Fraction = 0.986
# Frame 38: Largest cluster = 15975 | Fraction = 0.983
# Frame 39: Largest cluster = 16100 | Fraction = 0.991
# Frame 40: Largest cluster = 16025 | Fraction = 0.986
# Frame 41: Largest cluster = 16125 | Fraction = 0.992
# Frame 42: Largest cluster = 15900 | Fraction = 0.978
# Frame 43: Largest cluster = 16100 | Fraction = 0.991
# Frame 44: Largest cluster = 16050 | Fraction = 0.988
# Frame 45: Largest cluster = 16050 | Fraction = 0.988
# Frame 46: Largest cluster = 16200 | Fraction = 0.997
# Frame 47: Largest cluster = 15900 | Fraction = 0.978
# Frame 48: Largest cluster = 16125 | Fraction = 0.992
# Frame 49: Largest cluster = 15850 | Fraction = 0.975
# Frame 50: Largest cluster = 16050 | Fraction = 0.988
# Frame 51: Largest cluster = 15825 | Fraction = 0.974
# Frame 52: Largest cluster = 15975 | Fraction = 0.983
# Frame 53: Largest cluster = 16000 | Fraction = 0.985
# Frame 54: Largest cluster = 16200 | Fraction = 0.997
# Frame 55: Largest cluster = 15800 | Fraction = 0.972
# Frame 56: Largest cluster = 16050 | Fraction = 0.988
# Frame 57: Largest cluster = 16000 | Fraction = 0.985
# Frame 58: Largest cluster = 16075 | Fraction = 0.989
# Frame 59: Largest cluster = 16100 | Fraction = 0.991
# Frame 60: Largest cluster = 16200 | Fraction = 0.997
# Frame 61: Largest cluster = 16025 | Fraction = 0.986
# Frame 62: Largest cluster = 16050 | Fraction = 0.988
# Frame 63: Largest cluster = 16075 | Fraction = 0.989
# Frame 64: Largest cluster = 16200 | Fraction = 0.997
# Frame 65: Largest cluster = 16000 | Fraction = 0.985
# Frame 66: Largest cluster = 16050 | Fraction = 0.988
# Frame 67: Largest cluster = 16100 | Fraction = 0.991
# Frame 68: Largest cluster = 16050 | Fraction = 0.988
# Frame 69: Largest cluster = 15900 | Fraction = 0.978
# Frame 70: Largest cluster = 16125 | Fraction = 0.992
# Frame 71: Largest cluster = 16100 | Fraction = 0.991
# Frame 72: Largest cluster = 16050 | Fraction = 0.988
# Frame 73: Largest cluster = 16000 | Fraction = 0.985
# Frame 74: Largest cluster = 16125 | Fraction = 0.992
# Frame 75: Largest cluster = 16100 | Fraction = 0.991
# Frame 76: Largest cluster = 16075 | Fraction = 0.989
# Frame 77: Largest cluster = 16150 | Fraction = 0.994
# Frame 78: Largest cluster = 15800 | Fraction = 0.972
# Frame 79: Largest cluster = 16075 | Fraction = 0.989
# Frame 80: Largest cluster = 16000 | Fraction = 0.985
# Frame 81: Largest cluster = 16050 | Fraction = 0.988
# Frame 82: Largest cluster = 15775 | Fraction = 0.971
# Frame 83: Largest cluster = 16125 | Fraction = 0.992
# Frame 84: Largest cluster = 15875 | Fraction = 0.977
# Frame 85: Largest cluster = 16100 | Fraction = 0.991
# Frame 86: Largest cluster = 16025 | Fraction = 0.986
# Frame 87: Largest cluster = 16125 | Fraction = 0.992
# Frame 88: Largest cluster = 15925 | Fraction = 0.980
# Frame 89: Largest cluster = 16025 | Fraction = 0.986
# Frame 90: Largest cluster = 16025 | Fraction = 0.986
# Frame 91: Largest cluster = 16175 | Fraction = 0.995
# Frame 92: Largest cluster = 15925 | Fraction = 0.980
# Frame 93: Largest cluster = 16150 | Fraction = 0.994
# Frame 94: Largest cluster = 16075 | Fraction = 0.989
# Frame 95: Largest cluster = 16150 | Fraction = 0.994
# Frame 96: Largest cluster = 15975 | Fraction = 0.983
# Frame 97: Largest cluster = 16000 | Fraction = 0.985
# Frame 98: Largest cluster = 16100 | Fraction = 0.991
# Frame 99: Largest cluster = 15875 | Fraction = 0.977
# Frame 100: Largest cluster = 15825 | Fraction = 0.974
# Frame 101: Largest cluster = 16050 | Fraction = 0.988
# Frame 102: Largest cluster = 15950 | Fraction = 0.982
# Frame 103: Largest cluster = 15950 | Fraction = 0.982
# Frame 104: Largest cluster = 16100 | Fraction = 0.991
# Frame 105: Largest cluster = 16125 | Fraction = 0.992
# Frame 106: Largest cluster = 16125 | Fraction = 0.992
# Frame 107: Largest cluster = 15975 | Fraction = 0.983
# Frame 108: Largest cluster = 16000 | Fraction = 0.985
# Frame 109: Largest cluster = 15925 | Fraction = 0.980
# Frame 110: Largest cluster = 16025 | Fraction = 0.986
# Frame 111: Largest cluster = 15975 | Fraction = 0.983
# Frame 112: Largest cluster = 16150 | Fraction = 0.994
# Frame 113: Largest cluster = 16150 | Fraction = 0.994
# Frame 114: Largest cluster = 16150 | Fraction = 0.994
# Frame 115: Largest cluster = 15975 | Fraction = 0.983
# Frame 116: Largest cluster = 16000 | Fraction = 0.985
# Frame 117: Largest cluster = 15975 | Fraction = 0.983
# Frame 118: Largest cluster = 16050 | Fraction = 0.988
# Frame 119: Largest cluster = 16000 | Fraction = 0.985
# Frame 120: Largest cluster = 16050 | Fraction = 0.988
# Frame 121: Largest cluster = 16050 | Fraction = 0.988
# Frame 122: Largest cluster = 16175 | Fraction = 0.995
# Frame 123: Largest cluster = 16000 | Fraction = 0.985
# Frame 124: Largest cluster = 15975 | Fraction = 0.983
# Frame 125: Largest cluster = 15975 | Fraction = 0.983
# Frame 126: Largest cluster = 16175 | Fraction = 0.995
# Frame 127: Largest cluster = 16100 | Fraction = 0.991
# Frame 128: Largest cluster = 15925 | Fraction = 0.980
# Frame 129: Largest cluster = 16050 | Fraction = 0.988
# Frame 130: Largest cluster = 16050 | Fraction = 0.988
# Frame 131: Largest cluster = 16100 | Fraction = 0.991
# Frame 132: Largest cluster = 15975 | Fraction = 0.983
# Frame 133: Largest cluster = 16050 | Fraction = 0.988
# Frame 134: Largest cluster = 16050 | Fraction = 0.988
# Frame 135: Largest cluster = 16025 | Fraction = 0.986
# Frame 136: Largest cluster = 16025 | Fraction = 0.986
# Frame 137: Largest cluster = 16050 | Fraction = 0.988
# Frame 138: Largest cluster = 16050 | Fraction = 0.988
# Frame 139: Largest cluster = 16050 | Fraction = 0.988
# Frame 140: Largest cluster = 16175 | Fraction = 0.995
# Frame 141: Largest cluster = 15950 | Fraction = 0.982
# Frame 142: Largest cluster = 16075 | Fraction = 0.989
# Frame 143: Largest cluster = 16100 | Fraction = 0.991
# Frame 144: Largest cluster = 16000 | Fraction = 0.985
# Frame 145: Largest cluster = 16150 | Fraction = 0.994
# Frame 146: Largest cluster = 16100 | Fraction = 0.991
# Frame 147: Largest cluster = 15825 | Fraction = 0.974
# Frame 148: Largest cluster = 15875 | Fraction = 0.977
# Frame 149: Largest cluster = 16000 | Fraction = 0.985
# Frame 150: Largest cluster = 15850 | Fraction = 0.975
# Frame 151: Largest cluster = 16125 | Fraction = 0.992
# Frame 152: Largest cluster = 16125 | Fraction = 0.992
# Frame 153: Largest cluster = 16000 | Fraction = 0.985
# Frame 154: Largest cluster = 16125 | Fraction = 0.992
# Frame 155: Largest cluster = 16125 | Fraction = 0.992
# Frame 156: Largest cluster = 16025 | Fraction = 0.986
# Frame 157: Largest cluster = 16050 | Fraction = 0.988
# Frame 158: Largest cluster = 16075 | Fraction = 0.989
# Frame 159: Largest cluster = 16000 | Fraction = 0.985
# Frame 160: Largest cluster = 16000 | Fraction = 0.985
# Frame 161: Largest cluster = 16050 | Fraction = 0.988
# Frame 162: Largest cluster = 16075 | Fraction = 0.989
# Frame 163: Largest cluster = 16025 | Fraction = 0.986
# Frame 164: Largest cluster = 15775 | Fraction = 0.971
# Frame 165: Largest cluster = 16075 | Fraction = 0.989
# Frame 166: Largest cluster = 16150 | Fraction = 0.994
# Frame 167: Largest cluster = 16075 | Fraction = 0.989
# Frame 168: Largest cluster = 15750 | Fraction = 0.969
# Frame 169: Largest cluster = 16000 | Fraction = 0.985
# Frame 170: Largest cluster = 15975 | Fraction = 0.983
# Frame 171: Largest cluster = 15950 | Fraction = 0.982
# Frame 172: Largest cluster = 15900 | Fraction = 0.978
# Frame 173: Largest cluster = 15975 | Fraction = 0.983
# Frame 174: Largest cluster = 16075 | Fraction = 0.989
# Frame 175: Largest cluster = 16000 | Fraction = 0.985
# Frame 176: Largest cluster = 16125 | Fraction = 0.992
# Frame 177: Largest cluster = 16150 | Fraction = 0.994
# Frame 178: Largest cluster = 16000 | Fraction = 0.985
# Frame 179: Largest cluster = 16050 | Fraction = 0.988
# Frame 180: Largest cluster = 16075 | Fraction = 0.989
# Frame 181: Largest cluster = 16075 | Fraction = 0.989
# Frame 182: Largest cluster = 15975 | Fraction = 0.983
# Frame 183: Largest cluster = 16100 | Fraction = 0.991
# Frame 184: Largest cluster = 15925 | Fraction = 0.980
# Frame 185: Largest cluster = 16025 | Fraction = 0.986
# Frame 186: Largest cluster = 15900 | Fraction = 0.978
# Frame 187: Largest cluster = 16200 | Fraction = 0.997
# Frame 188: Largest cluster = 16125 | Fraction = 0.992
# Frame 189: Largest cluster = 16025 | Fraction = 0.986
# Frame 190: Largest cluster = 15850 | Fraction = 0.975
# Frame 191: Largest cluster = 16025 | Fraction = 0.986
# Frame 192: Largest cluster = 16100 | Fraction = 0.991
# Frame 193: Largest cluster = 16150 | Fraction = 0.994
# Frame 194: Largest cluster = 15950 | Fraction = 0.982
# Frame 195: Largest cluster = 15900 | Fraction = 0.978
# Frame 196: Largest cluster = 15925 | Fraction = 0.980
# Frame 197: Largest cluster = 16100 | Fraction = 0.991
# Frame 198: Largest cluster = 16075 | Fraction = 0.989
# Frame 199: Largest cluster = 16075 | Fraction = 0.989
# Frame 200: Largest cluster = 16025 | Fraction = 0.986
# Frame 201: Largest cluster = 15825 | Fraction = 0.974
# Frame 202: Largest cluster = 16125 | Fraction = 0.992
# Frame 203: Largest cluster = 16050 | Fraction = 0.988
# Frame 204: Largest cluster = 16125 | Fraction = 0.992
# Frame 205: Largest cluster = 16175 | Fraction = 0.995
# Frame 206: Largest cluster = 16075 | Fraction = 0.989
# Frame 207: Largest cluster = 16000 | Fraction = 0.985
# Frame 208: Largest cluster = 16025 | Fraction = 0.986
# Frame 209: Largest cluster = 16125 | Fraction = 0.992
# Frame 210: Largest cluster = 16050 | Fraction = 0.988
# Frame 211: Largest cluster = 16025 | Fraction = 0.986
# Frame 212: Largest cluster = 16150 | Fraction = 0.994
# Frame 213: Largest cluster = 16125 | Fraction = 0.992
# Frame 214: Largest cluster = 15900 | Fraction = 0.978
# Frame 215: Largest cluster = 16100 | Fraction = 0.991
# Frame 216: Largest cluster = 16225 | Fraction = 0.998
# Frame 217: Largest cluster = 16150 | Fraction = 0.994
# Frame 218: Largest cluster = 16050 | Fraction = 0.988
# Frame 219: Largest cluster = 16025 | Fraction = 0.986
# Frame 220: Largest cluster = 15925 | Fraction = 0.980
# Frame 221: Largest cluster = 15975 | Fraction = 0.983
# Frame 222: Largest cluster = 16075 | Fraction = 0.989
# Frame 223: Largest cluster = 16000 | Fraction = 0.985
# Frame 224: Largest cluster = 16000 | Fraction = 0.985
# Frame 225: Largest cluster = 16050 | Fraction = 0.988
# Frame 226: Largest cluster = 16075 | Fraction = 0.989
# Frame 227: Largest cluster = 16000 | Fraction = 0.985
# Frame 228: Largest cluster = 15875 | Fraction = 0.977
# Frame 229: Largest cluster = 16000 | Fraction = 0.985
# Frame 230: Largest cluster = 16100 | Fraction = 0.991
# Frame 231: Largest cluster = 15900 | Fraction = 0.978
# Frame 232: Largest cluster = 16050 | Fraction = 0.988
# Frame 233: Largest cluster = 16075 | Fraction = 0.989
# Frame 234: Largest cluster = 16025 | Fraction = 0.986
# Frame 235: Largest cluster = 16050 | Fraction = 0.988
# Frame 236: Largest cluster = 16125 | Fraction = 0.992
# Frame 237: Largest cluster = 16025 | Fraction = 0.986
# Frame 238: Largest cluster = 16150 | Fraction = 0.994
# Frame 239: Largest cluster = 15725 | Fraction = 0.968
# Frame 240: Largest cluster = 16050 | Fraction = 0.988
# Frame 241: Largest cluster = 16075 | Fraction = 0.989
# Frame 242: Largest cluster = 16075 | Fraction = 0.989
# Frame 243: Largest cluster = 16125 | Fraction = 0.992
# Frame 244: Largest cluster = 16075 | Fraction = 0.989
# Frame 245: Largest cluster = 16075 | Fraction = 0.989
# Frame 246: Largest cluster = 16075 | Fraction = 0.989
# Frame 247: Largest cluster = 16025 | Fraction = 0.986
# Frame 248: Largest cluster = 16050 | Fraction = 0.988
# Frame 249: Largest cluster = 16100 | Fraction = 0.991
# Frame 250: Largest cluster = 16075 | Fraction = 0.989
# Frame 251: Largest cluster = 15950 | Fraction = 0.982
# Frame 252: Largest cluster = 15750 | Fraction = 0.969
# Frame 253: Largest cluster = 15800 | Fraction = 0.972
# Frame 254: Largest cluster = 16050 | Fraction = 0.988
# Frame 255: Largest cluster = 15975 | Fraction = 0.983
# Frame 256: Largest cluster = 15875 | Fraction = 0.977
# Frame 257: Largest cluster = 16100 | Fraction = 0.991
# Frame 258: Largest cluster = 15950 | Fraction = 0.982
# Frame 259: Largest cluster = 16125 | Fraction = 0.992
# Frame 260: Largest cluster = 16000 | Fraction = 0.985
# Frame 261: Largest cluster = 15975 | Fraction = 0.983
# Frame 262: Largest cluster = 16050 | Fraction = 0.988
# Frame 263: Largest cluster = 15975 | Fraction = 0.983
# Frame 264: Largest cluster = 16100 | Fraction = 0.991
# Frame 265: Largest cluster = 15975 | Fraction = 0.983
# Frame 266: Largest cluster = 16175 | Fraction = 0.995
# Frame 267: Largest cluster = 16025 | Fraction = 0.986
# Frame 268: Largest cluster = 16000 | Fraction = 0.985
# Frame 269: Largest cluster = 16025 | Fraction = 0.986
# Frame 270: Largest cluster = 15950 | Fraction = 0.982
# Frame 271: Largest cluster = 16050 | Fraction = 0.988
# Frame 272: Largest cluster = 15975 | Fraction = 0.983
# Frame 273: Largest cluster = 16075 | Fraction = 0.989
# Frame 274: Largest cluster = 15850 | Fraction = 0.975
# Frame 275: Largest cluster = 16025 | Fraction = 0.986
# Frame 276: Largest cluster = 16175 | Fraction = 0.995
# Frame 277: Largest cluster = 16100 | Fraction = 0.991
# Frame 278: Largest cluster = 16075 | Fraction = 0.989
# Frame 279: Largest cluster = 16025 | Fraction = 0.986
# Frame 280: Largest cluster = 15950 | Fraction = 0.982
# Frame 281: Largest cluster = 15900 | Fraction = 0.978
# Frame 282: Largest cluster = 16025 | Fraction = 0.986
# Frame 283: Largest cluster = 16000 | Fraction = 0.985
# Frame 284: Largest cluster = 15950 | Fraction = 0.982
# Frame 285: Largest cluster = 16150 | Fraction = 0.994
# Frame 286: Largest cluster = 16075 | Fraction = 0.989
# Frame 287: Largest cluster = 16150 | Fraction = 0.994
# Frame 288: Largest cluster = 15975 | Fraction = 0.983
# Frame 289: Largest cluster = 16050 | Fraction = 0.988
# Frame 290: Largest cluster = 16000 | Fraction = 0.985
# Frame 291: Largest cluster = 15975 | Fraction = 0.983
# Frame 292: Largest cluster = 16175 | Fraction = 0.995
# Frame 293: Largest cluster = 16025 | Fraction = 0.986
# Frame 294: Largest cluster = 15950 | Fraction = 0.982
# Frame 295: Largest cluster = 16000 | Fraction = 0.985
# Frame 296: Largest cluster = 16000 | Fraction = 0.985
# Frame 297: Largest cluster = 16075 | Fraction = 0.989
# Frame 298: Largest cluster = 15975 | Fraction = 0.983
# Frame 299: Largest cluster = 15950 | Fraction = 0.982
# Frame 300: Largest cluster = 16075 | Fraction = 0.989
# Frame 301: Largest cluster = 15900 | Fraction = 0.978
# Frame 302: Largest cluster = 16175 | Fraction = 0.995
# Frame 303: Largest cluster = 15900 | Fraction = 0.978
# Frame 304: Largest cluster = 16025 | Fraction = 0.986
# Frame 305: Largest cluster = 16175 | Fraction = 0.995
# Frame 306: Largest cluster = 16100 | Fraction = 0.991
# Frame 307: Largest cluster = 16075 | Fraction = 0.989
# Frame 308: Largest cluster = 15900 | Fraction = 0.978
# Frame 309: Largest cluster = 16100 | Fraction = 0.991
# Frame 310: Largest cluster = 16000 | Fraction = 0.985
# Frame 311: Largest cluster = 16125 | Fraction = 0.992
# Frame 312: Largest cluster = 16100 | Fraction = 0.991
# Frame 313: Largest cluster = 16125 | Fraction = 0.992
# Frame 314: Largest cluster = 15875 | Fraction = 0.977
# Frame 315: Largest cluster = 15975 | Fraction = 0.983
# Frame 316: Largest cluster = 16025 | Fraction = 0.986
# Frame 317: Largest cluster = 15975 | Fraction = 0.983
# Frame 318: Largest cluster = 16050 | Fraction = 0.988
# Frame 319: Largest cluster = 16000 | Fraction = 0.985
# Frame 320: Largest cluster = 16100 | Fraction = 0.991
# Frame 321: Largest cluster = 15975 | Fraction = 0.983
# Frame 322: Largest cluster = 16100 | Fraction = 0.991
# Frame 323: Largest cluster = 15950 | Fraction = 0.982
# Frame 324: Largest cluster = 15900 | Fraction = 0.978
# Frame 325: Largest cluster = 16075 | Fraction = 0.989
# Frame 326: Largest cluster = 16025 | Fraction = 0.986
# Frame 327: Largest cluster = 16025 | Fraction = 0.986
# Frame 328: Largest cluster = 15900 | Fraction = 0.978
# Frame 329: Largest cluster = 15925 | Fraction = 0.980
# Frame 330: Largest cluster = 16075 | Fraction = 0.989
# Frame 331: Largest cluster = 15975 | Fraction = 0.983
# Frame 332: Largest cluster = 16100 | Fraction = 0.991
# Frame 333: Largest cluster = 16125 | Fraction = 0.992
# Frame 334: Largest cluster = 16150 | Fraction = 0.994
# Frame 335: Largest cluster = 16050 | Fraction = 0.988
# Frame 336: Largest cluster = 16075 | Fraction = 0.989
# Frame 337: Largest cluster = 16025 | Fraction = 0.986
# Frame 338: Largest cluster = 16025 | Fraction = 0.986
# Frame 339: Largest cluster = 16175 | Fraction = 0.995
# Frame 340: Largest cluster = 16125 | Fraction = 0.992
# Frame 341: Largest cluster = 15775 | Fraction = 0.971
# Frame 342: Largest cluster = 15850 | Fraction = 0.975
# Frame 343: Largest cluster = 16000 | Fraction = 0.985
# Frame 344: Largest cluster = 16025 | Fraction = 0.986
# Frame 345: Largest cluster = 16100 | Fraction = 0.991
# Frame 346: Largest cluster = 15900 | Fraction = 0.978
# Frame 347: Largest cluster = 16100 | Fraction = 0.991
# Frame 348: Largest cluster = 16125 | Fraction = 0.992
# Frame 349: Largest cluster = 16100 | Fraction = 0.991
# Frame 350: Largest cluster = 16000 | Fraction = 0.985
# Frame 351: Largest cluster = 16050 | Fraction = 0.988
# Frame 352: Largest cluster = 15925 | Fraction = 0.980
# Frame 353: Largest cluster = 16075 | Fraction = 0.989
# Frame 354: Largest cluster = 15975 | Fraction = 0.983
# Frame 355: Largest cluster = 16000 | Fraction = 0.985
# Frame 356: Largest cluster = 16075 | Fraction = 0.989
# Frame 357: Largest cluster = 15900 | Fraction = 0.978
# Frame 358: Largest cluster = 16050 | Fraction = 0.988
# Frame 359: Largest cluster = 16000 | Fraction = 0.985
# Frame 360: Largest cluster = 16125 | Fraction = 0.992
# Frame 361: Largest cluster = 16125 | Fraction = 0.992
# Frame 362: Largest cluster = 16000 | Fraction = 0.985
# Frame 363: Largest cluster = 15875 | Fraction = 0.977
# Frame 364: Largest cluster = 15975 | Fraction = 0.983
# Frame 365: Largest cluster = 16050 | Fraction = 0.988
# Frame 366: Largest cluster = 16125 | Fraction = 0.992
# Frame 367: Largest cluster = 16125 | Fraction = 0.992
# Frame 368: Largest cluster = 16175 | Fraction = 0.995
# Frame 369: Largest cluster = 15950 | Fraction = 0.982
# Frame 370: Largest cluster = 16150 | Fraction = 0.994
# Frame 371: Largest cluster = 16100 | Fraction = 0.991
# Frame 372: Largest cluster = 15975 | Fraction = 0.983
# Frame 373: Largest cluster = 15950 | Fraction = 0.982
# Frame 374: Largest cluster = 16050 | Fraction = 0.988
# Frame 375: Largest cluster = 15925 | Fraction = 0.980
# Frame 376: Largest cluster = 15975 | Fraction = 0.983
# Frame 377: Largest cluster = 16075 | Fraction = 0.989
# Frame 378: Largest cluster = 16075 | Fraction = 0.989
# Frame 379: Largest cluster = 15975 | Fraction = 0.983
# Frame 380: Largest cluster = 16075 | Fraction = 0.989
# Frame 381: Largest cluster = 16075 | Fraction = 0.989
# Frame 382: Largest cluster = 16175 | Fraction = 0.995
# Frame 383: Largest cluster = 16125 | Fraction = 0.992
# Frame 384: Largest cluster = 16225 | Fraction = 0.998
# Frame 385: Largest cluster = 16075 | Fraction = 0.989
# Frame 386: Largest cluster = 15850 | Fraction = 0.975
# Frame 387: Largest cluster = 15950 | Fraction = 0.982
# Frame 388: Largest cluster = 16075 | Fraction = 0.989
# Frame 389: Largest cluster = 16050 | Fraction = 0.988
# Frame 390: Largest cluster = 16125 | Fraction = 0.992
# Frame 391: Largest cluster = 16200 | Fraction = 0.997
# Frame 392: Largest cluster = 16075 | Fraction = 0.989
# Frame 393: Largest cluster = 16050 | Fraction = 0.988
# Frame 394: Largest cluster = 15825 | Fraction = 0.974
# Frame 395: Largest cluster = 16075 | Fraction = 0.989
# Frame 396: Largest cluster = 15925 | Fraction = 0.980
# Frame 397: Largest cluster = 15875 | Fraction = 0.977
# Frame 398: Largest cluster = 15925 | Fraction = 0.980

# %%
output_frame_csv = '/home/user/Desktop/Anagha/Shin_Colab/Linker_2/No_interaction/N_250/receptor_radial_density.csv'
output_density_csv = '/home/user/Desktop/Anagha/Shin_Colab/Linker_2/No_interaction/N_250/receptor_radial_density_table.csv'
output_plot = '/home/user/Desktop/Anagha/Shin_Colab/Linker_2/No_interaction/N_250/receptor_radial_density.png'

receptor_type = 2
cutoff = 2.5
bin_width = 1.0
max_radius = 30.0 * math.sqrt(2)
slab_thickness = 2.6

u = mda.Universe(lammps_data, trajectory_file, format='LAMMPSDUMP')

class UnionFind:
    def __init__(self, n):
        self.parent = list(range(n))
        self.rank = [0] * n
    def find(self, x):
        while self.parent[x] != x:
            self.parent[x] = self.parent[self.parent[x]]
            x = self.parent[x]
        return x
    def union(self, a, b):
        ra, rb = self.find(a), self.find(b)
        if ra == rb:
            return
        if self.rank[ra] < self.rank[rb]:
            self.parent[ra] = rb
        else:
            self.parent[rb] = ra
            if self.rank[ra] == self.rank[rb]:
                self.rank[ra] += 1

def get_cell_index(pos, cell_size, box):
    return tuple((pos // cell_size).astype(int))

bins = np.arange(0, max_radius + bin_width, bin_width)
bin_centers = 0.5 * (bins[:-1] + bins[1:])
shell_volumes = np.pi * slab_thickness * (bins[1:]**2 - bins[:-1]**2)

radial_density_cluster = np.zeros(len(shell_volumes))
radial_density_all = np.zeros(len(shell_volumes))
valid_frames = 0
frame_results = []

for ts in u.trajectory:
    Lz = ts.dimensions[2]
    receptors = u.select_atoms(f"type {receptor_type} and prop z>{Lz - slab_thickness}")
    total_receptors = len(receptors)
    if total_receptors == 0:
        continue

    receptors.wrap(compound='fragments')
    positions = receptors.positions
    box = ts.dimensions[:3]
    cell_size = cutoff
    cell_dict = defaultdict(list)
    for i, pos in enumerate(positions):
        cell = get_cell_index(pos, cell_size, box)
        cell_dict[cell].append(i)

    neighbor_offsets = [(dx, dy, dz) for dx in [-1, 0, 1] for dy in [-1, 0, 1] for dz in [-1, 0, 1]]
    pairs = []
    for cell, atom_ids in cell_dict.items():
        for dx, dy, dz in neighbor_offsets:
            neighbor_cell = (
                (cell[0] + dx) % int(box[0] / cell_size),
                (cell[1] + dy) % int(box[1] / cell_size),
                (cell[2] + dz) % int(box[2] / cell_size)
            )
            for i in atom_ids:
                for j in cell_dict.get(neighbor_cell, []):
                    if j <= i:
                        continue
                    diff = positions[i] - positions[j]
                    diff -= box * np.round(diff / box)
                    if np.dot(diff, diff) <= cutoff**2:
                        pairs.append((i, j))

    uf = UnionFind(total_receptors)
    for i, j in pairs:
        uf.union(i, j)

    groups = defaultdict(list)
    for i in range(total_receptors):
        groups[uf.find(i)].append(i)

    largest_cluster = max(groups.values(), key=len)
    fraction = len(largest_cluster) / total_receptors
    print(f"Frame {ts.frame}: largest receptor cluster = {len(largest_cluster)} atoms, fraction = {fraction:.3f}")

    frame_results.append([ts.frame, total_receptors, len(largest_cluster), fraction])

    cluster_positions = positions[largest_cluster]
    ref_com_cluster = cluster_positions.mean(axis=0)
    distances_cluster = np.linalg.norm(cluster_positions[:, :2] - ref_com_cluster[:2], axis=1)
    hist_cluster, _ = np.histogram(distances_cluster, bins=bins)
    radial_density_cluster += hist_cluster

    ref_com_all = receptors.center_of_mass()
    distances_all = np.linalg.norm(positions[:, :2] - ref_com_all[:2], axis=1)
    hist_all, _ = np.histogram(distances_all, bins=bins)
    radial_density_all += hist_all

    valid_frames += 1

df_frame = pd.DataFrame(frame_results, columns=["Frame", "TotalReceptors", "LargestClusterSize", "Fraction"])
df_frame.to_csv(output_frame_csv, index=False)

radial_density_cluster /= (valid_frames * shell_volumes)
radial_density_all /= (valid_frames * shell_volumes)

density_table = pd.DataFrame({
    "Radius (Å)": bin_centers,
    "Cluster Density (atoms/Å³)": radial_density_cluster,
    "All Receptors Density (atoms/Å³)": radial_density_all
})
density_table.to_csv(output_density_csv, index=False)

plt.plot(bin_centers, radial_density_cluster, label="Largest Receptor Cluster", color='g')
plt.plot(bin_centers, radial_density_all, label="All Receptors", color='r', linestyle='--')
plt.xlabel("Radius (Å)")
plt.ylabel("Density (atoms/Å³)")
plt.legend()
plt.title("Radial Density Profile - Receptors (Top Slab)")
plt.savefig(output_plot, dpi=300, bbox_inches='tight')
plt.show()
# Out:
# Frame 0: largest receptor cluster = 72 atoms, fraction = 0.288
# Frame 1: largest receptor cluster = 73 atoms, fraction = 0.292
# Frame 2: largest receptor cluster = 159 atoms, fraction = 0.636
# Frame 3: largest receptor cluster = 159 atoms, fraction = 0.636
# Frame 4: largest receptor cluster = 162 atoms, fraction = 0.648
# Frame 5: largest receptor cluster = 173 atoms, fraction = 0.692
# Frame 6: largest receptor cluster = 167 atoms, fraction = 0.668
# Frame 7: largest receptor cluster = 175 atoms, fraction = 0.700
# Frame 8: largest receptor cluster = 188 atoms, fraction = 0.752
# Frame 9: largest receptor cluster = 201 atoms, fraction = 0.804
# Frame 10: largest receptor cluster = 200 atoms, fraction = 0.800
# Frame 11: largest receptor cluster = 206 atoms, fraction = 0.824
# Frame 12: largest receptor cluster = 211 atoms, fraction = 0.844
# Frame 13: largest receptor cluster = 216 atoms, fraction = 0.864
# Frame 14: largest receptor cluster = 221 atoms, fraction = 0.884
# Frame 15: largest receptor cluster = 222 atoms, fraction = 0.888
# Frame 16: largest receptor cluster = 203 atoms, fraction = 0.812
# Frame 17: largest receptor cluster = 209 atoms, fraction = 0.836
# Frame 18: largest receptor cluster = 201 atoms, fraction = 0.804
# Frame 19: largest receptor cluster = 204 atoms, fraction = 0.816
# Frame 20: largest receptor cluster = 207 atoms, fraction = 0.828
# Frame 21: largest receptor cluster = 208 atoms, fraction = 0.832
# Frame 22: largest receptor cluster = 205 atoms, fraction = 0.820
# Frame 23: largest receptor cluster = 195 atoms, fraction = 0.780
# Frame 24: largest receptor cluster = 201 atoms, fraction = 0.804
# Frame 25: largest receptor cluster = 209 atoms, fraction = 0.836
# Frame 26: largest receptor cluster = 208 atoms, fraction = 0.832
# Frame 27: largest receptor cluster = 207 atoms, fraction = 0.828
# Frame 28: largest receptor cluster = 211 atoms, fraction = 0.844
# Frame 29: largest receptor cluster = 207 atoms, fraction = 0.828
# Frame 30: largest receptor cluster = 206 atoms, fraction = 0.824
# Frame 31: largest receptor cluster = 210 atoms, fraction = 0.840
# Frame 32: largest receptor cluster = 202 atoms, fraction = 0.808
# Frame 33: largest receptor cluster = 201 atoms, fraction = 0.804
# Frame 34: largest receptor cluster = 195 atoms, fraction = 0.780
# Frame 35: largest receptor cluster = 195 atoms, fraction = 0.780
# Frame 36: largest receptor cluster = 206 atoms, fraction = 0.824
# Frame 37: largest receptor cluster = 200 atoms, fraction = 0.800
# Frame 38: largest receptor cluster = 212 atoms, fraction = 0.848
# Frame 39: largest receptor cluster = 214 atoms, fraction = 0.856
# Frame 40: largest receptor cluster = 215 atoms, fraction = 0.860
# Frame 41: largest receptor cluster = 212 atoms, fraction = 0.848
# Frame 42: largest receptor cluster = 206 atoms, fraction = 0.824
# Frame 43: largest receptor cluster = 199 atoms, fraction = 0.796
# Frame 44: largest receptor cluster = 210 atoms, fraction = 0.840
# Frame 45: largest receptor cluster = 200 atoms, fraction = 0.800
# Frame 46: largest receptor cluster = 204 atoms, fraction = 0.816
# Frame 47: largest receptor cluster = 210 atoms, fraction = 0.840
# Frame 48: largest receptor cluster = 195 atoms, fraction = 0.780
# Frame 49: largest receptor cluster = 201 atoms, fraction = 0.804
# Frame 50: largest receptor cluster = 210 atoms, fraction = 0.840
# Frame 51: largest receptor cluster = 213 atoms, fraction = 0.852
# Frame 52: largest receptor cluster = 210 atoms, fraction = 0.840
# Frame 53: largest receptor cluster = 208 atoms, fraction = 0.832
# Frame 54: largest receptor cluster = 213 atoms, fraction = 0.852
# Frame 55: largest receptor cluster = 211 atoms, fraction = 0.844
# Frame 56: largest receptor cluster = 206 atoms, fraction = 0.824
# Frame 57: largest receptor cluster = 204 atoms, fraction = 0.816
# Frame 58: largest receptor cluster = 215 atoms, fraction = 0.860
# Frame 59: largest receptor cluster = 212 atoms, fraction = 0.848
# Frame 60: largest receptor cluster = 208 atoms, fraction = 0.832
# Frame 61: largest receptor cluster = 206 atoms, fraction = 0.824
# Frame 62: largest receptor cluster = 197 atoms, fraction = 0.788
# Frame 63: largest receptor cluster = 190 atoms, fraction = 0.760
# Frame 64: largest receptor cluster = 194 atoms, fraction = 0.776
# Frame 65: largest receptor cluster = 190 atoms, fraction = 0.760
# Frame 66: largest receptor cluster = 210 atoms, fraction = 0.840
# Frame 67: largest receptor cluster = 215 atoms, fraction = 0.860
# Frame 68: largest receptor cluster = 215 atoms, fraction = 0.860
# Frame 69: largest receptor cluster = 210 atoms, fraction = 0.840
# Frame 70: largest receptor cluster = 208 atoms, fraction = 0.832
# Frame 71: largest receptor cluster = 209 atoms, fraction = 0.836
# Frame 72: largest receptor cluster = 208 atoms, fraction = 0.832
# Frame 73: largest receptor cluster = 199 atoms, fraction = 0.796
# Frame 74: largest receptor cluster = 205 atoms, fraction = 0.820
# Frame 75: largest receptor cluster = 202 atoms, fraction = 0.808
# Frame 76: largest receptor cluster = 197 atoms, fraction = 0.788
# Frame 77: largest receptor cluster = 212 atoms, fraction = 0.848
# Frame 78: largest receptor cluster = 208 atoms, fraction = 0.832
# Frame 79: largest receptor cluster = 199 atoms, fraction = 0.796
# Frame 80: largest receptor cluster = 196 atoms, fraction = 0.784
# Frame 81: largest receptor cluster = 197 atoms, fraction = 0.788
# Frame 82: largest receptor cluster = 204 atoms, fraction = 0.816
# Frame 83: largest receptor cluster = 216 atoms, fraction = 0.864
# Frame 84: largest receptor cluster = 205 atoms, fraction = 0.820
# Frame 85: largest receptor cluster = 215 atoms, fraction = 0.860
# Frame 86: largest receptor cluster = 214 atoms, fraction = 0.856
# Frame 87: largest receptor cluster = 206 atoms, fraction = 0.824
# Frame 88: largest receptor cluster = 207 atoms, fraction = 0.828
# Frame 89: largest receptor cluster = 207 atoms, fraction = 0.828
# Frame 90: largest receptor cluster = 215 atoms, fraction = 0.860
# Frame 91: largest receptor cluster = 211 atoms, fraction = 0.844
# Frame 92: largest receptor cluster = 193 atoms, fraction = 0.772
# Frame 93: largest receptor cluster = 200 atoms, fraction = 0.800
# Frame 94: largest receptor cluster = 207 atoms, fraction = 0.828
# Frame 95: largest receptor cluster = 210 atoms, fraction = 0.840
# Frame 96: largest receptor cluster = 201 atoms, fraction = 0.804
# Frame 97: largest receptor cluster = 204 atoms, fraction = 0.816
# Frame 98: largest receptor cluster = 204 atoms, fraction = 0.816
# Frame 99: largest receptor cluster = 202 atoms, fraction = 0.808
# Frame 100: largest receptor cluster = 194 atoms, fraction = 0.776
# Frame 101: largest receptor cluster = 211 atoms, fraction = 0.844
# Frame 102: largest receptor cluster = 217 atoms, fraction = 0.868
# Frame 103: largest receptor cluster = 219 atoms, fraction = 0.876
# Frame 104: largest receptor cluster = 212 atoms, fraction = 0.848
# Frame 105: largest receptor cluster = 205 atoms, fraction = 0.820
# Frame 106: largest receptor cluster = 213 atoms, fraction = 0.852
# Frame 107: largest receptor cluster = 207 atoms, fraction = 0.828
# Frame 108: largest receptor cluster = 209 atoms, fraction = 0.836
# Frame 109: largest receptor cluster = 211 atoms, fraction = 0.844
# Frame 110: largest receptor cluster = 207 atoms, fraction = 0.828
# Frame 111: largest receptor cluster = 200 atoms, fraction = 0.800
# Frame 112: largest receptor cluster = 206 atoms, fraction = 0.824
# Frame 113: largest receptor cluster = 219 atoms, fraction = 0.876
# Frame 114: largest receptor cluster = 216 atoms, fraction = 0.864
# Frame 115: largest receptor cluster = 205 atoms, fraction = 0.820
# Frame 116: largest receptor cluster = 208 atoms, fraction = 0.832
# Frame 117: largest receptor cluster = 217 atoms, fraction = 0.868
# Frame 118: largest receptor cluster = 214 atoms, fraction = 0.856
# Frame 119: largest receptor cluster = 196 atoms, fraction = 0.784
# Frame 120: largest receptor cluster = 206 atoms, fraction = 0.824
# Frame 121: largest receptor cluster = 208 atoms, fraction = 0.832
# Frame 122: largest receptor cluster = 204 atoms, fraction = 0.816
# Frame 123: largest receptor cluster = 193 atoms, fraction = 0.772
# Frame 124: largest receptor cluster = 198 atoms, fraction = 0.792
# Frame 125: largest receptor cluster = 194 atoms, fraction = 0.776
# Frame 126: largest receptor cluster = 196 atoms, fraction = 0.784
# Frame 127: largest receptor cluster = 187 atoms, fraction = 0.748
# Frame 128: largest receptor cluster = 201 atoms, fraction = 0.804
# Frame 129: largest receptor cluster = 209 atoms, fraction = 0.836
# Frame 130: largest receptor cluster = 206 atoms, fraction = 0.824
# Frame 131: largest receptor cluster = 211 atoms, fraction = 0.844
# Frame 132: largest receptor cluster = 203 atoms, fraction = 0.812
# Frame 133: largest receptor cluster = 213 atoms, fraction = 0.852
# Frame 134: largest receptor cluster = 208 atoms, fraction = 0.832
# Frame 135: largest receptor cluster = 213 atoms, fraction = 0.852
# Frame 136: largest receptor cluster = 197 atoms, fraction = 0.788
# Frame 137: largest receptor cluster = 208 atoms, fraction = 0.832
# Frame 138: largest receptor cluster = 198 atoms, fraction = 0.792
# Frame 139: largest receptor cluster = 208 atoms, fraction = 0.832
# Frame 140: largest receptor cluster = 198 atoms, fraction = 0.792
# Frame 141: largest receptor cluster = 187 atoms, fraction = 0.748
# Frame 142: largest receptor cluster = 205 atoms, fraction = 0.820
# Frame 143: largest receptor cluster = 207 atoms, fraction = 0.828
# Frame 144: largest receptor cluster = 205 atoms, fraction = 0.820
# Frame 145: largest receptor cluster = 212 atoms, fraction = 0.848
# Frame 146: largest receptor cluster = 210 atoms, fraction = 0.840
# Frame 147: largest receptor cluster = 215 atoms, fraction = 0.860
# Frame 148: largest receptor cluster = 212 atoms, fraction = 0.848
# Frame 149: largest receptor cluster = 200 atoms, fraction = 0.800
# Frame 150: largest receptor cluster = 204 atoms, fraction = 0.816
# Frame 151: largest receptor cluster = 216 atoms, fraction = 0.864
# Frame 152: largest receptor cluster = 215 atoms, fraction = 0.860
# Frame 153: largest receptor cluster = 210 atoms, fraction = 0.840
# Frame 154: largest receptor cluster = 211 atoms, fraction = 0.844
# Frame 155: largest receptor cluster = 211 atoms, fraction = 0.844
# Frame 156: largest receptor cluster = 209 atoms, fraction = 0.836
# Frame 157: largest receptor cluster = 206 atoms, fraction = 0.824
# Frame 158: largest receptor cluster = 209 atoms, fraction = 0.836
# Frame 159: largest receptor cluster = 219 atoms, fraction = 0.876
# Frame 160: largest receptor cluster = 207 atoms, fraction = 0.828
# Frame 161: largest receptor cluster = 203 atoms, fraction = 0.812
# Frame 162: largest receptor cluster = 211 atoms, fraction = 0.844
# Frame 163: largest receptor cluster = 211 atoms, fraction = 0.844
# Frame 164: largest receptor cluster = 216 atoms, fraction = 0.864
# Frame 165: largest receptor cluster = 223 atoms, fraction = 0.892
# Frame 166: largest receptor cluster = 208 atoms, fraction = 0.832
# Frame 167: largest receptor cluster = 211 atoms, fraction = 0.844
# Frame 168: largest receptor cluster = 213 atoms, fraction = 0.852
# Frame 169: largest receptor cluster = 219 atoms, fraction = 0.876
# Frame 170: largest receptor cluster = 218 atoms, fraction = 0.872
# Frame 171: largest receptor cluster = 216 atoms, fraction = 0.864
# Frame 172: largest receptor cluster = 195 atoms, fraction = 0.780
# Frame 173: largest receptor cluster = 213 atoms, fraction = 0.852
# Frame 174: largest receptor cluster = 208 atoms, fraction = 0.832
# Frame 175: largest receptor cluster = 218 atoms, fraction = 0.872
# Frame 176: largest receptor cluster = 218 atoms, fraction = 0.872
# Frame 177: largest receptor cluster = 212 atoms, fraction = 0.848
# Frame 178: largest receptor cluster = 205 atoms, fraction = 0.820
# Frame 179: largest receptor cluster = 203 atoms, fraction = 0.812
# Frame 180: largest receptor cluster = 208 atoms, fraction = 0.832
# Frame 181: largest receptor cluster = 209 atoms, fraction = 0.836
# Frame 182: largest receptor cluster = 204 atoms, fraction = 0.816
# Frame 183: largest receptor cluster = 209 atoms, fraction = 0.836
# Frame 184: largest receptor cluster = 206 atoms, fraction = 0.824
# Frame 185: largest receptor cluster = 202 atoms, fraction = 0.808
# Frame 186: largest receptor cluster = 202 atoms, fraction = 0.808
# Frame 187: largest receptor cluster = 203 atoms, fraction = 0.812
# Frame 188: largest receptor cluster = 199 atoms, fraction = 0.796
# Frame 189: largest receptor cluster = 197 atoms, fraction = 0.788
# Frame 190: largest receptor cluster = 195 atoms, fraction = 0.780
# Frame 191: largest receptor cluster = 204 atoms, fraction = 0.816
# Frame 192: largest receptor cluster = 212 atoms, fraction = 0.848
# Frame 193: largest receptor cluster = 211 atoms, fraction = 0.844
# Frame 194: largest receptor cluster = 213 atoms, fraction = 0.852
# Frame 195: largest receptor cluster = 200 atoms, fraction = 0.800
# Frame 196: largest receptor cluster = 208 atoms, fraction = 0.832
# Frame 197: largest receptor cluster = 208 atoms, fraction = 0.832
# Frame 198: largest receptor cluster = 202 atoms, fraction = 0.808
# Frame 199: largest receptor cluster = 197 atoms, fraction = 0.788
# Frame 200: largest receptor cluster = 206 atoms, fraction = 0.824
# Frame 201: largest receptor cluster = 187 atoms, fraction = 0.748
# Frame 202: largest receptor cluster = 202 atoms, fraction = 0.808
# Frame 203: largest receptor cluster = 202 atoms, fraction = 0.808
# Frame 204: largest receptor cluster = 196 atoms, fraction = 0.784
# Frame 205: largest receptor cluster = 203 atoms, fraction = 0.812
# Frame 206: largest receptor cluster = 198 atoms, fraction = 0.792
# Frame 207: largest receptor cluster = 202 atoms, fraction = 0.808
# Frame 208: largest receptor cluster = 199 atoms, fraction = 0.796
# Frame 209: largest receptor cluster = 204 atoms, fraction = 0.816
# Frame 210: largest receptor cluster = 205 atoms, fraction = 0.820
# Frame 211: largest receptor cluster = 205 atoms, fraction = 0.820
# Frame 212: largest receptor cluster = 208 atoms, fraction = 0.832
# Frame 213: largest receptor cluster = 205 atoms, fraction = 0.820
# Frame 214: largest receptor cluster = 204 atoms, fraction = 0.816
# Frame 215: largest receptor cluster = 209 atoms, fraction = 0.836
# Frame 216: largest receptor cluster = 204 atoms, fraction = 0.816
# Frame 217: largest receptor cluster = 211 atoms, fraction = 0.844
# Frame 218: largest receptor cluster = 203 atoms, fraction = 0.812
# Frame 219: largest receptor cluster = 193 atoms, fraction = 0.772
# Frame 220: largest receptor cluster = 193 atoms, fraction = 0.772
# Frame 221: largest receptor cluster = 204 atoms, fraction = 0.816
# Frame 222: largest receptor cluster = 199 atoms, fraction = 0.796
# Frame 223: largest receptor cluster = 201 atoms, fraction = 0.804
# Frame 224: largest receptor cluster = 192 atoms, fraction = 0.768
# Frame 225: largest receptor cluster = 202 atoms, fraction = 0.808
# Frame 226: largest receptor cluster = 202 atoms, fraction = 0.808
# Frame 227: largest receptor cluster = 209 atoms, fraction = 0.836
# Frame 228: largest receptor cluster = 210 atoms, fraction = 0.840
# Frame 229: largest receptor cluster = 204 atoms, fraction = 0.816
# Frame 230: largest receptor cluster = 215 atoms, fraction = 0.860
# Frame 231: largest receptor cluster = 203 atoms, fraction = 0.812
# Frame 232: largest receptor cluster = 209 atoms, fraction = 0.836
# Frame 233: largest receptor cluster = 209 atoms, fraction = 0.836
# Frame 234: largest receptor cluster = 207 atoms, fraction = 0.828
# Frame 235: largest receptor cluster = 204 atoms, fraction = 0.816
# Frame 236: largest receptor cluster = 199 atoms, fraction = 0.796
# Frame 237: largest receptor cluster = 204 atoms, fraction = 0.816
# Frame 238: largest receptor cluster = 208 atoms, fraction = 0.832
# Frame 239: largest receptor cluster = 206 atoms, fraction = 0.824
# Frame 240: largest receptor cluster = 198 atoms, fraction = 0.792
# Frame 241: largest receptor cluster = 194 atoms, fraction = 0.776
# Frame 242: largest receptor cluster = 204 atoms, fraction = 0.816
# Frame 243: largest receptor cluster = 195 atoms, fraction = 0.780
# Frame 244: largest receptor cluster = 206 atoms, fraction = 0.824
# Frame 245: largest receptor cluster = 212 atoms, fraction = 0.848
# Frame 246: largest receptor cluster = 201 atoms, fraction = 0.804
# Frame 247: largest receptor cluster = 209 atoms, fraction = 0.836
# Frame 248: largest receptor cluster = 194 atoms, fraction = 0.776
# Frame 249: largest receptor cluster = 198 atoms, fraction = 0.792
# Frame 250: largest receptor cluster = 203 atoms, fraction = 0.812
# Frame 251: largest receptor cluster = 224 atoms, fraction = 0.896
# Frame 252: largest receptor cluster = 201 atoms, fraction = 0.804
# Frame 253: largest receptor cluster = 214 atoms, fraction = 0.856
# Frame 254: largest receptor cluster = 205 atoms, fraction = 0.820
# Frame 255: largest receptor cluster = 209 atoms, fraction = 0.836
# Frame 256: largest receptor cluster = 209 atoms, fraction = 0.836
# Frame 257: largest receptor cluster = 216 atoms, fraction = 0.864
# Frame 258: largest receptor cluster = 211 atoms, fraction = 0.844
# Frame 259: largest receptor cluster = 213 atoms, fraction = 0.852
# Frame 260: largest receptor cluster = 208 atoms, fraction = 0.832
# Frame 261: largest receptor cluster = 206 atoms, fraction = 0.824
# Frame 262: largest receptor cluster = 198 atoms, fraction = 0.792
# Frame 263: largest receptor cluster = 206 atoms, fraction = 0.824
# Frame 264: largest receptor cluster = 208 atoms, fraction = 0.832
# Frame 265: largest receptor cluster = 207 atoms, fraction = 0.828
# Frame 266: largest receptor cluster = 197 atoms, fraction = 0.788
# Frame 267: largest receptor cluster = 202 atoms, fraction = 0.808
# Frame 268: largest receptor cluster = 210 atoms, fraction = 0.840
# Frame 269: largest receptor cluster = 200 atoms, fraction = 0.800
# Frame 270: largest receptor cluster = 211 atoms, fraction = 0.844
# Frame 271: largest receptor cluster = 212 atoms, fraction = 0.848
# Frame 272: largest receptor cluster = 210 atoms, fraction = 0.840
# Frame 273: largest receptor cluster = 203 atoms, fraction = 0.812
# Frame 274: largest receptor cluster = 200 atoms, fraction = 0.800
# Frame 275: largest receptor cluster = 208 atoms, fraction = 0.832
# Frame 276: largest receptor cluster = 208 atoms, fraction = 0.832
# Frame 277: largest receptor cluster = 191 atoms, fraction = 0.764
# Frame 278: largest receptor cluster = 210 atoms, fraction = 0.840
# Frame 279: largest receptor cluster = 193 atoms, fraction = 0.772
# Frame 280: largest receptor cluster = 195 atoms, fraction = 0.780
# Frame 281: largest receptor cluster = 196 atoms, fraction = 0.784
# Frame 282: largest receptor cluster = 191 atoms, fraction = 0.764
# Frame 283: largest receptor cluster = 198 atoms, fraction = 0.792
# Frame 284: largest receptor cluster = 206 atoms, fraction = 0.824
# Frame 285: largest receptor cluster = 193 atoms, fraction = 0.772
# Frame 286: largest receptor cluster = 207 atoms, fraction = 0.828
# Frame 287: largest receptor cluster = 208 atoms, fraction = 0.832
# Frame 288: largest receptor cluster = 211 atoms, fraction = 0.844
# Frame 289: largest receptor cluster = 216 atoms, fraction = 0.864
# Frame 290: largest receptor cluster = 209 atoms, fraction = 0.836
# Frame 291: largest receptor cluster = 218 atoms, fraction = 0.872
# Frame 292: largest receptor cluster = 211 atoms, fraction = 0.844
# Frame 293: largest receptor cluster = 210 atoms, fraction = 0.840
# Frame 294: largest receptor cluster = 208 atoms, fraction = 0.832
# Frame 295: largest receptor cluster = 213 atoms, fraction = 0.852
# Frame 296: largest receptor cluster = 213 atoms, fraction = 0.852
# Frame 297: largest receptor cluster = 215 atoms, fraction = 0.860
# Frame 298: largest receptor cluster = 216 atoms, fraction = 0.864
# Frame 299: largest receptor cluster = 202 atoms, fraction = 0.808
# Frame 300: largest receptor cluster = 206 atoms, fraction = 0.824
# Frame 301: largest receptor cluster = 212 atoms, fraction = 0.848
# Frame 302: largest receptor cluster = 201 atoms, fraction = 0.804
# Frame 303: largest receptor cluster = 213 atoms, fraction = 0.852
# Frame 304: largest receptor cluster = 213 atoms, fraction = 0.852
# Frame 305: largest receptor cluster = 204 atoms, fraction = 0.816
# Frame 306: largest receptor cluster = 211 atoms, fraction = 0.844
# Frame 307: largest receptor cluster = 208 atoms, fraction = 0.832
# Frame 308: largest receptor cluster = 204 atoms, fraction = 0.816
# Frame 309: largest receptor cluster = 200 atoms, fraction = 0.800
# Frame 310: largest receptor cluster = 203 atoms, fraction = 0.812
# Frame 311: largest receptor cluster = 201 atoms, fraction = 0.804
# Frame 312: largest receptor cluster = 227 atoms, fraction = 0.908
# Frame 313: largest receptor cluster = 218 atoms, fraction = 0.872
# Frame 314: largest receptor cluster = 206 atoms, fraction = 0.824
# Frame 315: largest receptor cluster = 201 atoms, fraction = 0.804
# Frame 316: largest receptor cluster = 204 atoms, fraction = 0.816
# Frame 317: largest receptor cluster = 210 atoms, fraction = 0.840
# Frame 318: largest receptor cluster = 209 atoms, fraction = 0.836
# Frame 319: largest receptor cluster = 201 atoms, fraction = 0.804
# Frame 320: largest receptor cluster = 211 atoms, fraction = 0.844
# Frame 321: largest receptor cluster = 206 atoms, fraction = 0.824
# Frame 322: largest receptor cluster = 211 atoms, fraction = 0.844
# Frame 323: largest receptor cluster = 204 atoms, fraction = 0.816
# Frame 324: largest receptor cluster = 208 atoms, fraction = 0.832
# Frame 325: largest receptor cluster = 202 atoms, fraction = 0.808
# Frame 326: largest receptor cluster = 206 atoms, fraction = 0.824
# Frame 327: largest receptor cluster = 204 atoms, fraction = 0.816
# Frame 328: largest receptor cluster = 209 atoms, fraction = 0.836
# Frame 329: largest receptor cluster = 206 atoms, fraction = 0.824
# Frame 330: largest receptor cluster = 204 atoms, fraction = 0.816
# Frame 331: largest receptor cluster = 201 atoms, fraction = 0.804
# Frame 332: largest receptor cluster = 195 atoms, fraction = 0.780
# Frame 333: largest receptor cluster = 204 atoms, fraction = 0.816
# Frame 334: largest receptor cluster = 201 atoms, fraction = 0.804
# Frame 335: largest receptor cluster = 204 atoms, fraction = 0.816
# Frame 336: largest receptor cluster = 209 atoms, fraction = 0.836
# Frame 337: largest receptor cluster = 206 atoms, fraction = 0.824
# Frame 338: largest receptor cluster = 209 atoms, fraction = 0.836
# Frame 339: largest receptor cluster = 213 atoms, fraction = 0.852
# Frame 340: largest receptor cluster = 209 atoms, fraction = 0.836
# Frame 341: largest receptor cluster = 210 atoms, fraction = 0.840
# Frame 342: largest receptor cluster = 207 atoms, fraction = 0.828
# Frame 343: largest receptor cluster = 207 atoms, fraction = 0.828
# Frame 344: largest receptor cluster = 204 atoms, fraction = 0.816
# Frame 345: largest receptor cluster = 213 atoms, fraction = 0.852
# Frame 346: largest receptor cluster = 214 atoms, fraction = 0.856
# Frame 347: largest receptor cluster = 208 atoms, fraction = 0.832
# Frame 348: largest receptor cluster = 211 atoms, fraction = 0.844
# Frame 349: largest receptor cluster = 203 atoms, fraction = 0.812
# Frame 350: largest receptor cluster = 210 atoms, fraction = 0.840
# Frame 351: largest receptor cluster = 209 atoms, fraction = 0.836
# Frame 352: largest receptor cluster = 204 atoms, fraction = 0.816
# Frame 353: largest receptor cluster = 207 atoms, fraction = 0.828
# Frame 354: largest receptor cluster = 202 atoms, fraction = 0.808
# Frame 355: largest receptor cluster = 190 atoms, fraction = 0.760
# Frame 356: largest receptor cluster = 204 atoms, fraction = 0.816
# Frame 357: largest receptor cluster = 202 atoms, fraction = 0.808
# Frame 358: largest receptor cluster = 212 atoms, fraction = 0.848
# Frame 359: largest receptor cluster = 216 atoms, fraction = 0.864
# Frame 360: largest receptor cluster = 209 atoms, fraction = 0.836
# Frame 361: largest receptor cluster = 209 atoms, fraction = 0.836
# Frame 362: largest receptor cluster = 206 atoms, fraction = 0.824
# Frame 363: largest receptor cluster = 206 atoms, fraction = 0.824
# Frame 364: largest receptor cluster = 212 atoms, fraction = 0.848
# Frame 365: largest receptor cluster = 214 atoms, fraction = 0.856
# Frame 366: largest receptor cluster = 204 atoms, fraction = 0.816
# Frame 367: largest receptor cluster = 213 atoms, fraction = 0.852
# Frame 368: largest receptor cluster = 211 atoms, fraction = 0.844
# Frame 369: largest receptor cluster = 200 atoms, fraction = 0.800
# Frame 370: largest receptor cluster = 204 atoms, fraction = 0.816
# Frame 371: largest receptor cluster = 211 atoms, fraction = 0.844
# Frame 372: largest receptor cluster = 204 atoms, fraction = 0.816
# Frame 373: largest receptor cluster = 208 atoms, fraction = 0.832
# Frame 374: largest receptor cluster = 210 atoms, fraction = 0.840
# Frame 375: largest receptor cluster = 208 atoms, fraction = 0.832
# Frame 376: largest receptor cluster = 200 atoms, fraction = 0.800
# Frame 377: largest receptor cluster = 194 atoms, fraction = 0.776
# Frame 378: largest receptor cluster = 192 atoms, fraction = 0.768
# Frame 379: largest receptor cluster = 191 atoms, fraction = 0.764
# Frame 380: largest receptor cluster = 197 atoms, fraction = 0.788
# Frame 381: largest receptor cluster = 209 atoms, fraction = 0.836
# Frame 382: largest receptor cluster = 206 atoms, fraction = 0.824
# Frame 383: largest receptor cluster = 198 atoms, fraction = 0.792
# Frame 384: largest receptor cluster = 189 atoms, fraction = 0.756
# Frame 385: largest receptor cluster = 192 atoms, fraction = 0.768
# Frame 386: largest receptor cluster = 198 atoms, fraction = 0.792
# Frame 387: largest receptor cluster = 192 atoms, fraction = 0.768
# Frame 388: largest receptor cluster = 204 atoms, fraction = 0.816
# Frame 389: largest receptor cluster = 199 atoms, fraction = 0.796
# Frame 390: largest receptor cluster = 201 atoms, fraction = 0.804
# Frame 391: largest receptor cluster = 200 atoms, fraction = 0.800
# Frame 392: largest receptor cluster = 200 atoms, fraction = 0.800
# Frame 393: largest receptor cluster = 197 atoms, fraction = 0.788
# Frame 394: largest receptor cluster = 215 atoms, fraction = 0.860
# Frame 395: largest receptor cluster = 202 atoms, fraction = 0.808
# Frame 396: largest receptor cluster = 209 atoms, fraction = 0.836
# Frame 397: largest receptor cluster = 214 atoms, fraction = 0.856
# Frame 398: largest receptor cluster = 214 atoms, fraction = 0.856
# Frame 399: largest receptor cluster = 201 atoms, fraction = 0.804

# %%
print(df.columns.tolist())
# Out:
# ['Frame', 'Num_Receptors', 'LargestClusterSize', 'Fraction']

# %%
root_folder = '/home/user/Desktop/Anagha/Shin_Colab/Linker_2/eps_0.5'

# Automatically detect all folders starting with "N_"
n_folders = [f for f in os.listdir(root_folder) 
             if os.path.isdir(os.path.join(root_folder, f)) and re.match(r'^N_\d+$', f)]
n_folders.sort(key=lambda x: int(x.split('_')[1]))  # Sort numerically

# Output plot path
output_plot = os.path.join(root_folder, 'all_N_radial_density_plot.png')

# Initialize plot
plt.figure(figsize=(10,6))

# Loop through folders
for n in n_folders:
    folder_path = os.path.join(root_folder, n)
    csv_file = os.path.join(folder_path, 'polymer_radial_density_table.csv')
    
    # Check if CSV exists
    if not os.path.isfile(csv_file):
        print(f" CSV not found in {folder_path}, skipping...")
        continue
    
    # Load CSV
    try:
        df = pd.read_csv(csv_file)
    except Exception as e:
        print(f" Error reading {csv_file}: {e}")
        continue
    
    # Check required columns
    if 'Radius(Å)' not in df.columns or 'ClusterDensity(atoms/Å³)' not in df.columns:
        print(f" Required columns missing in {csv_file}, skipping...")
        continue
    
    # Extract data
    radius = df['Radius(Å)']
    cluster_density = df['ClusterDensity(atoms/Å³)']
    
    # Plot
    plt.plot(radius, cluster_density, label=n, linewidth=2)

# Plot formatting
plt.xlabel('Radius (Å)', fontsize=12)
plt.ylabel('Density (atoms/Å³)', fontsize=12)
plt.title('Radial Density Profile of Polymer for All N', fontsize=14)
plt.legend(title='N Values')
plt.grid(True, alpha=0.3)
plt.tight_layout()

# Save plot
plt.savefig(output_plot, dpi=300, bbox_inches='tight')
plt.show()

print(f"\n Combined plot saved at: {output_plot}")
# Out:
#  Combined plot saved at: /home/user/Desktop/Anagha/Shin_Colab/Linker_2/eps_0.5/all_N_radial_density_plot.png

# %%
root_folder = '/home/user/Desktop/Anagha/Shin_Colab/Linker_2/eps_0.5'

# Automatically detect all folders starting with "N_"
n_folders = [f for f in os.listdir(root_folder) 
             if os.path.isdir(os.path.join(root_folder, f)) and re.match(r'^N_\d+$', f)]
n_folders.sort(key=lambda x: int(x.split('_')[1]))  # Sort numerically

# Output plot path
output_plot = os.path.join(root_folder, 'all_N_radial_density_plot_log.png')

# Initialize plot
plt.figure(figsize=(10,6))

# Loop through folders
for n in n_folders:
    folder_path = os.path.join(root_folder, n)
    csv_file = os.path.join(folder_path, 'polymer_radial_density_table.csv')
    
    # Check if CSV exists
    if not os.path.isfile(csv_file):
        print(f" CSV not found in {folder_path}, skipping...")
        continue
    
    # Load CSV
    try:
        df = pd.read_csv(csv_file)
    except Exception as e:
        print(f" Error reading {csv_file}: {e}")
        continue
    
    # Check required columns
    if 'Radius(Å)' not in df.columns or 'ClusterDensity(atoms/Å³)' not in df.columns:
        print(f" Required columns missing in {csv_file}, skipping...")
        continue
    
    # Extract data
    radius = df['Radius(Å)']
    cluster_density = df['ClusterDensity(atoms/Å³)']

    plt.plot(radius, cluster_density, label=n, linewidth=2)

plt.xlabel('Radius (Å)', fontsize=12)
plt.ylabel('Density (atoms/Å³)', fontsize=12)
plt.yscale('log')  # Set y-axis to log scale
plt.title('Radial Density Profile of Polymer for All N (log scale)', fontsize=14)
plt.legend(title='N Values')
plt.grid(True, alpha=0.3, which='both')  # grid for both major and minor ticks
plt.tight_layout()

plt.savefig(output_plot, dpi=300, bbox_inches='tight')
plt.show()

print(f"\n Combined plot saved at: {output_plot}")
# Out:
#  Combined plot saved at: /home/user/Desktop/Anagha/Shin_Colab/Linker_2/eps_0.5/all_N_radial_density_plot_log.png

# %%
root_folder = '/home/user/Desktop/Anagha/Shin_Colab/Linker_2/eps_0.5'

# Detect all folders starting with "N_"
n_folders = [f for f in os.listdir(root_folder) 
             if os.path.isdir(os.path.join(root_folder, f)) and re.match(r'^N_\d+$', f)]
# Sort numerically by the number after N_
n_folders.sort(key=lambda x: int(x.split('_')[1]))

# Output plot path
output_plot = os.path.join(root_folder, 'all_N_receptor_radial_density_plot.png')

# Initialize plot
plt.figure(figsize=(10,6))

# Loop through folders
for n in n_folders:
    folder_path = os.path.join(root_folder, n)
    csv_file = os.path.join(folder_path, 'receptor_radial_density_table.csv')
    
    if not os.path.isfile(csv_file):
        print(f" CSV not found in {folder_path}, skipping...")
        continue
    
    try:
        df = pd.read_csv(csv_file)
    except Exception as e:
        print(f" Error reading {csv_file}: {e}")
        continue
    
    # Check required columns
    required_cols = ['Radius (Å)', 'Cluster Density (atoms/Å³)']
    if not all(col in df.columns for col in required_cols):
        print(f" Required columns missing in {csv_file}, skipping...")
        continue
    
    # Extract data
    radius = df['Radius (Å)']
    cluster_density = df['Cluster Density (atoms/Å³)']
    
    # Plot cluster density
    plt.plot(radius, cluster_density, label=n, linewidth=2)

# Plot formatting
plt.xlabel('Radius (Å)', fontsize=12)
plt.ylabel('Density (atoms/Å³)', fontsize=12)
plt.title('Radial Density Profile of Receptors for All N', fontsize=14)
plt.legend(title='N Values')
plt.grid(True, alpha=0.3)
plt.tight_layout()

# Save and show plot
plt.savefig(output_plot, dpi=300, bbox_inches='tight')
plt.show()

print(f"\n Combined receptor plot saved at: {output_plot}")
# Out:
#  Combined receptor plot saved at: /home/user/Desktop/Anagha/Shin_Colab/Linker_2/eps_0.5/all_N_receptor_radial_density_plot.png

# %%
root_folder = '/home/user/Desktop/Anagha/Shin_Colab/Linker_2/eps_0.5'

# Detect all folders starting with "N_"
n_folders = [f for f in os.listdir(root_folder) 
             if os.path.isdir(os.path.join(root_folder, f)) and re.match(r'^N_\d+$', f)]
# Sort numerically by the number after N_
n_folders.sort(key=lambda x: int(x.split('_')[1]))

# Output plot path
output_plot = os.path.join(root_folder, 'all_N_receptor_radial_density_log_plot.png')

# Initialize plot
plt.figure(figsize=(10,6))

# Loop through folders
for n in n_folders:
    folder_path = os.path.join(root_folder, n)
    csv_file = os.path.join(folder_path, 'receptor_radial_density_table.csv')
    
    if not os.path.isfile(csv_file):
        print(f"CSV not found in {folder_path}, skipping...")
        continue
    
    try:
        df = pd.read_csv(csv_file)
    except Exception as e:
        print(f"Error reading {csv_file}: {e}")
        continue
    
    # Check required columns
    required_cols = ['Radius (Å)', 'Cluster Density (atoms/Å³)']
    if not all(col in df.columns for col in required_cols):
        print(f"Required columns missing in {csv_file}, skipping...")
        continue
    
    # Extract data
    radius = df['Radius (Å)']
    cluster_density = df['Cluster Density (atoms/Å³)']

    plt.plot(radius, cluster_density, label=n, linewidth=2)

plt.xlabel('Radius (Å)', fontsize=12)
plt.ylabel('Density (atoms/Å³)', fontsize=12)
plt.yscale('log')  # Log scale for y-axis
plt.title('Radial Density Profile of Receptors for All N (log scale)', fontsize=14)
plt.legend(title='N Values')
plt.grid(True, alpha=0.3, which='both')
plt.tight_layout()

plt.savefig(output_plot, dpi=300, bbox_inches='tight')
plt.show()

print(f"\nCombined receptor plot (log scale) saved at: {output_plot}")
# Out:
# Combined receptor plot (log scale) saved at: /home/user/Desktop/Anagha/Shin_Colab/Linker_2/eps_0.5/all_N_receptor_radial_density_log_plot.png

# %%
root_folder = '/home/user/Desktop/Anagha/Shin_Colab/Linker_2/No_interaction'

# Detect all folders starting with "N_"
n_folders = [f for f in os.listdir(root_folder) 
             if os.path.isdir(os.path.join(root_folder, f)) and re.match(r'^N_\d+$', f)]
# Sort numerically by the number after N_
n_folders.sort(key=lambda x: int(x.split('_')[1]))

# Output plot path
output_plot = os.path.join(root_folder, 'all_N_receptor_radial_density_plot.png')

# Initialize plot
plt.figure(figsize=(10,6))

# Loop through folders
for n in n_folders:
    folder_path = os.path.join(root_folder, n)
    csv_file = os.path.join(folder_path, 'receptor_radial_density_table.csv')
    
    if not os.path.isfile(csv_file):
        print(f" CSV not found in {folder_path}, skipping...")
        continue
    
    try:
        df = pd.read_csv(csv_file)
    except Exception as e:
        print(f" Error reading {csv_file}: {e}")
        continue
    
    # Check required columns
    required_cols = ['Radius (Å)', 'Cluster Density (atoms/Å³)']
    if not all(col in df.columns for col in required_cols):
        print(f" Required columns missing in {csv_file}, skipping...")
        continue
    
    # Extract data
    radius = df['Radius (Å)']
    cluster_density = df['Cluster Density (atoms/Å³)']
    
    # Plot cluster density
    plt.plot(radius, cluster_density, label=n, linewidth=2)

# Plot formatting
plt.xlabel('Radius (Å)', fontsize=12)
plt.ylabel('Density (atoms/Å³)', fontsize=12)
plt.title('Radial Density Profile of Receptors for All N (No_interaction)', fontsize=14)
plt.legend(title='N Values')
plt.grid(True, alpha=0.3)
plt.tight_layout()

# Save and show plot
plt.savefig(output_plot, dpi=300, bbox_inches='tight')
plt.show()delete_atoms random count 75 no ligand NULL 32

print(f"\n Combined receptor plot saved at: {output_plot}")
# Out:
#  Combined receptor plot saved at: /home/user/Desktop/Anagha/Shin_Colab/Linker_2/No_interaction/all_N_receptor_radial_density_plot.png

# %%
root_folder = '/home/user/Desktop/Anagha/Shin_Colab/Linker_2/No_interaction'

# Detect all folders starting with "N_"
n_folders = [f for f in os.listdir(root_folder) 
             if os.path.isdir(os.path.join(root_folder, f)) and re.match(r'^N_\d+$', f)]
# Sort numerically by the number after N_
n_folders.sort(key=lambda x: int(x.split('_')[1]))

# Output plot path
output_plot = os.path.join(root_folder, 'all_N_polymer_radial_density_plot.png')

# Initialize plot
plt.figure(figsize=(10,6))

# Loop through folders
for n in n_folders:
    folder_path = os.path.join(root_folder, n)
    csv_file = os.path.join(folder_path, 'polymer_radial_density_table.csv')
    
    if not os.path.isfile(csv_file):
        print(f"CSV not found in {folder_path}, skipping...")
        continue
    
    try:
        df = pd.read_csv(csv_file)
    except Exception as e:
        print(f"Error reading {csv_file}: {e}")
        continue
    
    # Check required columns
    required_cols = ['Radius(Å)', 'ClusterDensity(atoms/Å³)']
    if not all(col in df.columns for col in required_cols):
        print(f"Required columns missing in {csv_file}, skipping...")
        continue
    
    # Extract data
    radius = df['Radius(Å)']
    cluster_density = df['ClusterDensity(atoms/Å³)']
    
    # Plot cluster density
    plt.plot(radius, cluster_density, label=n, linewidth=2)

# Plot formatting
plt.xlabel('Radius (Å)', fontsize=12)
plt.ylabel('Density (atoms/Å³)', fontsize=12)
plt.title('Radial Density Profile of Polymers for All N (No_interaction)', fontsize=14)
plt.legend(title='N Values')
plt.grid(True, alpha=0.3)
plt.tight_layout()

# Save and show plot
plt.savefig(output_plot, dpi=300, bbox_inches='tight')
plt.show()

print(f"\n Combined polymer plot saved at: {output_plot}")
# Out:
#  Combined polymer plot saved at: /home/user/Desktop/Anagha/Shin_Colab/Linker_2/No_interaction/all_N_polymer_radial_density_plot.png

# %%
root_folder = '/home/user/Desktop/Anagha/Shin_Colab/Linker_2/eps_0.5'

# Get all subfolders like N_1, N_20, N_50 ...
n_folders = [f for f in os.listdir(root_folder)
             if os.path.isdir(os.path.join(root_folder, f)) and re.match(r'^N_\d+$', f)]
n_folders.sort(key=lambda x: int(x.split('_')[1]))  # Sort by numeric N value

n_values = []
avg_fractions = []
std_fractions = []  # standard deviation for error bars

for n in n_folders:
    folder_path = os.path.join(root_folder, n)
    csv_file = os.path.join(folder_path, 'receptor_radial_density.csv')

    if not os.path.isfile(csv_file):
        print(f"Missing file: {csv_file}")
        continue

    try:
        df = pd.read_csv(csv_file)
    except Exception as e:
        print(f"Error reading {csv_file}: {e}")
        continue

    if 'Fraction' not in df.columns:
        print(f"No 'Fraction' column found in {csv_file}")
        continue

    # Compute mean and std of receptor fraction
    avg_fraction = df['Fraction'].mean()
    std_fraction = df['Fraction'].std()
    n_value = int(n.split('_')[1])

    n_values.append(n_value)
    avg_fractions.append(avg_fraction)
    std_fractions.append(std_fraction)

# --- Plot Fraction vs N with error bars ---
plt.figure(figsize=(8,5))
plt.errorbar(n_values, avg_fractions, yerr=std_fractions, fmt='o-', color='darkblue',
             ecolor='black', capsize=5, linewidth=2, label='Receptor Fraction')

plt.xlabel('N (Receptor Count)', fontsize=12)
plt.ylabel('Average Fraction of Receptors in Cluster', fontsize=12)
plt.title('Receptor Fraction in Cluster vs N (eps_0.5)', fontsize=14)
plt.grid(True, alpha=0.3)
plt.legend()
plt.tight_layout()

# Save the plot
output_plot = os.path.join(root_folder, 'receptor_fraction_vs_N_errorbars.png')
plt.savefig(output_plot, dpi=300, bbox_inches='tight')
plt.show()

print(f"\n Receptor fraction vs N (with error bars) saved to:\n{output_plot}")
# Out:
#  Receptor fraction vs N (with error bars) saved to:
# /home/user/Desktop/Anagha/Shin_Colab/Linker_2/eps_0.5/receptor_fraction_vs_N_errorbars.png

# %%
root_folder = '/home/user/Desktop/Anagha/Shin_Colab/Linker_2/No_interaction'

# Get all subfolders like N_1, N_20, N_50 ...
n_folders = [f for f in os.listdir(root_folder)
             if os.path.isdir(os.path.join(root_folder, f)) and re.match(r'^N_\d+$', f)]
n_folders.sort(key=lambda x: int(x.split('_')[1]))  # Sort by numeric N value

n_values = []
avg_fractions = []
std_fractions = []  # standard deviation for error bars

for n in n_folders:
    folder_path = os.path.join(root_folder, n)
    csv_file = os.path.join(folder_path, 'receptor_radial_density.csv')

    if not os.path.isfile(csv_file):
        print(f"Missing file: {csv_file}")
        continue

    try:
        df = pd.read_csv(csv_file)
    except Exception as e:
        print(f"Error reading {csv_file}: {e}")
        continue

    if 'Fraction' not in df.columns:
        print(f"No 'Fraction' column found in {csv_file}")
        continue

    # Compute mean and std of receptor fraction
    avg_fraction = df['Fraction'].mean()
    std_fraction = df['Fraction'].std()
    n_value = int(n.split('_')[1])

    n_values.append(n_value)
    avg_fractions.append(avg_fraction)
    std_fractions.append(std_fraction)

# --- Plot Fraction vs N with error bars ---
plt.figure(figsize=(8,5))
plt.errorbar(n_values, avg_fractions, yerr=std_fractions, fmt='o-', color='darkblue',
             ecolor='black', capsize=5, linewidth=2, label='Receptor Fraction')

plt.xlabel('N (Receptor Count)', fontsize=12)
plt.ylabel('Average Fraction of Receptors in Cluster', fontsize=12)
plt.title('Receptor Fraction in Cluster vs N (No_interaction)', fontsize=14)
plt.grid(True, alpha=0.3)
plt.legend()
plt.tight_layout()

# Save the plot
output_plot = os.path.join(root_folder, 'receptor_fraction_vs_N_errorbars.png')
plt.savefig(output_plot, dpi=300, bbox_inches='tight')
plt.show()

print(f"\n Receptor fraction vs N (with error bars) saved to:\n{output_plot}")
# Out:
#  Receptor fraction vs N (with error bars) saved to:
# /home/user/Desktop/Anagha/Shin_Colab/Linker_2/No_interaction/receptor_fraction_vs_N_errorbars.png

# %%
root_folders = {
    'No Interaction': '/home/user/Desktop/Anagha/Shin_Colab/Linker_2/No_interaction',
    'ε = 0.5': '/home/user/Desktop/Anagha/Shin_Colab/Linker_2/eps_0.5'
}

plt.figure(figsize=(8, 5))

# --- Loop over each root and plot ---
for label, root_folder in root_folders.items():
    # Get all subfolders like N_1, N_20, N_50 ...
    n_folders = [
        f for f in os.listdir(root_folder)
        if os.path.isdir(os.path.join(root_folder, f)) and re.match(r'^N_\d+$', f)
    ]
    n_folders.sort(key=lambda x: int(x.split('_')[1]))  # Sort numerically by N

    n_values = []
    avg_fractions = []
    std_fractions = []    # standard deviation for error bars

    for n in n_folders:
        if n == "N_1":  
            continue
        folder_path = os.path.join(root_folder, n)
        csv_file = os.path.join(folder_path, 'receptor_radial_density.csv')

        if not os.path.isfile(csv_file):
            print(f"Missing file: {csv_file}")
            continue

        try:
            df = pd.read_csv(csv_file)
        except Exception as e:
            print(f"Error reading {csv_file}: {e}")
            continue

        if 'Fraction' not in df.columns:
            print(f"No 'Fraction' column found in {csv_file}")
            continue

        # Mean and standard deviation
        avg_fraction = df['Fraction'].mean()
        std_fraction = df['Fraction'].std()
        n_value = int(n.split('_')[1])

        n_values.append(n_value)
        avg_fractions.append(avg_fraction)
        std_fractions.append(std_fraction)

    # Plot with error bars
    plt.errorbar(
        n_values, avg_fractions, yerr=std_fractions,
        fmt='o-', capsize=5, linewidth=2, label=label
    )

plt.xlabel('N (Receptor Count)', fontsize=12)
plt.ylabel('Average Fraction of Receptors in Cluster', fontsize=12)
plt.title('Receptor Fraction in Cluster vs N', fontsize=14)
plt.grid(True, alpha=0.3)
plt.legend()
plt.tight_layout()

output_plot = '/home/user/Desktop/Anagha/Shin_Colab/Linker_2/receptor_fraction_vs_N_combined.png'
plt.savefig(output_plot, dpi=300, bbox_inches='tight')
plt.show()

print(f"\n Combined receptor fraction vs N plot saved to:\n{output_plot}")
# Out:
#  Combined receptor fraction vs N plot saved to:
# /home/user/Desktop/Anagha/Shin_Colab/Linker_2/receptor_fraction_vs_N_combined.png

# %%
root_folder = '/home/user/Desktop/Anagha/Shin_Colab/Linker_2/No_interaction'

# Identify subfolders named N_*
n_folders = [f for f in os.listdir(root_folder)
             if os.path.isdir(os.path.join(root_folder, f)) and re.match(r'^N_\d+$', f)]
n_folders.sort(key=lambda x: int(x.split('_')[1]))  # Sort numerically by N value

n_values = []
avg_fractions = []
std_fractions = []  # standard deviation for error bars

for n in n_folders:
    folder_path = os.path.join(root_folder, n)
    csv_file = os.path.join(folder_path, 'polymer_cluster_analysis.csv')https://www.pnas.org/doi/epdf/10.1073/pnas.2017184118

    if not os.path.isfile(csv_file):
        print(f"Missing file: {csv_file}")
        continue

    try:
        df = pd.read_csv(csv_file)
    except Exception as e:
        print(f"Error reading {csv_file}: {e}")
        continue

    if 'Fraction' not in df.columns:
        print(f"No 'Fraction' column found in {csv_file}")
        continue

    # Compute mean and standard deviation of fraction for this N
    avg_fraction = df['Fraction'].mean()
    std_fraction = df['Fraction'].std()
    n_value = int(n.split('_')[1])

    n_values.append(n_value)
    avg_fractions.append(avg_fraction)
    std_fractions.append(std_fraction)

# --- Plot Fraction vs N with error bars ---
plt.figure(figsize=(8, 5))
plt.errorbar(n_values, avg_fractions, yerr=std_fractions, fmt='o-', color='crimson',
             ecolor='black', capsize=5, linewidth=2, label='Polymer Fraction')

plt.xlabel('N (Receptor Count)', fontsize=12)
plt.ylabel('Average Fraction of Polymers in Cluster', fontsize=12)
plt.title('Polymer Fraction in Cluster vs N (No_interaction)', fontsize=14)
plt.grid(True, alpha=0.3)
plt.legend()
plt.tight_layout()

# Save the plot
output_plot = os.path.join(root_folder, 'fraction_vs_N_polymer_errorbars.png')
plt.savefig(output_plot, dpi=300, bbox_inches='tight')
plt.show()

print(f"\n Polymer fraction vs N (with error bars) saved to:\n{output_plot}")
# Out:
#  Polymer fraction vs N (with error bars) saved to:
# /home/user/Desktop/Anagha/Shin_Colab/Linker_2/No_interaction/fraction_vs_N_polymer_errorbars.png

# %%
root_folder = '/home/user/Desktop/Anagha/Shin_Colab/Linker_2/eps_0.5'

# Identify subfolders named N_*
n_folders = [f for f in os.listdir(root_folder)
             if os.path.isdir(os.path.join(root_folder, f)) and re.match(r'^N_\d+$', f)]
n_folders.sort(key=lambda x: int(x.split('_')[1]))  # Sort numerically by N value

n_values = []
avg_fractions = []
std_fractions = []  # standard deviation for error bars

for n in n_folders:
    folder_path = os.path.join(root_folder, n)
    csv_file = os.path.join(folder_path, 'polymer_cluster_analysis.csv')

    if not os.path.isfile(csv_file):
        print(f"Missing file: {csv_file}")
        continue

    try:
        df = pd.read_csv(csv_file)
    except Exception as e:
        print(f"Error reading {csv_file}: {e}")
        continue

    if 'Fraction' not in df.columns:
        print(f"No 'Fraction' column found in {csv_file}")
        continue

    # Compute mean and standard deviation of fraction for this N
    avg_fraction = df['Fraction'].mean()
    std_fraction = df['Fraction'].std()
    n_value = int(n.split('_')[1])

    n_values.append(n_value)
    avg_fractions.append(avg_fraction)
    std_fractions.append(std_fraction)

# --- Plot Fraction vs N with error bars ---
plt.figure(figsize=(8, 5))
plt.errorbar(n_values, avg_fractions, yerr=std_fractions, fmt='o-', color='crimson',
             ecolor='black', capsize=5, linewidth=2, label='Polymer Fraction')

plt.xlabel('N (Receptor Count)', fontsize=12)
plt.ylabel('Average Fraction of Polymers in Cluster', fontsize=12)
plt.title('Polymer Fraction in Cluster vs N (eps_0.5)', fontsize=14)
plt.grid(True, alpha=0.3)
plt.legend()
plt.tight_layout()

# Save the plot
output_plot = os.path.join(root_folder, 'fraction_vs_N_polymer_errorbars.png')
plt.savefig(output_plot, dpi=300, bbox_inches='tight')
plt.show()

print(f"\n Polymer fraction vs N (with error bars) saved to:\n{output_plot}")
# Out:
#  Polymer fraction vs N (with error bars) saved to:
# /home/user/Desktop/Anagha/Shin_Colab/Linker_2/eps_0.5/fraction_vs_N_polymer_errorbars.png

# %%
root_folders = {
    'No Interaction': '/home/user/Desktop/Anagha/Shin_Colab/Linker_2/No_interaction',
    'ε = 0.5': '/home/user/Desktop/Anagha/Shin_Colab/Linker_2/eps_0.5'
}

plt.figure(figsize=(8, 5))

# --- Loop over each root and plot ---
for label, root_folder in root_folders.items():
    # Identify subfolders like N_1, N_20, etc.
    n_folders = [
        f for f in os.listdir(root_folder)
        if os.path.isdir(os.path.join(root_folder, f)) and re.match(r'^N_\d+$', f)
    ]
    n_folders.sort(key=lambda x: int(x.split('_')[1]))  # Sort numerically

    n_values = []
    avg_fractions = []
    std_fractions = []

    for n in n_folders:
        if n == "N_1":  # Skip N_1
            continue

        folder_path = os.path.join(root_folder, n)
        csv_file = os.path.join(folder_path, 'polymer_cluster_analysis.csv')

        if not os.path.isfile(csv_file):
            print(f"Missing file: {csv_file}")
            continue

        try:
            df = pd.read_csv(csv_file)
        except Exception as e:
            print(f"Error reading {csv_file}: {e}")
            continue

        if 'Fraction' not in df.columns:
            print(f"No 'Fraction' column found in {csv_file}")
            continue

        # Compute mean and std for this N
        avg_fraction = df['Fraction'].mean()
        std_fraction = df['Fraction'].std()
        n_value = int(n.split('_')[1])

        n_values.append(n_value)
        avg_fractions.append(avg_fraction)
        std_fractions.append(std_fraction)

    # Plot each dataset with error bars
    plt.errorbar(
        n_values, avg_fractions, yerr=std_fractions,
        fmt='o-', capsize=5, linewidth=2, label=label
    )

plt.xlabel('N (Receptor Count)', fontsize=12)
plt.ylabel('Average Fraction of Polymers in Cluster', fontsize=12)
plt.title('Polymer Fraction in Cluster vs N', fontsize=14)
plt.grid(True, alpha=0.3)
plt.legend()
plt.tight_layout()

output_plot = '/home/user/Desktop/Anagha/Shin_Colab/Linker_2/polymer_fraction_vs_N_combined.png'
plt.savefig(output_plot, dpi=300, bbox_inches='tight')
plt.show()

print(f"\nCombined polymer fraction vs N plot saved to:\n{output_plot}")
# Out:
# Combined polymer fraction vs N plot saved to:
# /home/user/Desktop/Anagha/Shin_Colab/Linker_2/polymer_fraction_vs_N_combined.png
