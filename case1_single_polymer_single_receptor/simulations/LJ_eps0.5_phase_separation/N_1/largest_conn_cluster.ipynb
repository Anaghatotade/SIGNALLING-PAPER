# %%
import MDAnalysis as mda
import numpy as np
import re
import matplotlib.pyplot as plt
import pandas as pd
from MDAnalysis.lib.nsgrid import FastNS
from MDAnalysis.lib import mdamath 
from collections import defaultdict
from scipy.spatial import cKDTree
import math
import os
import matplotlib.pyplot as plt

lammps_data = '/home/user/Desktop/Anagha/Shin_Colab/Linker_2/eps_0.5/N_1/lammps.data'
trajectory_file = '/home/user/Desktop/Anagha/Shin_Colab/Linker_2/eps_0.5/N_1/traj.lammpstrj'
u = mda.Universe(lammps_data, trajectory_file, format='LAMMPSDUMP')
# Out:
# /home/user/anaconda3/lib/python3.12/site-packages/MDAnalysis/coordinates/LAMMPS.py:749: UserWarning: Reader has no dt information, set to 1.0 ps
#   ts.data["time"] = step_num * ts.dt

# %%
total_chains = 650              # Set to actual polymer chain count in your system
polymer_type = 1                # Atom type for polymer
receptor_type = 2               # Atom type for receptor

num_bins = 50
max_distance = 50               # Maximum distance sphere radius (Angstrom)
bins = np.linspace(0, max_distance, num_bins + 1)
bin_centers = 0.5 * (bins[:-1] + bins[1:])

z_slab = 115.0                  # z where slab starts t(set for your system)
buffer = 0.0   
# Slab region definition
x_min, x_max = -30, 30
y_min, y_max = -30, 30
z_min, z_max = 32.2, 34.# Optionally set >0 to avoid near-boundary artifacts

# %%
def any_common_elements(list1, list2):
    set1 = set(list1)
    for element in set1:
        if element in list2:
            return True
    return False

def partner_array(resid_interest, cutoff, universe):
    array_partner = [resid_interest]
    atom_list = universe.select_atoms(f"around {cutoff:.2f} (resid {resid_interest})")
    for atom in atom_list:
        array_partner.append(atom.resid)
    return list(set(array_partner))

def max_clu(u, total_chains):
    partners_list = [partner_array(ele, 3.0, u) for ele in range(1, total_chains + 1)]
    max_length, max_list = 0, []
    for lst in partners_list:
        if len(lst) > max_length:
            max_length = len(lst)
            max_list = lst
    chain_in_cluster = max_list
    for chains in range(total_chains):
        if any_common_elements(chain_in_cluster, partners_list[chains]):
            chain_in_cluster += partners_list[chains]
            chain_in_cluster = list(set(chain_in_cluster))
    return chain_in_cluster

def is_chain_inside_box(chain, box, buffer=0.):
    for atom in chain.atoms:
        x, y, z = atom.position
        if not (buffer < x < box[0] - buffer and buffer < y < box[1] - buffer and buffer < z < box[2] - buffer):
            return False
    return True

# %%
output_csv = '/home/user/Desktop/Anagha/Shin_Colab/Linker_2/eps_0.5/N_1/polymer_cluster_analysis_sphere.csv'
output_table_csv = '/home/user/Desktop/Anagha/Shin_Colab/Linker_2/eps_0.5/N_1/polymer_radial_density_table_sphere.csv'
output_plot = '/home/user/Desktop/Anagha/Shin_Colab/Linker_2/eps_0.5/N_1/radialdensity_polymer_sphere.png'

from MDAnalysis.lib.distances import distance_array

polymer_type = 1
cutoff = 2.5
bin_width = 1.0
max_radius = 30 * math.sqrt(3)

polymers = u.select_atoms(f"type {polymer_type}")

#polymer = fragment
fragments = polymers.fragments
n_polymers = len(fragments)

print(f"Total polymers (fragments): {n_polymers}")

class UnionFind:
    def __init__(self, n):
        self.parent = list(range(n))
        self.rank = [0]*n

    def find(self, x):
        if self.parent[x] != x:
            self.parent[x] = self.find(self.parent[x])
        return self.parent[x]

    def union(self, a, b):
        ra, rb = self.find(a), self.find(b)
        if ra == rb:
            return
        if self.rank[ra] < self.rank[rb]:
            self.parent[ra] = rb
        else:
            self.parent[rb] = ra
            if self.rank[ra] == self.rank[rb]:
                self.rank[ra] += 1

bins = np.arange(0, max_radius + bin_width, bin_width)
V_r = [(4/3) * np.pi * r**3 for r in bins]
shell_volumes = np.array([V_r[i+1] - V_r[i] for i in range(len(V_r)-1)])
bin_centers = 0.5 * (bins[:-1] + bins[1:])

radial_density_cluster = np.zeros(len(shell_volumes))
radial_density_all = np.zeros(len(shell_volumes))
results = []


for ts in u.trajectory[250:399]:

    polymers.wrap(compound='fragments')

    uf = UnionFind(n_polymers)

#polymer polymer neighbor check
    for i in range(n_polymers):
        frag_i = fragments[i]
        for j in range(i+1, n_polymers):
            frag_j = fragments[j]

            dists = distance_array(
                frag_i.positions,
                frag_j.positions,
                box=ts.dimensions
            )

            if np.any(dists <= cutoff):
                uf.union(i, j)

    #Build clusters
    groups = defaultdict(list)
    for i in range(n_polymers):
        groups[uf.find(i)].append(i)

    largest_cluster_polymers = max(groups.values(), key=len)
    largest_cluster_size = len(largest_cluster_polymers)
    fraction = largest_cluster_size / n_polymers

    print(f"Frame {ts.frame}: Largest cluster = {largest_cluster_size} polymers, fraction = {fraction:.3f}")
    results.append([ts.frame, largest_cluster_size, fraction])

    largest_cluster_atoms = mda.AtomGroup(
        np.concatenate([fragments[i].indices for i in largest_cluster_polymers]),
        u
    )

    #cluster
    ref_com_cluster = largest_cluster_atoms.center_of_mass()
    distances_cluster = np.linalg.norm(
        largest_cluster_atoms.positions - ref_com_cluster,
        axis=1
    )
    hist_cluster, _ = np.histogram(distances_cluster, bins=bins)
    radial_density_cluster += hist_cluster

    # all polymers
    ref_com_all = polymers.center_of_mass()
    distances_all = np.linalg.norm(
        polymers.positions - ref_com_all,
        axis=1
    )
    hist_all, _ = np.histogram(distances_all, bins=bins)
    radial_density_all += hist_all

df = pd.DataFrame(results, columns=["Frame", "LargestClusterSize", "Fraction"])
df.to_csv(output_csv, index=False)

n_frames = len(range(0, 399))
radial_density_cluster /= (n_frames * shell_volumes)
radial_density_all /= (n_frames * shell_volumes)

density_df = pd.DataFrame({
    "Radius(Å)": bin_centers,
    "ClusterDensity(atoms/Å³)": radial_density_cluster,
    "AllPolymerDensity(atoms/Å³)": radial_density_all
})
density_df.to_csv(output_table_csv, index=False)

plt.figure(figsize=(8,6))
plt.plot(bin_centers, radial_density_cluster, label="Largest Polymer Cluster", color='r')
plt.plot(bin_centers, radial_density_all, label="All Polymers", color='b', linestyle='--')
plt.xlabel("Radius (Å)", fontsize=12)
plt.ylabel("Density (atoms/Å³)", fontsize=12)
plt.title("Radial Density Profile (Polymer-Level Clustering)", fontsize=13)
plt.legend()
plt.tight_layout()
plt.savefig(output_plot, dpi=300, bbox_inches='tight')
plt.show()
# Out:
# Total polymers (fragments): 650
# Frame 250: Largest cluster = 625 polymers, fraction = 0.962
# Frame 251: Largest cluster = 627 polymers, fraction = 0.965
# Frame 252: Largest cluster = 615 polymers, fraction = 0.946
# Frame 253: Largest cluster = 626 polymers, fraction = 0.963
# Frame 254: Largest cluster = 618 polymers, fraction = 0.951
# Frame 255: Largest cluster = 622 polymers, fraction = 0.957
# Frame 256: Largest cluster = 624 polymers, fraction = 0.960
# Frame 257: Largest cluster = 632 polymers, fraction = 0.972
# Frame 258: Largest cluster = 617 polymers, fraction = 0.949
# Frame 259: Largest cluster = 614 polymers, fraction = 0.945
# Frame 260: Largest cluster = 617 polymers, fraction = 0.949
# Frame 261: Largest cluster = 626 polymers, fraction = 0.963
# Frame 262: Largest cluster = 620 polymers, fraction = 0.954
# Frame 263: Largest cluster = 624 polymers, fraction = 0.960
# Frame 264: Largest cluster = 629 polymers, fraction = 0.968
# Frame 265: Largest cluster = 633 polymers, fraction = 0.974
# Frame 266: Largest cluster = 615 polymers, fraction = 0.946
# Frame 267: Largest cluster = 628 polymers, fraction = 0.966
# Frame 268: Largest cluster = 612 polymers, fraction = 0.942
# Frame 269: Largest cluster = 627 polymers, fraction = 0.965
# Frame 270: Largest cluster = 627 polymers, fraction = 0.965
# Frame 271: Largest cluster = 620 polymers, fraction = 0.954
# Frame 272: Largest cluster = 624 polymers, fraction = 0.960
# Frame 273: Largest cluster = 631 polymers, fraction = 0.971
# Frame 274: Largest cluster = 625 polymers, fraction = 0.962
# Frame 275: Largest cluster = 620 polymers, fraction = 0.954
# Frame 276: Largest cluster = 614 polymers, fraction = 0.945
# Frame 277: Largest cluster = 628 polymers, fraction = 0.966
# Frame 278: Largest cluster = 626 polymers, fraction = 0.963
# Frame 279: Largest cluster = 611 polymers, fraction = 0.940
# Frame 280: Largest cluster = 607 polymers, fraction = 0.934
# Frame 281: Largest cluster = 614 polymers, fraction = 0.945
# Frame 282: Largest cluster = 623 polymers, fraction = 0.958
# Frame 283: Largest cluster = 625 polymers, fraction = 0.962
# Frame 284: Largest cluster = 618 polymers, fraction = 0.951
# Frame 285: Largest cluster = 630 polymers, fraction = 0.969
# Frame 286: Largest cluster = 621 polymers, fraction = 0.955
# Frame 287: Largest cluster = 625 polymers, fraction = 0.962
# Frame 288: Largest cluster = 630 polymers, fraction = 0.969
# Frame 289: Largest cluster = 624 polymers, fraction = 0.960
# Frame 290: Largest cluster = 628 polymers, fraction = 0.966
# Frame 291: Largest cluster = 631 polymers, fraction = 0.971
# Frame 292: Largest cluster = 626 polymers, fraction = 0.963
# Frame 293: Largest cluster = 632 polymers, fraction = 0.972
# Frame 294: Largest cluster = 626 polymers, fraction = 0.963
# Frame 295: Largest cluster = 619 polymers, fraction = 0.952
# Frame 296: Largest cluster = 623 polymers, fraction = 0.958
# Frame 297: Largest cluster = 626 polymers, fraction = 0.963
# Frame 298: Largest cluster = 632 polymers, fraction = 0.972
# Frame 299: Largest cluster = 628 polymers, fraction = 0.966
# Frame 300: Largest cluster = 625 polymers, fraction = 0.962
# Frame 301: Largest cluster = 624 polymers, fraction = 0.960
# Frame 302: Largest cluster = 626 polymers, fraction = 0.963
# Frame 303: Largest cluster = 630 polymers, fraction = 0.969
# Frame 304: Largest cluster = 615 polymers, fraction = 0.946
# Frame 305: Largest cluster = 620 polymers, fraction = 0.954
# Frame 306: Largest cluster = 622 polymers, fraction = 0.957
# Frame 307: Largest cluster = 628 polymers, fraction = 0.966
# Frame 308: Largest cluster = 621 polymers, fraction = 0.955
# Frame 309: Largest cluster = 618 polymers, fraction = 0.951
# Frame 310: Largest cluster = 618 polymers, fraction = 0.951
# Frame 311: Largest cluster = 621 polymers, fraction = 0.955
# Frame 312: Largest cluster = 632 polymers, fraction = 0.972
# Frame 313: Largest cluster = 634 polymers, fraction = 0.975
# Frame 314: Largest cluster = 628 polymers, fraction = 0.966
# Frame 315: Largest cluster = 613 polymers, fraction = 0.943
# Frame 316: Largest cluster = 616 polymers, fraction = 0.948
# Frame 317: Largest cluster = 624 polymers, fraction = 0.960
# Frame 318: Largest cluster = 630 polymers, fraction = 0.969
# Frame 319: Largest cluster = 622 polymers, fraction = 0.957
# Frame 320: Largest cluster = 627 polymers, fraction = 0.965
# Frame 321: Largest cluster = 616 polymers, fraction = 0.948
# Frame 322: Largest cluster = 628 polymers, fraction = 0.966
# Frame 323: Largest cluster = 622 polymers, fraction = 0.957
# Frame 324: Largest cluster = 627 polymers, fraction = 0.965
# Frame 325: Largest cluster = 613 polymers, fraction = 0.943
# Frame 326: Largest cluster = 624 polymers, fraction = 0.960
# Frame 327: Largest cluster = 628 polymers, fraction = 0.966
# Frame 328: Largest cluster = 628 polymers, fraction = 0.966
# Frame 329: Largest cluster = 624 polymers, fraction = 0.960
# Frame 330: Largest cluster = 622 polymers, fraction = 0.957
# Frame 331: Largest cluster = 621 polymers, fraction = 0.955
# Frame 332: Largest cluster = 615 polymers, fraction = 0.946
# Frame 333: Largest cluster = 616 polymers, fraction = 0.948
# Frame 334: Largest cluster = 626 polymers, fraction = 0.963
# Frame 335: Largest cluster = 634 polymers, fraction = 0.975
# Frame 336: Largest cluster = 626 polymers, fraction = 0.963
# Frame 337: Largest cluster = 627 polymers, fraction = 0.965
# Frame 338: Largest cluster = 629 polymers, fraction = 0.968
# Frame 339: Largest cluster = 615 polymers, fraction = 0.946
# Frame 340: Largest cluster = 626 polymers, fraction = 0.963
# Frame 341: Largest cluster = 632 polymers, fraction = 0.972
# Frame 342: Largest cluster = 628 polymers, fraction = 0.966
# Frame 343: Largest cluster = 628 polymers, fraction = 0.966
# Frame 344: Largest cluster = 621 polymers, fraction = 0.955
# Frame 345: Largest cluster = 621 polymers, fraction = 0.955
# Frame 346: Largest cluster = 627 polymers, fraction = 0.965
# Frame 347: Largest cluster = 627 polymers, fraction = 0.965
# Frame 348: Largest cluster = 628 polymers, fraction = 0.966
# Frame 349: Largest cluster = 623 polymers, fraction = 0.958
# Frame 350: Largest cluster = 634 polymers, fraction = 0.975
# Frame 351: Largest cluster = 633 polymers, fraction = 0.974
# Frame 352: Largest cluster = 629 polymers, fraction = 0.968
# Frame 353: Largest cluster = 623 polymers, fraction = 0.958
# Frame 354: Largest cluster = 622 polymers, fraction = 0.957
# Frame 355: Largest cluster = 619 polymers, fraction = 0.952
# Frame 356: Largest cluster = 629 polymers, fraction = 0.968
# Frame 357: Largest cluster = 629 polymers, fraction = 0.968
# Frame 358: Largest cluster = 635 polymers, fraction = 0.977
# Frame 359: Largest cluster = 626 polymers, fraction = 0.963
# Frame 360: Largest cluster = 623 polymers, fraction = 0.958
# Frame 361: Largest cluster = 630 polymers, fraction = 0.969
# Frame 362: Largest cluster = 627 polymers, fraction = 0.965
# Frame 363: Largest cluster = 622 polymers, fraction = 0.957
# Frame 364: Largest cluster = 629 polymers, fraction = 0.968
# Frame 365: Largest cluster = 624 polymers, fraction = 0.960
# Frame 366: Largest cluster = 617 polymers, fraction = 0.949
# Frame 367: Largest cluster = 621 polymers, fraction = 0.955
# Frame 368: Largest cluster = 628 polymers, fraction = 0.966
# Frame 369: Largest cluster = 609 polymers, fraction = 0.937
# Frame 370: Largest cluster = 616 polymers, fraction = 0.948
# Frame 371: Largest cluster = 611 polymers, fraction = 0.940
# Frame 372: Largest cluster = 619 polymers, fraction = 0.952
# Frame 373: Largest cluster = 622 polymers, fraction = 0.957
# Frame 374: Largest cluster = 623 polymers, fraction = 0.958
# Frame 375: Largest cluster = 623 polymers, fraction = 0.958
# Frame 376: Largest cluster = 634 polymers, fraction = 0.975
# Frame 377: Largest cluster = 637 polymers, fraction = 0.980
# Frame 378: Largest cluster = 632 polymers, fraction = 0.972
# Frame 379: Largest cluster = 634 polymers, fraction = 0.975
# Frame 380: Largest cluster = 622 polymers, fraction = 0.957
# Frame 381: Largest cluster = 619 polymers, fraction = 0.952
# Frame 382: Largest cluster = 623 polymers, fraction = 0.958
# Frame 383: Largest cluster = 627 polymers, fraction = 0.965
# Frame 384: Largest cluster = 630 polymers, fraction = 0.969
# Frame 385: Largest cluster = 617 polymers, fraction = 0.949
# Frame 386: Largest cluster = 622 polymers, fraction = 0.957
# Frame 387: Largest cluster = 616 polymers, fraction = 0.948
# Frame 388: Largest cluster = 630 polymers, fraction = 0.969
# Frame 389: Largest cluster = 635 polymers, fraction = 0.977
# Frame 390: Largest cluster = 627 polymers, fraction = 0.965
# Frame 391: Largest cluster = 628 polymers, fraction = 0.966
# Frame 392: Largest cluster = 631 polymers, fraction = 0.971
# Frame 393: Largest cluster = 626 polymers, fraction = 0.963
# Frame 394: Largest cluster = 626 polymers, fraction = 0.963
# Frame 395: Largest cluster = 623 polymers, fraction = 0.958
# Frame 396: Largest cluster = 631 polymers, fraction = 0.971
# Frame 397: Largest cluster = 627 polymers, fraction = 0.965
# Frame 398: Largest cluster = 635 polymers, fraction = 0.977

# %%
output_csv = '/home/user/Desktop/Anagha/Shin_Colab/Linker_2/eps_0.5/N_1/polymer_cluster_analysis_sphere.csv'
output_table_csv = '/home/user/Desktop/Anagha/Shin_Colab/Linker_2/eps_0.5/N_1/polymer_radial_density_table_sphere.csv'
output_plot = '/home/user/Desktop/Anagha/Shin_Colab/Linker_2/eps_0.5/N_1/radialdensity_polymer_sphere.png'

polymer_type = 1
cutoff = 2.5
bin_width = 1.0

polymers = u.select_atoms(f"type {polymer_type}")
total_polymers = len(polymers)

class UnionFind:
    def __init__(self, n):
        self.parent = list(range(n))
        self.rank = [0]*n

    def find(self, x):
        while self.parent[x] != x:
            self.parent[x] = self.parent[self.parent[x]]
            x = self.parent[x]
        return x

    def union(self, a, b):
        ra, rb = self.find(a), self.find(b)
        if ra == rb:
            return
        if self.rank[ra] < self.rank[rb]:
            self.parent[ra] = rb
        else:
            self.parent[rb] = ra
            if self.rank[ra] == self.rank[rb]:
                self.rank[ra] += 1

def get_cell_index(pos, cell_size):
    return tuple((pos // cell_size).astype(int))

max_radius = 30 * math.sqrt(3)
bins = np.arange(0, max_radius + bin_width, bin_width)

V_r = [(4/3)*math.pi*r**3 for r in bins]
shell_volumes = np.array([V_r[i+1] - V_r[i] for i in range(len(V_r)-1)])
bin_centers = 0.5 * (bins[:-1] + bins[1:])

radial_density_cluster = np.zeros(len(shell_volumes))
radial_density_all = np.zeros(len(shell_volumes))

results = []


for ts in u.trajectory[0:399]:

    polymers.wrap(compound='fragments')
    positions = polymers.positions
    box = ts.dimensions[:3]

    cell_size = cutoff
    ncell = (box / cell_size).astype(int)

    cell_dict = defaultdict(list)
    for i, pos in enumerate(positions):
        cell = get_cell_index(pos, cell_size)
        cell_dict[cell].append(i)

    neighbor_offsets = [(dx,dy,dz) 
                        for dx in [-1,0,1]
                        for dy in [-1,0,1]
                        for dz in [-1,0,1]]

    pairs = set()
    
    for cell, atom_ids in cell_dict.items():
        for dx,dy,dz in neighbor_offsets:
            neigh = ((cell[0]+dx) % ncell[0],
                     (cell[1]+dy) % ncell[1],
                     (cell[2]+dz) % ncell[2])
    
            for i in atom_ids:
                for j in cell_dict.get(neigh, []):
                    if i == j:
                        continue
    
                    a, b = min(i, j), max(i, j)
    
                    dx = positions[a][0] - positions[b][0]
                    dy = positions[a][1] - positions[b][1]
                    dz = positions[a][2] - positions[b][2]
    
                    dx -= box[0] * round(dx / box[0])
                    dy -= box[1] * round(dy / box[1])
                    dz -= box[2] * round(dz / box[2])
    
                    if dx*dx + dy*dy + dz*dz <= cutoff*cutoff:
                        pairs.add((a, b))


    # Cluster detection 
    uf = UnionFind(total_polymers)
    for i, j in pairs:
        uf.union(i, j)

    groups = defaultdict(list)
    for i in range(total_polymers):
        groups[uf.find(i)].append(i)

    largest_cluster = max(groups.values(), key=len)
    fraction = len(largest_cluster) / total_polymers

    print(f"Frame {ts.frame}: Largest cluster = {len(largest_cluster)} | Fraction = {fraction:.3f}")
    results.append([ts.frame, len(largest_cluster), fraction])


    cluster_positions = positions[largest_cluster]
    ref_com_cluster = cluster_positions.mean(axis=0)

    hist_cluster = np.zeros(len(bins)-1)
    for pos in cluster_positions:
        dx = pos[0] - ref_com_cluster[0]
        dy = pos[1] - ref_com_cluster[1]
        dz = pos[2] - ref_com_cluster[2]
        r = math.sqrt(dx*dx + dy*dy + dz*dz)

        bin_id = int(r // bin_width)
        if bin_id < len(hist_cluster):
            hist_cluster[bin_id] += 1

    radial_density_cluster += hist_cluster

    # ---- All polymers ----
    ref_com_all = polymers.center_of_mass()
    hist_all = np.zeros(len(bins)-1)

    for pos in positions:
        dx = pos[0] - ref_com_all[0]
        dy = pos[1] - ref_com_all[1]
        dz = pos[2] - ref_com_all[2]
        r = math.sqrt(dx*dx + dy*dy + dz*dz)

        bin_id = int(r // bin_width)
        if bin_id < len(hist_all):
            hist_all[bin_id] += 1

    radial_density_all += hist_all

df = pd.DataFrame(results, columns=["Frame", "LargestClusterSize", "Fraction"])
df.to_csv(output_csv, index=False)

n_frames = len(range(0,399))
radial_density_cluster /= (n_frames * shell_volumes)
radial_density_all /= (n_frames * shell_volumes)

density_df = pd.DataFrame({
    "Radius(Å)": bin_centers,
    "ClusterDensity(atoms/Å³)": radial_density_cluster,
    "AllPolymerDensity(atoms/Å³)": radial_density_all
})
density_df.to_csv(output_table_csv, index=False)

plt.figure(figsize=(8,6))
plt.plot(bin_centers, radial_density_cluster, label="Largest Polymer Cluster")
plt.plot(bin_centers, radial_density_all, '--', label="All Polymers")
plt.xlabel("Radius (Å)")
plt.ylabel("Density (atoms/Å³)")
plt.title("Radial Density Profile (Manual Distance)")
plt.legend()
plt.tight_layout()
plt.savefig(output_plot, dpi=300)
plt.show()
# Out:
# Frame 0: Largest cluster = 16250 | Fraction = 1.000
# Frame 1: Largest cluster = 16175 | Fraction = 0.995
# Frame 2: Largest cluster = 15850 | Fraction = 0.975
# Frame 3: Largest cluster = 15800 | Fraction = 0.972
# Frame 4: Largest cluster = 15575 | Fraction = 0.958
# Frame 5: Largest cluster = 15575 | Fraction = 0.958
# Frame 6: Largest cluster = 15650 | Fraction = 0.963
# Frame 7: Largest cluster = 15650 | Fraction = 0.963
# Frame 8: Largest cluster = 15550 | Fraction = 0.957
# Frame 9: Largest cluster = 15625 | Fraction = 0.962
# Frame 10: Largest cluster = 15675 | Fraction = 0.965
# Frame 11: Largest cluster = 15350 | Fraction = 0.945
# Frame 12: Largest cluster = 15175 | Fraction = 0.934
# Frame 13: Largest cluster = 15625 | Fraction = 0.962
# Frame 14: Largest cluster = 15600 | Fraction = 0.960
# Frame 15: Largest cluster = 15650 | Fraction = 0.963
# Frame 16: Largest cluster = 15750 | Fraction = 0.969
# Frame 17: Largest cluster = 15600 | Fraction = 0.960
# Frame 18: Largest cluster = 15725 | Fraction = 0.968
# Frame 19: Largest cluster = 15625 | Fraction = 0.962
# Frame 20: Largest cluster = 15675 | Fraction = 0.965
# Frame 21: Largest cluster = 15700 | Fraction = 0.966
# Frame 22: Largest cluster = 15725 | Fraction = 0.968
# Frame 23: Largest cluster = 15725 | Fraction = 0.968
# Frame 24: Largest cluster = 15625 | Fraction = 0.962
# Frame 25: Largest cluster = 15500 | Fraction = 0.954
# Frame 26: Largest cluster = 15850 | Fraction = 0.975
# Frame 27: Largest cluster = 15725 | Fraction = 0.968
# Frame 28: Largest cluster = 15650 | Fraction = 0.963
# Frame 29: Largest cluster = 15500 | Fraction = 0.954
# Frame 30: Largest cluster = 15625 | Fraction = 0.962
# Frame 31: Largest cluster = 15825 | Fraction = 0.974
# Frame 32: Largest cluster = 15950 | Fraction = 0.982
# Frame 33: Largest cluster = 15650 | Fraction = 0.963
# Frame 34: Largest cluster = 15700 | Fraction = 0.966
# Frame 35: Largest cluster = 15700 | Fraction = 0.966
# Frame 36: Largest cluster = 15700 | Fraction = 0.966
# Frame 37: Largest cluster = 15675 | Fraction = 0.965
# Frame 38: Largest cluster = 15600 | Fraction = 0.960
# Frame 39: Largest cluster = 15625 | Fraction = 0.962
# Frame 40: Largest cluster = 15700 | Fraction = 0.966
# Frame 41: Largest cluster = 15800 | Fraction = 0.972
# Frame 42: Largest cluster = 15900 | Fraction = 0.978
# Frame 43: Largest cluster = 15900 | Fraction = 0.978
# Frame 44: Largest cluster = 15675 | Fraction = 0.965
# Frame 45: Largest cluster = 15700 | Fraction = 0.966
# Frame 46: Largest cluster = 15500 | Fraction = 0.954
# Frame 47: Largest cluster = 15825 | Fraction = 0.974
# Frame 48: Largest cluster = 15700 | Fraction = 0.966
# Frame 49: Largest cluster = 15725 | Fraction = 0.968
# Frame 50: Largest cluster = 15875 | Fraction = 0.977
# Frame 51: Largest cluster = 15450 | Fraction = 0.951
# Frame 52: Largest cluster = 15600 | Fraction = 0.960
# Frame 53: Largest cluster = 15875 | Fraction = 0.977
# Frame 54: Largest cluster = 15625 | Fraction = 0.962
# Frame 55: Largest cluster = 15725 | Fraction = 0.968
# Frame 56: Largest cluster = 15600 | Fraction = 0.960
# Frame 57: Largest cluster = 15850 | Fraction = 0.975
# Frame 58: Largest cluster = 15800 | Fraction = 0.972
# Frame 59: Largest cluster = 15825 | Fraction = 0.974
# Frame 60: Largest cluster = 15775 | Fraction = 0.971
# Frame 61: Largest cluster = 15650 | Fraction = 0.963
# Frame 62: Largest cluster = 15800 | Fraction = 0.972
# Frame 63: Largest cluster = 15850 | Fraction = 0.975
# Frame 64: Largest cluster = 15650 | Fraction = 0.963
# Frame 65: Largest cluster = 15800 | Fraction = 0.972
# Frame 66: Largest cluster = 15675 | Fraction = 0.965
# Frame 67: Largest cluster = 15650 | Fraction = 0.963
# Frame 68: Largest cluster = 15350 | Fraction = 0.945
# Frame 69: Largest cluster = 15375 | Fraction = 0.946
# Frame 70: Largest cluster = 15675 | Fraction = 0.965
# Frame 71: Largest cluster = 15750 | Fraction = 0.969
# Frame 72: Largest cluster = 15600 | Fraction = 0.960
# Frame 73: Largest cluster = 15800 | Fraction = 0.972
# Frame 74: Largest cluster = 15700 | Fraction = 0.966
# Frame 75: Largest cluster = 15575 | Fraction = 0.958
# Frame 76: Largest cluster = 15550 | Fraction = 0.957
# Frame 77: Largest cluster = 15650 | Fraction = 0.963
# Frame 78: Largest cluster = 15400 | Fraction = 0.948
# Frame 79: Largest cluster = 15600 | Fraction = 0.960
# Frame 80: Largest cluster = 15500 | Fraction = 0.954
# Frame 81: Largest cluster = 15775 | Fraction = 0.971
# Frame 82: Largest cluster = 15750 | Fraction = 0.969
# Frame 83: Largest cluster = 15775 | Fraction = 0.971
# Frame 84: Largest cluster = 15500 | Fraction = 0.954
# Frame 85: Largest cluster = 15650 | Fraction = 0.963
# Frame 86: Largest cluster = 15625 | Fraction = 0.962
# Frame 87: Largest cluster = 15650 | Fraction = 0.963
# Frame 88: Largest cluster = 15550 | Fraction = 0.957
# Frame 89: Largest cluster = 15375 | Fraction = 0.946
# Frame 90: Largest cluster = 15550 | Fraction = 0.957
# Frame 91: Largest cluster = 15725 | Fraction = 0.968
# Frame 92: Largest cluster = 15700 | Fraction = 0.966
# Frame 93: Largest cluster = 15700 | Fraction = 0.966
# Frame 94: Largest cluster = 15625 | Fraction = 0.962
# Frame 95: Largest cluster = 15650 | Fraction = 0.963
# Frame 96: Largest cluster = 15875 | Fraction = 0.977
# Frame 97: Largest cluster = 15900 | Fraction = 0.978
# Frame 98: Largest cluster = 15475 | Fraction = 0.952
# Frame 99: Largest cluster = 15650 | Fraction = 0.963
# Frame 100: Largest cluster = 15675 | Fraction = 0.965
# Frame 101: Largest cluster = 15825 | Fraction = 0.974
# Frame 102: Largest cluster = 15875 | Fraction = 0.977
# Frame 103: Largest cluster = 15775 | Fraction = 0.971
# Frame 104: Largest cluster = 15700 | Fraction = 0.966
# Frame 105: Largest cluster = 15550 | Fraction = 0.957
# Frame 106: Largest cluster = 15650 | Fraction = 0.963
# Frame 107: Largest cluster = 15875 | Fraction = 0.977
# Frame 108: Largest cluster = 15725 | Fraction = 0.968
# Frame 109: Largest cluster = 15575 | Fraction = 0.958
# Frame 110: Largest cluster = 15775 | Fraction = 0.971
# Frame 111: Largest cluster = 15625 | Fraction = 0.962
# Frame 112: Largest cluster = 15700 | Fraction = 0.966
# Frame 113: Largest cluster = 15600 | Fraction = 0.960
# Frame 114: Largest cluster = 15725 | Fraction = 0.968
# Frame 115: Largest cluster = 15625 | Fraction = 0.962
# Frame 116: Largest cluster = 15700 | Fraction = 0.966
# Frame 117: Largest cluster = 15625 | Fraction = 0.962
# Frame 118: Largest cluster = 15575 | Fraction = 0.958
# Frame 119: Largest cluster = 15675 | Fraction = 0.965
# Frame 120: Largest cluster = 15750 | Fraction = 0.969
# Frame 121: Largest cluster = 15775 | Fraction = 0.971
# Frame 122: Largest cluster = 15750 | Fraction = 0.969
# Frame 123: Largest cluster = 15650 | Fraction = 0.963
# Frame 124: Largest cluster = 15800 | Fraction = 0.972
# Frame 125: Largest cluster = 15600 | Fraction = 0.960
# Frame 126: Largest cluster = 15725 | Fraction = 0.968
# Frame 127: Largest cluster = 15650 | Fraction = 0.963
# Frame 128: Largest cluster = 15825 | Fraction = 0.974
# Frame 129: Largest cluster = 15900 | Fraction = 0.978
# Frame 130: Largest cluster = 15525 | Fraction = 0.955
# Frame 131: Largest cluster = 15575 | Fraction = 0.958
# Frame 132: Largest cluster = 15600 | Fraction = 0.960
# Frame 133: Largest cluster = 15525 | Fraction = 0.955
# Frame 134: Largest cluster = 15525 | Fraction = 0.955
# Frame 135: Largest cluster = 15175 | Fraction = 0.934
# Frame 136: Largest cluster = 15600 | Fraction = 0.960
# Frame 137: Largest cluster = 15600 | Fraction = 0.960
# Frame 138: Largest cluster = 15525 | Fraction = 0.955
# Frame 139: Largest cluster = 15700 | Fraction = 0.966
# Frame 140: Largest cluster = 15750 | Fraction = 0.969
# Frame 141: Largest cluster = 15675 | Fraction = 0.965
# Frame 142: Largest cluster = 15450 | Fraction = 0.951
# Frame 143: Largest cluster = 15900 | Fraction = 0.978
# Frame 144: Largest cluster = 15375 | Fraction = 0.946
# Frame 145: Largest cluster = 15700 | Fraction = 0.966
# Frame 146: Largest cluster = 15800 | Fraction = 0.972
# Frame 147: Largest cluster = 15650 | Fraction = 0.963
# Frame 148: Largest cluster = 15650 | Fraction = 0.963
# Frame 149: Largest cluster = 15675 | Fraction = 0.965
# Frame 150: Largest cluster = 15675 | Fraction = 0.965
# Frame 151: Largest cluster = 15375 | Fraction = 0.946
# Frame 152: Largest cluster = 15625 | Fraction = 0.962
# Frame 153: Largest cluster = 15325 | Fraction = 0.943
# Frame 154: Largest cluster = 15475 | Fraction = 0.952
# Frame 155: Largest cluster = 15575 | Fraction = 0.958
# Frame 156: Largest cluster = 15475 | Fraction = 0.952
# Frame 157: Largest cluster = 15650 | Fraction = 0.963
# Frame 158: Largest cluster = 15625 | Fraction = 0.962
# Frame 159: Largest cluster = 15650 | Fraction = 0.963
# Frame 160: Largest cluster = 15650 | Fraction = 0.963
# Frame 161: Largest cluster = 15725 | Fraction = 0.968
# Frame 162: Largest cluster = 15750 | Fraction = 0.969
# Frame 163: Largest cluster = 15725 | Fraction = 0.968
# Frame 164: Largest cluster = 15525 | Fraction = 0.955
# Frame 165: Largest cluster = 15450 | Fraction = 0.951
# Frame 166: Largest cluster = 15800 | Fraction = 0.972
# Frame 167: Largest cluster = 15775 | Fraction = 0.971
# Frame 168: Largest cluster = 15675 | Fraction = 0.965
# Frame 169: Largest cluster = 15675 | Fraction = 0.965
# Frame 170: Largest cluster = 15650 | Fraction = 0.963
# Frame 171: Largest cluster = 15525 | Fraction = 0.955
# Frame 172: Largest cluster = 15825 | Fraction = 0.974
# Frame 173: Largest cluster = 15550 | Fraction = 0.957
# Frame 174: Largest cluster = 15700 | Fraction = 0.966
# Frame 175: Largest cluster = 15625 | Fraction = 0.962
# Frame 176: Largest cluster = 15700 | Fraction = 0.966
# Frame 177: Largest cluster = 15700 | Fraction = 0.966
# Frame 178: Largest cluster = 15475 | Fraction = 0.952
# Frame 179: Largest cluster = 15650 | Fraction = 0.963
# Frame 180: Largest cluster = 15625 | Fraction = 0.962
# Frame 181: Largest cluster = 15550 | Fraction = 0.957
# Frame 182: Largest cluster = 15650 | Fraction = 0.963
# Frame 183: Largest cluster = 15625 | Fraction = 0.962
# Frame 184: Largest cluster = 15375 | Fraction = 0.946
# Frame 185: Largest cluster = 15300 | Fraction = 0.942
# Frame 186: Largest cluster = 15525 | Fraction = 0.955
# Frame 187: Largest cluster = 15400 | Fraction = 0.948
# Frame 188: Largest cluster = 15500 | Fraction = 0.954
# Frame 189: Largest cluster = 15600 | Fraction = 0.960
# Frame 190: Largest cluster = 15700 | Fraction = 0.966
# Frame 191: Largest cluster = 15500 | Fraction = 0.954
# Frame 192: Largest cluster = 15600 | Fraction = 0.960
# Frame 193: Largest cluster = 15675 | Fraction = 0.965
# Frame 194: Largest cluster = 15700 | Fraction = 0.966
# Frame 195: Largest cluster = 15650 | Fraction = 0.963
# Frame 196: Largest cluster = 15400 | Fraction = 0.948
# Frame 197: Largest cluster = 15750 | Fraction = 0.969
# Frame 198: Largest cluster = 15575 | Fraction = 0.958
# Frame 199: Largest cluster = 15550 | Fraction = 0.957
# Frame 200: Largest cluster = 15400 | Fraction = 0.948
# Frame 201: Largest cluster = 15625 | Fraction = 0.962
# Frame 202: Largest cluster = 15500 | Fraction = 0.954
# Frame 203: Largest cluster = 15625 | Fraction = 0.962
# Frame 204: Largest cluster = 15950 | Fraction = 0.982
# Frame 205: Largest cluster = 15725 | Fraction = 0.968
# Frame 206: Largest cluster = 15600 | Fraction = 0.960
# Frame 207: Largest cluster = 15675 | Fraction = 0.965
# Frame 208: Largest cluster = 15650 | Fraction = 0.963
# Frame 209: Largest cluster = 15625 | Fraction = 0.962
# Frame 210: Largest cluster = 15650 | Fraction = 0.963
# Frame 211: Largest cluster = 15550 | Fraction = 0.957
# Frame 212: Largest cluster = 15750 | Fraction = 0.969
# Frame 213: Largest cluster = 15675 | Fraction = 0.965
# Frame 214: Largest cluster = 15675 | Fraction = 0.965
# Frame 215: Largest cluster = 15650 | Fraction = 0.963
# Frame 216: Largest cluster = 15475 | Fraction = 0.952
# Frame 217: Largest cluster = 15425 | Fraction = 0.949
# Frame 218: Largest cluster = 15550 | Fraction = 0.957
# Frame 219: Largest cluster = 15650 | Fraction = 0.963
# Frame 220: Largest cluster = 15575 | Fraction = 0.958
# Frame 221: Largest cluster = 15650 | Fraction = 0.963
# Frame 222: Largest cluster = 15675 | Fraction = 0.965
# Frame 223: Largest cluster = 15800 | Fraction = 0.972
# Frame 224: Largest cluster = 15725 | Fraction = 0.968
# Frame 225: Largest cluster = 15600 | Fraction = 0.960
# Frame 226: Largest cluster = 15500 | Fraction = 0.954
# Frame 227: Largest cluster = 15625 | Fraction = 0.962
# Frame 228: Largest cluster = 15425 | Fraction = 0.949
# Frame 229: Largest cluster = 15775 | Fraction = 0.971
# Frame 230: Largest cluster = 15675 | Fraction = 0.965
# Frame 231: Largest cluster = 15675 | Fraction = 0.965
# Frame 232: Largest cluster = 15875 | Fraction = 0.977
# Frame 233: Largest cluster = 15800 | Fraction = 0.972
# Frame 234: Largest cluster = 15675 | Fraction = 0.965
# Frame 235: Largest cluster = 15675 | Fraction = 0.965
# Frame 236: Largest cluster = 15700 | Fraction = 0.966
# Frame 237: Largest cluster = 15775 | Fraction = 0.971
# Frame 238: Largest cluster = 15700 | Fraction = 0.966
# Frame 239: Largest cluster = 15725 | Fraction = 0.968
# Frame 240: Largest cluster = 15650 | Fraction = 0.963
# Frame 241: Largest cluster = 15775 | Fraction = 0.971
# Frame 242: Largest cluster = 15575 | Fraction = 0.958
# Frame 243: Largest cluster = 15575 | Fraction = 0.958
# Frame 244: Largest cluster = 15725 | Fraction = 0.968
# Frame 245: Largest cluster = 15550 | Fraction = 0.957
# Frame 246: Largest cluster = 15550 | Fraction = 0.957
# Frame 247: Largest cluster = 15525 | Fraction = 0.955
# Frame 248: Largest cluster = 15650 | Fraction = 0.963
# Frame 249: Largest cluster = 15550 | Fraction = 0.957
# Frame 250: Largest cluster = 15625 | Fraction = 0.962
# Frame 251: Largest cluster = 15675 | Fraction = 0.965
# Frame 252: Largest cluster = 15375 | Fraction = 0.946
# Frame 253: Largest cluster = 15650 | Fraction = 0.963
# Frame 254: Largest cluster = 15450 | Fraction = 0.951
# Frame 255: Largest cluster = 15550 | Fraction = 0.957
# Frame 256: Largest cluster = 15600 | Fraction = 0.960
# Frame 257: Largest cluster = 15800 | Fraction = 0.972
# Frame 258: Largest cluster = 15425 | Fraction = 0.949
# Frame 259: Largest cluster = 15350 | Fraction = 0.945
# Frame 260: Largest cluster = 15425 | Fraction = 0.949
# Frame 261: Largest cluster = 15650 | Fraction = 0.963
# Frame 262: Largest cluster = 15500 | Fraction = 0.954
# Frame 263: Largest cluster = 15600 | Fraction = 0.960
# Frame 264: Largest cluster = 15725 | Fraction = 0.968
# Frame 265: Largest cluster = 15825 | Fraction = 0.974
# Frame 266: Largest cluster = 15375 | Fraction = 0.946
# Frame 267: Largest cluster = 15700 | Fraction = 0.966
# Frame 268: Largest cluster = 15300 | Fraction = 0.942
# Frame 269: Largest cluster = 15675 | Fraction = 0.965
# Frame 270: Largest cluster = 15675 | Fraction = 0.965
# Frame 271: Largest cluster = 15500 | Fraction = 0.954
# Frame 272: Largest cluster = 15600 | Fraction = 0.960
# Frame 273: Largest cluster = 15775 | Fraction = 0.971
# Frame 274: Largest cluster = 15625 | Fraction = 0.962
# Frame 275: Largest cluster = 15500 | Fraction = 0.954
# Frame 276: Largest cluster = 15350 | Fraction = 0.945
# Frame 277: Largest cluster = 15700 | Fraction = 0.966
# Frame 278: Largest cluster = 15650 | Fraction = 0.963
# Frame 279: Largest cluster = 15275 | Fraction = 0.940
# Frame 280: Largest cluster = 15175 | Fraction = 0.934
# Frame 281: Largest cluster = 15350 | Fraction = 0.945
# Frame 282: Largest cluster = 15575 | Fraction = 0.958
# Frame 283: Largest cluster = 15625 | Fraction = 0.962
# Frame 284: Largest cluster = 15450 | Fraction = 0.951
# Frame 285: Largest cluster = 15750 | Fraction = 0.969
# Frame 286: Largest cluster = 15525 | Fraction = 0.955
# Frame 287: Largest cluster = 15625 | Fraction = 0.962
# Frame 288: Largest cluster = 15750 | Fraction = 0.969
# Frame 289: Largest cluster = 15600 | Fraction = 0.960
# Frame 290: Largest cluster = 15700 | Fraction = 0.966
# Frame 291: Largest cluster = 15775 | Fraction = 0.971
# Frame 292: Largest cluster = 15650 | Fraction = 0.963
# Frame 293: Largest cluster = 15800 | Fraction = 0.972
# Frame 294: Largest cluster = 15650 | Fraction = 0.963
# Frame 295: Largest cluster = 15475 | Fraction = 0.952
# Frame 296: Largest cluster = 15575 | Fraction = 0.958
# Frame 297: Largest cluster = 15650 | Fraction = 0.963
# Frame 298: Largest cluster = 15800 | Fraction = 0.972
# Frame 299: Largest cluster = 15700 | Fraction = 0.966
# Frame 300: Largest cluster = 15625 | Fraction = 0.962
# Frame 301: Largest cluster = 15600 | Fraction = 0.960
# Frame 302: Largest cluster = 15650 | Fraction = 0.963
# Frame 303: Largest cluster = 15750 | Fraction = 0.969
# Frame 304: Largest cluster = 15375 | Fraction = 0.946
# Frame 305: Largest cluster = 15500 | Fraction = 0.954
# Frame 306: Largest cluster = 15550 | Fraction = 0.957
# Frame 307: Largest cluster = 15700 | Fraction = 0.966
# Frame 308: Largest cluster = 15525 | Fraction = 0.955
# Frame 309: Largest cluster = 15450 | Fraction = 0.951
# Frame 310: Largest cluster = 15450 | Fraction = 0.951
# Frame 311: Largest cluster = 15525 | Fraction = 0.955
# Frame 312: Largest cluster = 15800 | Fraction = 0.972
# Frame 313: Largest cluster = 15850 | Fraction = 0.975
# Frame 314: Largest cluster = 15700 | Fraction = 0.966
# Frame 315: Largest cluster = 15325 | Fraction = 0.943
# Frame 316: Largest cluster = 15400 | Fraction = 0.948
# Frame 317: Largest cluster = 15600 | Fraction = 0.960
# Frame 318: Largest cluster = 15750 | Fraction = 0.969
# Frame 319: Largest cluster = 15550 | Fraction = 0.957
# Frame 320: Largest cluster = 15675 | Fraction = 0.965
# Frame 321: Largest cluster = 15400 | Fraction = 0.948
# Frame 322: Largest cluster = 15700 | Fraction = 0.966
# Frame 323: Largest cluster = 15550 | Fraction = 0.957
# Frame 324: Largest cluster = 15675 | Fraction = 0.965
# Frame 325: Largest cluster = 15325 | Fraction = 0.943
# Frame 326: Largest cluster = 15600 | Fraction = 0.960
# Frame 327: Largest cluster = 15700 | Fraction = 0.966
# Frame 328: Largest cluster = 15700 | Fraction = 0.966
# Frame 329: Largest cluster = 15600 | Fraction = 0.960
# Frame 330: Largest cluster = 15550 | Fraction = 0.957
# Frame 331: Largest cluster = 15525 | Fraction = 0.955
# Frame 332: Largest cluster = 15375 | Fraction = 0.946
# Frame 333: Largest cluster = 15400 | Fraction = 0.948
# Frame 334: Largest cluster = 15650 | Fraction = 0.963
# Frame 335: Largest cluster = 15850 | Fraction = 0.975
# Frame 336: Largest cluster = 15650 | Fraction = 0.963
# Frame 337: Largest cluster = 15675 | Fraction = 0.965
# Frame 338: Largest cluster = 15725 | Fraction = 0.968
# Frame 339: Largest cluster = 15375 | Fraction = 0.946
# Frame 340: Largest cluster = 15650 | Fraction = 0.963
# Frame 341: Largest cluster = 15800 | Fraction = 0.972
# Frame 342: Largest cluster = 15700 | Fraction = 0.966
# Frame 343: Largest cluster = 15700 | Fraction = 0.966
# Frame 344: Largest cluster = 15525 | Fraction = 0.955
# Frame 345: Largest cluster = 15525 | Fraction = 0.955
# Frame 346: Largest cluster = 15675 | Fraction = 0.965
# Frame 347: Largest cluster = 15675 | Fraction = 0.965
# Frame 348: Largest cluster = 15700 | Fraction = 0.966
# Frame 349: Largest cluster = 15575 | Fraction = 0.958
# Frame 350: Largest cluster = 15850 | Fraction = 0.975
# Frame 351: Largest cluster = 15825 | Fraction = 0.974
# Frame 352: Largest cluster = 15725 | Fraction = 0.968
# Frame 353: Largest cluster = 15575 | Fraction = 0.958
# Frame 354: Largest cluster = 15550 | Fraction = 0.957
# Frame 355: Largest cluster = 15475 | Fraction = 0.952
# Frame 356: Largest cluster = 15725 | Fraction = 0.968
# Frame 357: Largest cluster = 15725 | Fraction = 0.968
# Frame 358: Largest cluster = 15875 | Fraction = 0.977
# Frame 359: Largest cluster = 15650 | Fraction = 0.963
# Frame 360: Largest cluster = 15575 | Fraction = 0.958
# Frame 361: Largest cluster = 15750 | Fraction = 0.969
# Frame 362: Largest cluster = 15675 | Fraction = 0.965
# Frame 363: Largest cluster = 15550 | Fraction = 0.957
# Frame 364: Largest cluster = 15725 | Fraction = 0.968
# Frame 365: Largest cluster = 15600 | Fraction = 0.960
# Frame 366: Largest cluster = 15425 | Fraction = 0.949
# Frame 367: Largest cluster = 15525 | Fraction = 0.955
# Frame 368: Largest cluster = 15700 | Fraction = 0.966
# Frame 369: Largest cluster = 15225 | Fraction = 0.937
# Frame 370: Largest cluster = 15400 | Fraction = 0.948
# Frame 371: Largest cluster = 15275 | Fraction = 0.940
# Frame 372: Largest cluster = 15475 | Fraction = 0.952
# Frame 373: Largest cluster = 15550 | Fraction = 0.957
# Frame 374: Largest cluster = 15575 | Fraction = 0.958
# Frame 375: Largest cluster = 15575 | Fraction = 0.958
# Frame 376: Largest cluster = 15850 | Fraction = 0.975
# Frame 377: Largest cluster = 15925 | Fraction = 0.980
# Frame 378: Largest cluster = 15800 | Fraction = 0.972
# Frame 379: Largest cluster = 15850 | Fraction = 0.975
# Frame 380: Largest cluster = 15550 | Fraction = 0.957
# Frame 381: Largest cluster = 15475 | Fraction = 0.952
# Frame 382: Largest cluster = 15575 | Fraction = 0.958
# Frame 383: Largest cluster = 15675 | Fraction = 0.965
# Frame 384: Largest cluster = 15750 | Fraction = 0.969
# Frame 385: Largest cluster = 15425 | Fraction = 0.949
# Frame 386: Largest cluster = 15550 | Fraction = 0.957
# Frame 387: Largest cluster = 15400 | Fraction = 0.948
# Frame 388: Largest cluster = 15750 | Fraction = 0.969
# Frame 389: Largest cluster = 15875 | Fraction = 0.977
# Frame 390: Largest cluster = 15675 | Fraction = 0.965
# Frame 391: Largest cluster = 15700 | Fraction = 0.966
# Frame 392: Largest cluster = 15775 | Fraction = 0.971
# Frame 393: Largest cluster = 15650 | Fraction = 0.963
# Frame 394: Largest cluster = 15650 | Fraction = 0.963
# Frame 395: Largest cluster = 15575 | Fraction = 0.958
# Frame 396: Largest cluster = 15775 | Fraction = 0.971
# Frame 397: Largest cluster = 15675 | Fraction = 0.965
# Frame 398: Largest cluster = 15875 | Fraction = 0.977

# %%
output_frame_csv = '/home/user/Desktop/Anagha/Shin_Colab/Linker_2/eps_0.5/N_1/receptor_radial_density.csv'
output_density_csv = '/home/user/Desktop/Anagha/Shin_Colab/Linker_2/eps_0.5/N_1/receptor_radial_density_table.csv'
output_plot = '/home/user/Desktop/Anagha/Shin_Colab/Linker_2/eps_0.5/N_1/receptor_radial_density.png'

receptor_type = 2
cutoff = 2.5
bin_width = 1.0
max_radius = 30.0 * math.sqrt(2)
slab_thickness = 2.6

u = mda.Universe(lammps_data, trajectory_file, format='LAMMPSDUMP')

class UnionFind:
    def __init__(self, n):
        self.parent = list(range(n))
        self.rank = [0] * n
    def find(self, x):
        while self.parent[x] != x:
            self.parent[x] = self.parent[self.parent[x]]
            x = self.parent[x]
        return x
    def union(self, a, b):
        ra, rb = self.find(a), self.find(b)
        if ra == rb:
            return
        if self.rank[ra] < self.rank[rb]:
            self.parent[ra] = rb
        else:
            self.parent[rb] = ra
            if self.rank[ra] == self.rank[rb]:
                self.rank[ra] += 1

def get_cell_index(pos, cell_size, box):
    return tuple((pos // cell_size).astype(int))

bins = np.arange(0, max_radius + bin_width, bin_width)
bin_centers = 0.5 * (bins[:-1] + bins[1:])
shell_volumes = np.pi * slab_thickness * (bins[1:]**2 - bins[:-1]**2)

radial_density_cluster = np.zeros(len(shell_volumes))
radial_density_all = np.zeros(len(shell_volumes))
valid_frames = 0
frame_results = []

for ts in u.trajectory:
    Lz = ts.dimensions[2]
    receptors = u.select_atoms(f"type {receptor_type} and prop z>{Lz - slab_thickness}")
    total_receptors = len(receptors)
    if total_receptors == 0:
        continue

    receptors.wrap(compound='fragments')
    positions = receptors.positions
    box = ts.dimensions[:3]
    cell_size = cutoff
    cell_dict = defaultdict(list)
    for i, pos in enumerate(positions):
        cell = get_cell_index(pos, cell_size, box)
        cell_dict[cell].append(i)

    neighbor_offsets = [(dx, dy, dz) for dx in [-1, 0, 1] for dy in [-1, 0, 1] for dz in [-1, 0, 1]]
    pairs = []
    for cell, atom_ids in cell_dict.items():
        for dx, dy, dz in neighbor_offsets:
            neighbor_cell = (
                (cell[0] + dx) % int(box[0] / cell_size),
                (cell[1] + dy) % int(box[1] / cell_size),
                (cell[2] + dz) % int(box[2] / cell_size)
            )
            for i in atom_ids:
                for j in cell_dict.get(neighbor_cell, []):
                    if j <= i:
                        continue
                    diff = positions[i] - positions[j]
                    diff -= box * np.round(diff / box)
                    if np.dot(diff, diff) <= cutoff**2:
                        pairs.append((i, j))

    uf = UnionFind(total_receptors)
    for i, j in pairs:
        uf.union(i, j)

    groups = defaultdict(list)
    for i in range(total_receptors):
        groups[uf.find(i)].append(i)

    largest_cluster = max(groups.values(), key=len)
    fraction = len(largest_cluster) / total_receptors
    print(f"Frame {ts.frame}: largest receptor cluster = {len(largest_cluster)} atoms, fraction = {fraction:.3f}")

    frame_results.append([ts.frame, total_receptors, len(largest_cluster), fraction])

    cluster_positions = positions[largest_cluster]
    ref_com_cluster = cluster_positions.mean(axis=0)
    distances_cluster = np.linalg.norm(cluster_positions[:, :2] - ref_com_cluster[:2], axis=1)
    hist_cluster, _ = np.histogram(distances_cluster, bins=bins)
    radial_density_cluster += hist_cluster

    ref_com_all = receptors.center_of_mass()
    distances_all = np.linalg.norm(positions[:, :2] - ref_com_all[:2], axis=1)
    hist_all, _ = np.histogram(distances_all, bins=bins)
    radial_density_all += hist_all

    valid_frames += 1

df_frame = pd.DataFrame(frame_results, columns=["Frame", "TotalReceptors", "LargestClusterSize", "Fraction"])
df_frame.to_csv(output_frame_csv, index=False)

radial_density_cluster /= (valid_frames * shell_volumes)
radial_density_all /= (valid_frames * shell_volumes)

density_table = pd.DataFrame({
    "Radius (Å)": bin_centers,
    "Cluster Density (atoms/Å³)": radial_density_cluster,
    "All Receptors Density (atoms/Å³)": radial_density_all
})
density_table.to_csv(output_density_csv, index=False)

plt.plot(bin_centers, radial_density_cluster, label="Largest Receptor Cluster", color='g')
plt.plot(bin_centers, radial_density_all, label="All Receptors", color='r', linestyle='--')
plt.xlabel("Radius (Å)")
plt.ylabel("Density (atoms/Å³)")
plt.legend()
plt.title("Radial Density Profile - Receptors (Top Slab)")
plt.savefig(output_plot, dpi=300, bbox_inches='tight')
plt.show()
# Out:
# /home/user/anaconda3/lib/python3.12/site-packages/MDAnalysis/coordinates/LAMMPS.py:751: UserWarning: Reader has no dt information, set to 1.0 ps
#   ts.data["time"] = step_num * ts.dt
# Frame 0: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 1: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 2: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 3: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 4: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 5: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 6: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 7: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 8: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 9: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 10: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 11: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 12: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 13: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 14: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 15: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 16: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 17: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 18: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 19: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 20: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 21: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 22: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 23: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 24: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 25: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 26: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 27: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 28: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 29: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 30: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 31: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 32: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 33: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 34: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 35: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 36: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 37: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 38: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 39: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 40: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 41: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 42: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 43: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 44: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 45: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 46: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 47: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 48: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 49: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 50: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 51: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 52: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 53: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 54: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 55: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 56: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 57: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 58: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 59: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 60: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 61: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 62: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 63: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 64: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 65: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 66: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 67: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 68: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 69: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 70: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 71: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 72: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 73: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 74: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 75: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 76: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 77: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 78: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 79: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 80: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 81: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 82: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 83: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 84: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 85: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 86: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 87: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 88: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 89: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 90: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 91: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 92: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 93: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 94: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 95: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 96: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 97: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 98: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 99: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 100: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 101: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 102: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 103: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 104: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 105: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 106: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 107: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 108: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 109: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 110: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 111: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 112: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 113: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 114: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 115: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 116: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 117: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 118: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 119: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 120: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 121: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 122: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 123: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 124: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 125: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 126: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 127: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 128: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 129: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 130: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 131: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 132: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 133: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 134: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 135: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 136: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 137: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 138: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 139: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 140: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 141: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 142: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 143: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 144: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 145: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 146: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 147: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 148: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 149: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 150: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 151: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 152: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 153: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 154: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 155: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 156: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 157: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 158: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 159: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 160: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 161: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 162: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 163: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 164: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 165: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 166: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 167: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 168: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 169: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 170: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 171: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 172: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 173: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 174: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 175: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 176: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 177: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 178: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 179: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 180: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 181: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 182: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 183: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 184: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 185: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 186: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 187: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 188: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 189: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 190: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 191: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 192: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 193: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 194: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 195: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 196: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 197: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 198: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 199: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 200: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 201: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 202: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 203: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 204: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 205: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 206: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 207: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 208: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 209: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 210: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 211: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 212: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 213: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 214: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 215: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 216: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 217: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 218: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 219: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 220: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 221: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 222: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 223: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 224: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 225: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 226: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 227: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 228: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 229: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 230: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 231: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 232: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 233: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 234: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 235: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 236: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 237: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 238: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 239: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 240: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 241: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 242: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 243: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 244: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 245: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 246: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 247: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 248: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 249: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 250: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 251: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 252: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 253: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 254: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 255: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 256: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 257: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 258: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 259: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 260: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 261: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 262: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 263: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 264: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 265: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 266: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 267: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 268: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 269: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 270: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 271: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 272: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 273: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 274: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 275: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 276: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 277: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 278: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 279: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 280: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 281: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 282: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 283: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 284: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 285: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 286: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 287: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 288: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 289: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 290: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 291: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 292: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 293: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 294: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 295: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 296: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 297: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 298: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 299: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 300: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 301: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 302: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 303: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 304: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 305: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 306: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 307: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 308: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 309: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 310: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 311: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 312: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 313: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 314: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 315: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 316: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 317: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 318: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 319: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 320: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 321: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 322: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 323: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 324: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 325: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 326: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 327: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 328: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 329: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 330: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 331: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 332: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 333: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 334: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 335: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 336: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 337: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 338: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 339: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 340: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 341: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 342: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 343: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 344: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 345: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 346: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 347: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 348: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 349: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 350: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 351: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 352: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 353: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 354: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 355: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 356: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 357: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 358: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 359: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 360: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 361: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 362: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 363: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 364: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 365: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 366: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 367: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 368: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 369: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 370: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 371: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 372: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 373: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 374: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 375: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 376: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 377: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 378: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 379: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 380: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 381: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 382: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 383: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 384: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 385: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 386: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 387: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 388: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 389: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 390: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 391: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 392: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 393: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 394: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 395: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 396: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 397: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 398: largest receptor cluster = 1 atoms, fraction = 1.000
# Frame 399: largest receptor cluster = 1 atoms, fraction = 1.000

# %%
#2D radial density plot of receptors
slab_thickness = 2.6  # Å or units of your simulation
Lx, Ly, Lz = u.dimensions[:3]
receptors = u.select_atoms(f"type {receptor_type} and prop z > {Lz-slab_thickness}")
xy = receptors.positions[:, :2]
x_bins = np.linspace(0, Lx, 100) 
y_bins = np.linspace(0, Ly, 100)  
H, xedges, yedges = np.histogram2d(xy[:,0], xy[:,1], bins=[x_bins, y_bins])
H = H / np.sum(H)

plt.figure(figsize=(6,5))
plt.imshow(H.T, origin='lower', extent=[0, Lx, 0, Ly], cmap='viridis', aspect='auto')
plt.colorbar(label='Normalized Density')
plt.xlabel('X (Å)')
plt.ylabel('Y (Å)')
plt.title('2D Radial Density of Receptors in Upper Slab')
plt.savefig("/home/user/Desktop/Anagha/Shin_Colab/Linker_2/No_interaction/N_300/2D_radialdensity_receptor.png", dpi=300, bbox_inches='tight')
plt.show()

# %%
#plot the fraction of polymers in the cluster (=Polymer_in_cluster/ Total_polymers) as a function of number of receptors. 
from MDAnalysis.lib import distances
save_path = '/home/user/Desktop/Anagha/Shin_Colab/Linker_2/No_interaction/N_300/polymers_fraction_vs_no _of_receptors.csv'

slab_thickness = 2.6  # thickness of upper slab
cutoff = 2.5          # clustering cutoff in Å

fraction_polymers = []
num_receptors_list = []

print("Frame\tNum_Receptors\tFraction_of_Polymers_in_Cluster")

for i, ts in enumerate(u.trajectory):
    # Select receptors in upper slab
    receptors = u.select_atoms(f"type {receptor_type} and prop z > {u.dimensions[2]-slab_thickness}")
    num_receptors = len(receptors)
    
    if num_receptors == 0:
        continue 
    polymers = u.select_atoms(f"type {polymer_type}")
    dists = distances.distance_array(polymers.positions, receptors.positions)
    polymers_in_cluster = np.sum(np.any(dists < cutoff, axis=1))
    fraction = polymers_in_cluster / len(polymers)
    num_receptors_list.append(num_receptors)
    fraction_polymers.append(fraction)
    print(f"{i}\t{num_receptors}\t{fraction:.3f}")


df = pd.DataFrame(results, columns=[
    'Frame', 'Num_Receptors', 'LargestClusterSize', 'Fraction'
])
df.to_csv(save_path, index=False)


plt.figure(figsize=(6,4))
plt.plot(num_receptors_list, fraction_polymers, 'o-', color='purple')
plt.xlabel("Number of Receptors in Upper Slab")
plt.ylabel("Fraction of Polymers in Cluster")
plt.title("Polymer Fraction vs Number of Receptors")
plt.grid(True)
plt.savefig("/home/user/Desktop/Anagha/Shin_Colab/Linker_2/No_interaction/N_300/polymers_fraction_vs_no _of_receptors.png", dpi=300, bbox_inches='tight')
plt.show()
# Out:
# Frame	Num_Receptors	Fraction_of_Polymers_in_Cluster
# 0	300	0.024
# 1	300	0.021
# 2	300	0.020
# 3	300	0.019
# 4	300	0.019
# 5	300	0.018
# 6	300	0.019
# 7	300	0.019
# 8	300	0.019
# 9	300	0.019
# 10	300	0.018
# 11	300	0.018
# 12	300	0.018
# 13	300	0.019
# 14	300	0.020
# 15	300	0.019
# 16	300	0.019
# 17	300	0.020
# 18	300	0.019
# 19	300	0.019
# 20	300	0.021
# 21	300	0.020
# 22	300	0.019
# 23	300	0.020
# 24	300	0.020
# 25	300	0.020
# 26	300	0.019
# 27	300	0.017
# 28	300	0.019
# 29	300	0.019
# 30	300	0.019
# 31	300	0.019
# 32	300	0.019
# 33	300	0.021
# 34	300	0.020
# 35	300	0.019
# 36	300	0.019
# 37	300	0.020
# 38	300	0.019
# 39	300	0.020
# 40	300	0.020
# 41	300	0.020
# 42	300	0.020
# 43	300	0.020
# 44	300	0.019
# 45	300	0.019
# 46	300	0.018
# 47	300	0.019
# 48	300	0.019
# 49	300	0.020
# 50	300	0.020
# 51	300	0.020
# 52	300	0.019
# 53	300	0.019
# 54	300	0.019
# 55	300	0.019
# 56	300	0.020
# 57	300	0.019
# 58	300	0.019
# 59	300	0.020
# 60	300	0.019
# 61	300	0.019
# 62	300	0.019
# 63	300	0.018
# 64	300	0.019
# 65	300	0.020
# 66	300	0.019
# 67	300	0.020
# 68	300	0.019
# 69	300	0.019
# 70	300	0.020
# 71	300	0.020
# 72	300	0.021
# 73	300	0.020
# 74	300	0.020
# 75	300	0.020
# 76	300	0.020
# 77	300	0.019
# 78	300	0.019
# 79	300	0.019
# 80	300	0.019
# 81	300	0.020
# 82	300	0.018
# 83	300	0.018
# 84	300	0.020
# 85	300	0.019
# 86	300	0.020
# 87	300	0.019
# 88	300	0.018
# 89	300	0.018
# 90	300	0.018
# 91	300	0.019
# 92	300	0.018
# 93	300	0.020
# 94	300	0.019
# 95	300	0.020
# 96	300	0.019
# 97	300	0.019
# 98	300	0.019
# 99	300	0.019
# 100	300	0.019
# 101	300	0.019
# 102	300	0.018
# 103	300	0.019
# 104	300	0.020
# 105	300	0.020
# 106	300	0.020
# 107	300	0.019
# 108	300	0.019
# 109	300	0.021
# 110	300	0.019
# 111	300	0.020
# 112	300	0.019
# 113	300	0.020
# 114	300	0.020
# 115	300	0.020
# 116	300	0.019
# 117	300	0.020
# 118	300	0.019
# 119	300	0.019
# 120	300	0.019
# 121	300	0.020
# 122	300	0.020
# 123	300	0.020
# 124	300	0.020
# 125	300	0.019
# 126	300	0.020
# 127	300	0.020
# 128	300	0.019
# 129	300	0.020
# 130	300	0.019
# 131	300	0.020
# 132	300	0.020
# 133	300	0.020
# 134	300	0.020
# 135	300	0.020
# 136	300	0.021
# 137	300	0.021
# 138	300	0.019
# 139	300	0.020
# 140	300	0.020
# 141	300	0.019
# 142	300	0.020
# 143	300	0.020
# 144	300	0.019
# 145	300	0.019
# 146	300	0.019
# 147	300	0.020
# 148	300	0.019
# 149	300	0.019
# 150	300	0.019
# 151	300	0.019
# 152	300	0.018
# 153	300	0.020
# 154	300	0.020
# 155	300	0.019
# 156	300	0.019
# 157	300	0.019
# 158	300	0.019
# 159	300	0.019
# 160	300	0.020
# 161	300	0.020
# 162	300	0.020
# 163	300	0.020
# 164	300	0.019
# 165	300	0.019
# 166	300	0.019
# 167	300	0.019
# 168	300	0.019
# 169	300	0.019
# 170	300	0.020
# 171	300	0.019
# 172	300	0.020
# 173	300	0.019
# 174	300	0.019
# 175	300	0.020
# 176	300	0.019
# 177	300	0.019
# 178	300	0.020
# 179	300	0.019
# 180	300	0.020
# 181	300	0.019
# 182	300	0.019
# 183	300	0.020
# 184	300	0.020
# 185	300	0.019
# 186	300	0.020
# 187	300	0.019
# 188	300	0.020
# 189	300	0.021
# 190	300	0.020
# 191	300	0.019
# 192	300	0.020
# 193	300	0.019
# 194	300	0.020
# 195	300	0.020
# 196	300	0.020
# 197	300	0.020
# 198	300	0.019
# 199	300	0.020
# 200	300	0.019
# 201	300	0.020
# 202	300	0.020
# 203	300	0.019
# 204	300	0.019
# 205	300	0.020
# 206	300	0.019
# 207	300	0.019
# 208	300	0.019
# 209	300	0.019
# 210	300	0.019
# 211	300	0.018
# 212	300	0.020
# 213	300	0.019
# 214	300	0.020
# 215	300	0.020
# 216	300	0.020
# 217	300	0.019
# 218	300	0.018
# 219	300	0.019
# 220	300	0.020
# 221	300	0.020
# 222	300	0.019
# 223	300	0.020
# 224	300	0.019
# 225	300	0.019
# 226	300	0.020
# 227	300	0.020
# 228	300	0.020
# 229	300	0.020
# 230	300	0.020
# 231	300	0.019
# 232	300	0.019
# 233	300	0.020
# 234	300	0.020
# 235	300	0.020
# 236	300	0.020
# 237	300	0.020
# 238	300	0.019
# 239	300	0.020
# 240	300	0.020
# 241	300	0.019
# 242	300	0.018
# 243	300	0.018
# 244	300	0.019
# 245	300	0.019
# 246	300	0.018
# 247	300	0.019
# 248	300	0.020
# 249	300	0.019
# 250	300	0.019
# 251	300	0.019
# 252	300	0.021
# 253	300	0.020
# 254	300	0.020
# 255	300	0.020
# 256	300	0.020
# 257	300	0.020
# 258	300	0.020
# 259	300	0.019
# 260	300	0.020
# 261	300	0.019
# 262	300	0.019
# 263	300	0.020
# 264	300	0.019
# 265	300	0.020
# 266	300	0.019
# 267	300	0.019
# 268	300	0.019
# 269	300	0.019
# 270	300	0.020
# 271	300	0.019
# 272	300	0.019
# 273	300	0.019
# 274	300	0.019
# 275	300	0.018
# 276	300	0.020
# 277	300	0.020
# 278	300	0.020
# 279	300	0.019
# 280	300	0.019
# 281	300	0.020
# 282	300	0.020
# 283	300	0.021
# 284	300	0.020
# 285	300	0.021
# 286	300	0.020
# 287	300	0.020
# 288	300	0.020
# 289	300	0.020
# 290	300	0.019
# 291	300	0.020
# 292	300	0.019
# 293	300	0.019
# 294	300	0.019
# 295	300	0.020
# 296	300	0.020
# 297	300	0.019
# 298	300	0.019
# 299	300	0.019
# 300	300	0.020
# 301	300	0.021
# 302	300	0.020
# 303	300	0.019
# 304	300	0.019
# 305	300	0.019
# 306	300	0.018
# 307	300	0.020
# 308	300	0.019
# 309	300	0.020
# 310	300	0.019
# 311	300	0.020
# 312	300	0.021
# 313	300	0.021
# 314	300	0.020
# 315	300	0.021
# 316	300	0.021
# 317	300	0.020
# 318	300	0.019
# 319	300	0.019
# 320	300	0.019
# 321	300	0.018
# 322	300	0.020
# 323	300	0.021
# 324	300	0.019
# 325	300	0.020
# 326	300	0.021
# 327	300	0.020
# 328	300	0.020
# 329	300	0.020
# 330	300	0.020
# 331	300	0.020
# 332	300	0.020
# 333	300	0.021
# 334	300	0.020
# 335	300	0.018
# 336	300	0.020
# 337	300	0.021
# 338	300	0.021
# 339	300	0.020
# 340	300	0.020
# 341	300	0.019
# 342	300	0.019
# 343	300	0.019
# 344	300	0.019
# 345	300	0.020
# 346	300	0.020
# 347	300	0.020
# 348	300	0.020
# 349	300	0.020
# 350	300	0.020
# 351	300	0.020
# 352	300	0.020
# 353	300	0.019
# 354	300	0.020
# 355	300	0.020
# 356	300	0.020
# 357	300	0.020
# 358	300	0.020
# 359	300	0.020
# 360	300	0.019
# 361	300	0.020
# 362	300	0.019
# 363	300	0.019
# 364	300	0.019
# 365	300	0.021
# 366	300	0.020
# 367	300	0.020
# 368	300	0.020
# 369	300	0.019
# 370	300	0.019
# 371	300	0.019
# 372	300	0.019
# 373	300	0.020
# 374	300	0.020
# 375	300	0.020
# 376	300	0.019
# 377	300	0.020
# 378	300	0.019
# 379	300	0.019
# 380	300	0.019
# 381	300	0.019
# 382	300	0.020
# 383	300	0.020
# 384	300	0.020
# 385	300	0.019
# 386	300	0.020
# 387	300	0.020
# 388	300	0.020
# 389	300	0.019
# 390	300	0.020
# 391	300	0.020
# 392	300	0.020
# 393	300	0.020
# 394	300	0.021
# 395	300	0.020
# 396	300	0.019
# 397	300	0.020
# 398	300	0.020
# 399	300	0.019

# %%
print(df.columns.tolist())
# Out:
# ['Frame', 'Num_Receptors', 'LargestClusterSize', 'Fraction']

# %%
#plot the fraction of receptors in the cluster (=Receptors_in_cluster/ Total_receptors) as a function of number of receptors. 
save_path = '/home/user/Desktop/Anagha/Shin_Colab/Linker_2/No_interaction/N_300/receptor_fraction_vs_no_of_receptors.csv'
slab_thickness = 2.6  # Å
cutoff = 2.5          # Å

fraction_receptors = []
num_receptors_list = []
results = []  # to store CSV rows

print("Frame\tNum_Receptors\tReceptors_in_Cluster\tTotal_Receptors\tFraction_in_Cluster")

for i, ts in enumerate(u.trajectory):  # loop over frames
    # --- Select receptors in upper slab ---
    receptors = u.select_atoms(f"type {receptor_type} and prop z > {u.dimensions[2]-slab_thickness}")
    num_receptors = len(receptors)
    if num_receptors == 0:
        continue

    polymers = u.select_atoms(f"type {polymer_type}") 
    dists = distances.distance_array(receptors.positions, polymers.positions, box=u.dimensions)
    receptors_in_cluster = np.sum(np.any(dists < cutoff, axis=1))
    fraction = receptors_in_cluster / num_receptors

    # --- Store for plotting + CSV ---
    num_receptors_list.append(num_receptors)
    fraction_receptors.append(fraction)
    results.append([ts.frame, num_receptors, receptors_in_cluster, num_receptors, fraction])

    print(f"{i}\t{num_receptors}\t{receptors_in_cluster}\t{num_receptors}\t{fraction:.3f}")

# --- Save CSV ---0
df = pd.DataFrame(results, columns=[
    "Frame", "Num_Receptors", "Receptors_in_Cluster", "Total_Receptors", "Fraction_Receptors"
])
df.to_csv(save_path, index=False)
print(f"\nResults saved to {save_path}")

plt.figure(figsize=(6,4))
plt.plot(num_receptors_list, fraction_receptors, 'o-', color='green')
plt.xlabel("Number of Receptors in Upper Slab")
plt.ylabel("Fraction of Receptors in Cluster")
plt.title("Fraction of Receptors vs Number of Receptors")
plt.grid(True)
plt.savefig("/home/user/Desktop/Anagha/Shin_Colab/Linker_2/eps_0.5/N_300/receptors_fraction_vs_no_of_receptors.png",
            dpi=300, bbox_inches='tight')
plt.show()
# Out:
# Frame	Num_Receptors	Receptors_in_Cluster	Total_Receptors	Fraction_in_Cluster
# 0	300	289	300	0.963
# 1	300	261	300	0.870
# 2	300	254	300	0.847
# 3	300	241	300	0.803
# 4	300	243	300	0.810
# 5	300	238	300	0.793
# 6	300	247	300	0.823
# 7	300	240	300	0.800
# 8	300	245	300	0.817
# 9	300	245	300	0.817
# 10	300	233	300	0.777
# 11	300	244	300	0.813
# 12	300	235	300	0.783
# 13	300	253	300	0.843
# 14	300	250	300	0.833
# 15	300	247	300	0.823
# 16	300	250	300	0.833
# 17	300	257	300	0.857
# 18	300	252	300	0.840
# 19	300	256	300	0.853
# 20	300	264	300	0.880
# 21	300	253	300	0.843
# 22	300	247	300	0.823
# 23	300	255	300	0.850
# 24	300	248	300	0.827
# 25	300	251	300	0.837
# 26	300	246	300	0.820
# 27	300	233	300	0.777
# 28	300	236	300	0.787
# 29	300	238	300	0.793
# 30	300	240	300	0.800
# 31	300	251	300	0.837
# 32	300	246	300	0.820
# 33	300	263	300	0.877
# 34	300	259	300	0.863
# 35	300	244	300	0.813
# 36	300	247	300	0.823
# 37	300	249	300	0.830
# 38	300	245	300	0.817
# 39	300	251	300	0.837
# 40	300	248	300	0.827
# 41	300	254	300	0.847
# 42	300	255	300	0.850
# 43	300	258	300	0.860
# 44	300	249	300	0.830
# 45	300	241	300	0.803
# 46	300	242	300	0.807
# 47	300	236	300	0.787
# 48	300	245	300	0.817
# 49	300	260	300	0.867
# 50	300	250	300	0.833
# 51	300	251	300	0.837
# 52	300	251	300	0.837
# 53	300	242	300	0.807
# 54	300	247	300	0.823
# 55	300	249	300	0.830
# 56	300	253	300	0.843
# 57	300	251	300	0.837
# 58	300	255	300	0.850
# 59	300	257	300	0.857
# 60	300	238	300	0.793
# 61	300	254	300	0.847
# 62	300	247	300	0.823
# 63	300	239	300	0.797
# 64	300	244	300	0.813
# 65	300	253	300	0.843
# 66	300	248	300	0.827
# 67	300	256	300	0.853
# 68	300	251	300	0.837
# 69	300	254	300	0.847
# 70	300	254	300	0.847
# 71	300	252	300	0.840
# 72	300	259	300	0.863
# 73	300	253	300	0.843
# 74	300	248	300	0.827
# 75	300	249	300	0.830
# 76	300	249	300	0.830
# 77	300	246	300	0.820
# 78	300	246	300	0.820
# 79	300	251	300	0.837
# 80	300	255	300	0.850
# 81	300	252	300	0.840
# 82	300	238	300	0.793
# 83	300	244	300	0.813
# 84	300	256	300	0.853
# 85	300	243	300	0.810
# 86	300	247	300	0.823
# 87	300	246	300	0.820
# 88	300	242	300	0.807
# 89	300	242	300	0.807
# 90	300	236	300	0.787
# 91	300	236	300	0.787
# 92	300	235	300	0.783
# 93	300	250	300	0.833
# 94	300	249	300	0.830
# 95	300	256	300	0.853
# 96	300	246	300	0.820
# 97	300	248	300	0.827
# 98	300	241	300	0.803
# 99	300	240	300	0.800
# 100	300	242	300	0.807
# 101	300	241	300	0.803
# 102	300	240	300	0.800
# 103	300	249	300	0.830
# 104	300	252	300	0.840
# 105	300	245	300	0.817
# 106	300	254	300	0.847
# 107	300	244	300	0.813
# 108	300	252	300	0.840
# 109	300	258	300	0.860
# 110	300	249	300	0.830
# 111	300	252	300	0.840
# 112	300	252	300	0.840
# 113	300	259	300	0.863
# 114	300	250	300	0.833
# 115	300	254	300	0.847
# 116	300	254	300	0.847
# 117	300	244	300	0.813
# 118	300	243	300	0.810
# 119	300	247	300	0.823
# 120	300	256	300	0.853
# 121	300	255	300	0.850
# 122	300	258	300	0.860
# 123	300	253	300	0.843
# 124	300	252	300	0.840
# 125	300	251	300	0.837
# 126	300	255	300	0.850
# 127	300	257	300	0.857
# 128	300	255	300	0.850
# 129	300	263	300	0.877
# 130	300	250	300	0.833
# 131	300	257	300	0.857
# 132	300	259	300	0.863
# 133	300	263	300	0.877
# 134	300	258	300	0.860
# 135	300	264	300	0.880
# 136	300	263	300	0.877
# 137	300	272	300	0.907
# 138	300	255	300	0.850
# 139	300	256	300	0.853
# 140	300	265	300	0.883
# 141	300	253	300	0.843
# 142	300	255	300	0.850
# 143	300	259	300	0.863
# 144	300	244	300	0.813
# 145	300	253	300	0.843
# 146	300	253	300	0.843
# 147	300	259	300	0.863
# 148	300	248	300	0.827
# 149	300	240	300	0.800
# 150	300	242	300	0.807
# 151	300	242	300	0.807
# 152	300	242	300	0.807
# 153	300	251	300	0.837
# 154	300	257	300	0.857
# 155	300	246	300	0.820
# 156	300	248	300	0.827
# 157	300	245	300	0.817
# 158	300	244	300	0.813
# 159	300	249	300	0.830
# 160	300	252	300	0.840
# 161	300	261	300	0.870
# 162	300	255	300	0.850
# 163	300	262	300	0.873
# 164	300	250	300	0.833
# 165	300	254	300	0.847
# 166	300	246	300	0.820
# 167	300	237	300	0.790
# 168	300	245	300	0.817
# 169	300	248	300	0.827
# 170	300	252	300	0.840
# 171	300	255	300	0.850
# 172	300	252	300	0.840
# 173	300	245	300	0.817
# 174	300	250	300	0.833
# 175	300	254	300	0.847
# 176	300	247	300	0.823
# 177	300	243	300	0.810
# 178	300	243	300	0.810
# 179	300	245	300	0.817
# 180	300	254	300	0.847
# 181	300	248	300	0.827
# 182	300	251	300	0.837
# 183	300	253	300	0.843
# 184	300	253	300	0.843
# 185	300	251	300	0.837
# 186	300	257	300	0.857
# 187	300	246	300	0.820
# 188	300	257	300	0.857
# 189	300	264	300	0.880
# 190	300	258	300	0.860
# 191	300	251	300	0.837
# 192	300	258	300	0.860
# 193	300	245	300	0.817
# 194	300	250	300	0.833
# 195	300	249	300	0.830
# 196	300	257	300	0.857
# 197	300	251	300	0.837
# 198	300	247	300	0.823
# 199	300	249	300	0.830
# 200	300	247	300	0.823
# 201	300	256	300	0.853
# 202	300	250	300	0.833
# 203	300	242	300	0.807
# 204	300	247	300	0.823
# 205	300	251	300	0.837
# 206	300	257	300	0.857
# 207	300	243	300	0.810
# 208	300	246	300	0.820
# 209	300	236	300	0.787
# 210	300	239	300	0.797
# 211	300	232	300	0.773
# 212	300	249	300	0.830
# 213	300	249	300	0.830
# 214	300	246	300	0.820
# 215	300	261	300	0.870
# 216	300	264	300	0.880
# 217	300	246	300	0.820
# 218	300	241	300	0.803
# 219	300	246	300	0.820
# 220	300	246	300	0.820
# 221	300	247	300	0.823
# 222	300	250	300	0.833
# 223	300	259	300	0.863
# 224	300	245	300	0.817
# 225	300	247	300	0.823
# 226	300	250	300	0.833
# 227	300	256	300	0.853
# 228	300	248	300	0.827
# 229	300	256	300	0.853
# 230	300	258	300	0.860
# 231	300	245	300	0.817
# 232	300	245	300	0.817
# 233	300	263	300	0.877
# 234	300	259	300	0.863
# 235	300	252	300	0.840
# 236	300	254	300	0.847
# 237	300	260	300	0.867
# 238	300	248	300	0.827
# 239	300	260	300	0.867
# 240	300	255	300	0.850
# 241	300	251	300	0.837
# 242	300	244	300	0.813
# 243	300	236	300	0.787
# 244	300	248	300	0.827
# 245	300	237	300	0.790
# 246	300	241	300	0.803
# 247	300	249	300	0.830
# 248	300	255	300	0.850
# 249	300	248	300	0.827
# 250	300	242	300	0.807
# 251	300	246	300	0.820
# 252	300	249	300	0.830
# 253	300	252	300	0.840
# 254	300	255	300	0.850
# 255	300	257	300	0.857
# 256	300	258	300	0.860
# 257	300	253	300	0.843
# 258	300	256	300	0.853
# 259	300	244	300	0.813
# 260	300	253	300	0.843
# 261	300	252	300	0.840
# 262	300	247	300	0.823
# 263	300	245	300	0.817
# 264	300	253	300	0.843
# 265	300	251	300	0.837
# 266	300	251	300	0.837
# 267	300	247	300	0.823
# 268	300	253	300	0.843
# 269	300	241	300	0.803
# 270	300	255	300	0.850
# 271	300	240	300	0.800
# 272	300	244	300	0.813
# 273	300	240	300	0.800
# 274	300	255	300	0.850
# 275	300	242	300	0.807
# 276	300	254	300	0.847
# 277	300	254	300	0.847
# 278	300	255	300	0.850
# 279	300	249	300	0.830
# 280	300	239	300	0.797
# 281	300	258	300	0.860
# 282	300	253	300	0.843
# 283	300	268	300	0.893
# 284	300	260	300	0.867
# 285	300	268	300	0.893
# 286	300	258	300	0.860
# 287	300	259	300	0.863
# 288	300	258	300	0.860
# 289	300	255	300	0.850
# 290	300	250	300	0.833
# 291	300	251	300	0.837
# 292	300	247	300	0.823
# 293	300	237	300	0.790
# 294	300	245	300	0.817
# 295	300	249	300	0.830
# 296	300	250	300	0.833
# 297	300	247	300	0.823
# 298	300	242	300	0.807
# 299	300	248	300	0.827
# 300	300	256	300	0.853
# 301	300	258	300	0.860
# 302	300	254	300	0.847
# 303	300	248	300	0.827
# 304	300	244	300	0.813
# 305	300	246	300	0.820
# 306	300	240	300	0.800
# 307	300	249	300	0.830
# 308	300	242	300	0.807
# 309	300	253	300	0.843
# 310	300	240	300	0.800
# 311	300	254	300	0.847
# 312	300	260	300	0.867
# 313	300	258	300	0.860
# 314	300	270	300	0.900
# 315	300	271	300	0.903
# 316	300	265	300	0.883
# 317	300	257	300	0.857
# 318	300	245	300	0.817
# 319	300	244	300	0.813
# 320	300	252	300	0.840
# 321	300	234	300	0.780
# 322	300	253	300	0.843
# 323	300	265	300	0.883
# 324	300	249	300	0.830
# 325	300	248	300	0.827
# 326	300	255	300	0.850
# 327	300	258	300	0.860
# 328	300	257	300	0.857
# 329	300	259	300	0.863
# 330	300	257	300	0.857
# 331	300	266	300	0.887
# 332	300	259	300	0.863
# 333	300	266	300	0.887
# 334	300	252	300	0.840
# 335	300	238	300	0.793
# 336	300	261	300	0.870
# 337	300	255	300	0.850
# 338	300	264	300	0.880
# 339	300	262	300	0.873
# 340	300	262	300	0.873
# 341	300	245	300	0.817
# 342	300	239	300	0.797
# 343	300	248	300	0.827
# 344	300	256	300	0.853
# 345	300	262	300	0.873
# 346	300	261	300	0.870
# 347	300	248	300	0.827
# 348	300	253	300	0.843
# 349	300	263	300	0.877
# 350	300	264	300	0.880
# 351	300	254	300	0.847
# 352	300	259	300	0.863
# 353	300	249	300	0.830
# 354	300	256	300	0.853
# 355	300	255	300	0.850
# 356	300	250	300	0.833
# 357	300	253	300	0.843
# 358	300	260	300	0.867
# 359	300	256	300	0.853
# 360	300	253	300	0.843
# 361	300	251	300	0.837
# 362	300	246	300	0.820
# 363	300	253	300	0.843
# 364	300	246	300	0.820
# 365	300	263	300	0.877
# 366	300	249	300	0.830
# 367	300	249	300	0.830
# 368	300	254	300	0.847
# 369	300	250	300	0.833
# 370	300	245	300	0.817
# 371	300	247	300	0.823
# 372	300	252	300	0.840
# 373	300	249	300	0.830
# 374	300	248	300	0.827
# 375	300	252	300	0.840
# 376	300	243	300	0.810
# 377	300	246	300	0.820
# 378	300	243	300	0.810
# 379	300	249	300	0.830
# 380	300	246	300	0.820
# 381	300	246	300	0.820
# 382	300	257	300	0.857
# 383	300	257	300	0.857
# 384	300	251	300	0.837
# 385	300	245	300	0.817
# 386	300	248	300	0.827
# 387	300	258	300	0.860
# 388	300	262	300	0.873
# 389	300	251	300	0.837
# 390	300	264	300	0.880
# 391	300	253	300	0.843
# 392	300	253	300	0.843
# 393	300	259	300	0.863
# 394	300	260	300	0.867
# 395	300	260	300	0.867
# 396	300	255	300	0.850
# 397	300	255	300	0.850
# 398	300	253	300	0.843
# 399	300	248	300	0.827
#
# Results saved to /home/user/Desktop/Anagha/Shin_Colab/Linker_2/No_interaction/N_300/receptor_fraction_vs_no_of_receptors.csv

# %%
root_folder = '/home/user/Desktop/Anagha/Shin_Colab/Linker_2/eps_0.5'

# Automatically detect all folders starting with "N_"
n_folders = [f for f in os.listdir(root_folder) 
             if os.path.isdir(os.path.join(root_folder, f)) and re.match(r'^N_\d+$', f)]
n_folders.sort(key=lambda x: int(x.split('_')[1]))  # Sort numerically

# Output plot path
output_plot = os.path.join(root_folder, 'all_N_radial_density_plot.png')

# Initialize plot
plt.figure(figsize=(10,6))

# Loop through folders
for n in n_folders:
    folder_path = os.path.join(root_folder, n)
    csv_file = os.path.join(folder_path, 'polymer_radial_density_table.csv')
    
    # Check if CSV exists
    if not os.path.isfile(csv_file):
        print(f" CSV not found in {folder_path}, skipping...")
        continue
    
    # Load CSV
    try:
        df = pd.read_csv(csv_file)
    except Exception as e:
        print(f" Error reading {csv_file}: {e}")
        continue
    
    # Check required columns
    if 'Radius(Å)' not in df.columns or 'ClusterDensity(atoms/Å³)' not in df.columns:
        print(f" Required columns missing in {csv_file}, skipping...")
        continue
    
    # Extract data
    radius = df['Radius(Å)']
    cluster_density = df['ClusterDensity(atoms/Å³)']
    
    # Plot
    plt.plot(radius, cluster_density, label=n, linewidth=2)

# Plot formatting
plt.xlabel('Radius (Å)', fontsize=12)
plt.ylabel('Density (atoms/Å³)', fontsize=12)
plt.title('Radial Density Profile of Polymer for All N', fontsize=14)
plt.legend(title='N Values')
plt.grid(True, alpha=0.3)
plt.tight_layout()

# Save plot
plt.savefig(output_plot, dpi=300, bbox_inches='tight')
plt.show()

print(f"\n Combined plot saved at: {output_plot}")
# Out:
#  Combined plot saved at: /home/user/Desktop/Anagha/Shin_Colab/Linker_2/eps_0.5/all_N_radial_density_plot.png

# %%
root_folder = '/home/user/Desktop/Anagha/Shin_Colab/Linker_2/eps_0.5'

# Automatically detect all folders starting with "N_"
n_folders = [f for f in os.listdir(root_folder) 
             if os.path.isdir(os.path.join(root_folder, f)) and re.match(r'^N_\d+$', f)]
n_folders.sort(key=lambda x: int(x.split('_')[1]))  # Sort numerically

# Output plot path
output_plot = os.path.join(root_folder, 'all_N_radial_density_plot_log.png')

# Initialize plot
plt.figure(figsize=(10,6))

# Loop through folders
for n in n_folders:
    folder_path = os.path.join(root_folder, n)
    csv_file = os.path.join(folder_path, 'polymer_radial_density_table.csv')
    
    # Check if CSV exists
    if not os.path.isfile(csv_file):
        print(f" CSV not found in {folder_path}, skipping...")
        continue
    
    # Load CSV
    try:
        df = pd.read_csv(csv_file)
    except Exception as e:
        print(f" Error reading {csv_file}: {e}")
        continue
    
    # Check required columns
    if 'Radius(Å)' not in df.columns or 'ClusterDensity(atoms/Å³)' not in df.columns:
        print(f" Required columns missing in {csv_file}, skipping...")
        continue
    
    # Extract data
    radius = df['Radius(Å)']
    cluster_density = df['ClusterDensity(atoms/Å³)']

    plt.plot(radius, cluster_density, label=n, linewidth=2)

plt.xlabel('Radius (Å)', fontsize=12)
plt.ylabel('Density (atoms/Å³)', fontsize=12)
plt.yscale('log')  # Set y-axis to log scale
plt.title('Radial Density Profile of Polymer for All N (log scale)', fontsize=14)
plt.legend(title='N Values')
plt.grid(True, alpha=0.3, which='both')  # grid for both major and minor ticks
plt.tight_layout()

plt.savefig(output_plot, dpi=300, bbox_inches='tight')
plt.show()

print(f"\n Combined plot saved at: {output_plot}")
# Out:
#  Combined plot saved at: /home/user/Desktop/Anagha/Shin_Colab/Linker_2/eps_0.5/all_N_radial_density_plot_log.png

# %%
root_folder = '/home/user/Desktop/Anagha/Shin_Colab/Linker_2/eps_0.5'

# Detect all folders starting with "N_"
n_folders = [f for f in os.listdir(root_folder) 
             if os.path.isdir(os.path.join(root_folder, f)) and re.match(r'^N_\d+$', f)]
# Sort numerically by the number after N_
n_folders.sort(key=lambda x: int(x.split('_')[1]))

# Output plot path
output_plot = os.path.join(root_folder, 'all_N_receptor_radial_density_plot.png')

# Initialize plot
plt.figure(figsize=(10,6))

# Loop through folders
for n in n_folders:
    folder_path = os.path.join(root_folder, n)
    csv_file = os.path.join(folder_path, 'receptor_radial_density_table.csv')
    
    if not os.path.isfile(csv_file):
        print(f" CSV not found in {folder_path}, skipping...")
        continue
    
    try:
        df = pd.read_csv(csv_file)
    except Exception as e:
        print(f" Error reading {csv_file}: {e}")
        continue
    
    # Check required columns
    required_cols = ['Radius (Å)', 'Cluster Density (atoms/Å³)']
    if not all(col in df.columns for col in required_cols):
        print(f" Required columns missing in {csv_file}, skipping...")
        continue
    
    # Extract data
    radius = df['Radius (Å)']
    cluster_density = df['Cluster Density (atoms/Å³)']
    
    # Plot cluster density
    plt.plot(radius, cluster_density, label=n, linewidth=2)

# Plot formatting
plt.xlabel('Radius (Å)', fontsize=12)
plt.ylabel('Density (atoms/Å³)', fontsize=12)
plt.title('Radial Density Profile of Receptors for All N', fontsize=14)
plt.legend(title='N Values')
plt.grid(True, alpha=0.3)
plt.tight_layout()

# Save and show plot
plt.savefig(output_plot, dpi=300, bbox_inches='tight')
plt.show()

print(f"\n Combined receptor plot saved at: {output_plot}")
# Out:
#  Combined receptor plot saved at: /home/user/Desktop/Anagha/Shin_Colab/Linker_2/eps_0.5/all_N_receptor_radial_density_plot.png

# %%
root_folder = '/home/user/Desktop/Anagha/Shin_Colab/Linker_2/eps_0.5'

# Detect all folders starting with "N_"
n_folders = [f for f in os.listdir(root_folder) 
             if os.path.isdir(os.path.join(root_folder, f)) and re.match(r'^N_\d+$', f)]
# Sort numerically by the number after N_
n_folders.sort(key=lambda x: int(x.split('_')[1]))

# Output plot path
output_plot = os.path.join(root_folder, 'all_N_receptor_radial_density_log_plot.png')

# Initialize plot
plt.figure(figsize=(10,6))

# Loop through folders
for n in n_folders:
    folder_path = os.path.join(root_folder, n)
    csv_file = os.path.join(folder_path, 'receptor_radial_density_table.csv')
    
    if not os.path.isfile(csv_file):
        print(f"CSV not found in {folder_path}, skipping...")
        continue
    
    try:
        df = pd.read_csv(csv_file)
    except Exception as e:
        print(f"Error reading {csv_file}: {e}")
        continue
    
    # Check required columns
    required_cols = ['Radius (Å)', 'Cluster Density (atoms/Å³)']
    if not all(col in df.columns for col in required_cols):
        print(f"Required columns missing in {csv_file}, skipping...")
        continue
    
    # Extract data
    radius = df['Radius (Å)']
    cluster_density = df['Cluster Density (atoms/Å³)']

    plt.plot(radius, cluster_density, label=n, linewidth=2)

plt.xlabel('Radius (Å)', fontsize=12)
plt.ylabel('Density (atoms/Å³)', fontsize=12)
plt.yscale('log')  # Log scale for y-axis
plt.title('Radial Density Profile of Receptors for All N (log scale)', fontsize=14)
plt.legend(title='N Values')
plt.grid(True, alpha=0.3, which='both')
plt.tight_layout()

plt.savefig(output_plot, dpi=300, bbox_inches='tight')
plt.show()

print(f"\nCombined receptor plot (log scale) saved at: {output_plot}")
# Out:
# Combined receptor plot (log scale) saved at: /home/user/Desktop/Anagha/Shin_Colab/Linker_2/eps_0.5/all_N_receptor_radial_density_log_plot.png

# %%
root_folder = '/home/user/Desktop/Anagha/Shin_Colab/Linker_2/No_interaction'

# Detect all folders starting with "N_"
n_folders = [f for f in os.listdir(root_folder) 
             if os.path.isdir(os.path.join(root_folder, f)) and re.match(r'^N_\d+$', f)]
# Sort numerically by the number after N_
n_folders.sort(key=lambda x: int(x.split('_')[1]))

# Output plot path
output_plot = os.path.join(root_folder, 'all_N_receptor_radial_density_plot.png')

# Initialize plot
plt.figure(figsize=(10,6))

# Loop through folders
for n in n_folders:
    folder_path = os.path.join(root_folder, n)
    csv_file = os.path.join(folder_path, 'receptor_radial_density_table.csv')
    
    if not os.path.isfile(csv_file):
        print(f" CSV not found in {folder_path}, skipping...")
        continue
    
    try:
        df = pd.read_csv(csv_file)
    except Exception as e:
        print(f" Error reading {csv_file}: {e}")
        continue
    
    # Check required columns
    required_cols = ['Radius (Å)', 'Cluster Density (atoms/Å³)']
    if not all(col in df.columns for col in required_cols):
        print(f" Required columns missing in {csv_file}, skipping...")
        continue
    
    # Extract data
    radius = df['Radius (Å)']
    cluster_density = df['Cluster Density (atoms/Å³)']
    
    # Plot cluster density
    plt.plot(radius, cluster_density, label=n, linewidth=2)

# Plot formatting
plt.xlabel('Radius (Å)', fontsize=12)
plt.ylabel('Density (atoms/Å³)', fontsize=12)
plt.title('Radial Density Profile of Receptors for All N (No_interaction)', fontsize=14)
plt.legend(title='N Values')
plt.grid(True, alpha=0.3)
plt.tight_layout()

# Save and show plot
plt.savefig(output_plot, dpi=300, bbox_inches='tight')
plt.show()delete_atoms random count 75 no ligand NULL 32

print(f"\n Combined receptor plot saved at: {output_plot}")
# Out:
#  Combined receptor plot saved at: /home/user/Desktop/Anagha/Shin_Colab/Linker_2/No_interaction/all_N_receptor_radial_density_plot.png

# %%
root_folder = '/home/user/Desktop/Anagha/Shin_Colab/Linker_2/No_interaction'

# Detect all folders starting with "N_"
n_folders = [f for f in os.listdir(root_folder) 
             if os.path.isdir(os.path.join(root_folder, f)) and re.match(r'^N_\d+$', f)]
# Sort numerically by the number after N_
n_folders.sort(key=lambda x: int(x.split('_')[1]))

# Output plot path
output_plot = os.path.join(root_folder, 'all_N_polymer_radial_density_plot.png')

# Initialize plot
plt.figure(figsize=(10,6))

# Loop through folders
for n in n_folders:
    folder_path = os.path.join(root_folder, n)
    csv_file = os.path.join(folder_path, 'polymer_radial_density_table.csv')
    
    if not os.path.isfile(csv_file):
        print(f"CSV not found in {folder_path}, skipping...")
        continue
    
    try:
        df = pd.read_csv(csv_file)
    except Exception as e:
        print(f"Error reading {csv_file}: {e}")
        continue
    
    # Check required columns
    required_cols = ['Radius(Å)', 'ClusterDensity(atoms/Å³)']
    if not all(col in df.columns for col in required_cols):
        print(f"Required columns missing in {csv_file}, skipping...")
        continue
    
    # Extract data
    radius = df['Radius(Å)']
    cluster_density = df['ClusterDensity(atoms/Å³)']
    
    # Plot cluster density
    plt.plot(radius, cluster_density, label=n, linewidth=2)

# Plot formatting
plt.xlabel('Radius (Å)', fontsize=12)
plt.ylabel('Density (atoms/Å³)', fontsize=12)
plt.title('Radial Density Profile of Polymers for All N (No_interaction)', fontsize=14)
plt.legend(title='N Values')
plt.grid(True, alpha=0.3)
plt.tight_layout()

# Save and show plot
plt.savefig(output_plot, dpi=300, bbox_inches='tight')
plt.show()

print(f"\n Combined polymer plot saved at: {output_plot}")
# Out:
#  Combined polymer plot saved at: /home/user/Desktop/Anagha/Shin_Colab/Linker_2/No_interaction/all_N_polymer_radial_density_plot.png

# %%
root_folder = '/home/user/Desktop/Anagha/Shin_Colab/Linker_2/eps_0.5'

# Get all subfolders like N_1, N_20, N_50 ...
n_folders = [f for f in os.listdir(root_folder)
             if os.path.isdir(os.path.join(root_folder, f)) and re.match(r'^N_\d+$', f)]
n_folders.sort(key=lambda x: int(x.split('_')[1]))  # Sort by numeric N value

n_values = []
avg_fractions = []
std_fractions = []  # standard deviation for error bars

for n in n_folders:
    folder_path = os.path.join(root_folder, n)
    csv_file = os.path.join(folder_path, 'receptor_radial_density.csv')

    if not os.path.isfile(csv_file):
        print(f"Missing file: {csv_file}")
        continue

    try:
        df = pd.read_csv(csv_file)
    except Exception as e:
        print(f"Error reading {csv_file}: {e}")
        continue

    if 'Fraction' not in df.columns:
        print(f"No 'Fraction' column found in {csv_file}")
        continue

    # Compute mean and std of receptor fraction
    avg_fraction = df['Fraction'].mean()
    std_fraction = df['Fraction'].std()
    n_value = int(n.split('_')[1])

    n_values.append(n_value)
    avg_fractions.append(avg_fraction)
    std_fractions.append(std_fraction)

# --- Plot Fraction vs N with error bars ---
plt.figure(figsize=(8,5))
plt.errorbar(n_values, avg_fractions, yerr=std_fractions, fmt='o-', color='darkblue',
             ecolor='black', capsize=5, linewidth=2, label='Receptor Fraction')

plt.xlabel('N (Receptor Count)', fontsize=12)
plt.ylabel('Average Fraction of Receptors in Cluster', fontsize=12)
plt.title('Receptor Fraction in Cluster vs N (eps_0.5)', fontsize=14)
plt.grid(True, alpha=0.3)
plt.legend()
plt.tight_layout()

# Save the plot
output_plot = os.path.join(root_folder, 'receptor_fraction_vs_N_errorbars.png')
plt.savefig(output_plot, dpi=300, bbox_inches='tight')
plt.show()

print(f"\n Receptor fraction vs N (with error bars) saved to:\n{output_plot}")
# Out:
#  Receptor fraction vs N (with error bars) saved to:
# /home/user/Desktop/Anagha/Shin_Colab/Linker_2/eps_0.5/receptor_fraction_vs_N_errorbars.png

# %%
root_folder = '/home/user/Desktop/Anagha/Shin_Colab/Linker_2/No_interaction'

# Get all subfolders like N_1, N_20, N_50 ...
n_folders = [f for f in os.listdir(root_folder)
             if os.path.isdir(os.path.join(root_folder, f)) and re.match(r'^N_\d+$', f)]
n_folders.sort(key=lambda x: int(x.split('_')[1]))  # Sort by numeric N value

n_values = []
avg_fractions = []
std_fractions = []  # standard deviation for error bars

for n in n_folders:
    folder_path = os.path.join(root_folder, n)
    csv_file = os.path.join(folder_path, 'receptor_radial_density.csv')

    if not os.path.isfile(csv_file):
        print(f"Missing file: {csv_file}")
        continue

    try:
        df = pd.read_csv(csv_file)
    except Exception as e:
        print(f"Error reading {csv_file}: {e}")
        continue

    if 'Fraction' not in df.columns:
        print(f"No 'Fraction' column found in {csv_file}")
        continue

    # Compute mean and std of receptor fraction
    avg_fraction = df['Fraction'].mean()
    std_fraction = df['Fraction'].std()
    n_value = int(n.split('_')[1])

    n_values.append(n_value)
    avg_fractions.append(avg_fraction)
    std_fractions.append(std_fraction)

# --- Plot Fraction vs N with error bars ---
plt.figure(figsize=(8,5))
plt.errorbar(n_values, avg_fractions, yerr=std_fractions, fmt='o-', color='darkblue',
             ecolor='black', capsize=5, linewidth=2, label='Receptor Fraction')

plt.xlabel('N (Receptor Count)', fontsize=12)
plt.ylabel('Average Fraction of Receptors in Cluster', fontsize=12)
plt.title('Receptor Fraction in Cluster vs N (No_interaction)', fontsize=14)
plt.grid(True, alpha=0.3)
plt.legend()
plt.tight_layout()

# Save the plot
output_plot = os.path.join(root_folder, 'receptor_fraction_vs_N_errorbars.png')
plt.savefig(output_plot, dpi=300, bbox_inches='tight')
plt.show()

print(f"\n Receptor fraction vs N (with error bars) saved to:\n{output_plot}")
# Out:
#  Receptor fraction vs N (with error bars) saved to:
# /home/user/Desktop/Anagha/Shin_Colab/Linker_2/No_interaction/receptor_fraction_vs_N_errorbars.png

# %%
root_folders = {
    'No Interaction': '/home/user/Desktop/Anagha/Shin_Colab/Linker_2/No_interaction',
    'ε = 0.5': '/home/user/Desktop/Anagha/Shin_Colab/Linker_2/eps_0.5'
}

plt.figure(figsize=(8, 5))

# --- Loop over each root and plot ---
for label, root_folder in root_folders.items():
    # Get all subfolders like N_1, N_20, N_50 ...
    n_folders = [
        f for f in os.listdir(root_folder)
        if os.path.isdir(os.path.join(root_folder, f)) and re.match(r'^N_\d+$', f)
    ]
    n_folders.sort(key=lambda x: int(x.split('_')[1]))  # Sort numerically by N

    n_values = []
    avg_fractions = []
    std_fractions = []    # standard deviation for error bars

    for n in n_folders:
        if n == "N_1":  
            continue
        folder_path = os.path.join(root_folder, n)
        csv_file = os.path.join(folder_path, 'receptor_radial_density.csv')

        if not os.path.isfile(csv_file):
            print(f"Missing file: {csv_file}")
            continue

        try:
            df = pd.read_csv(csv_file)
        except Exception as e:
            print(f"Error reading {csv_file}: {e}")
            continue

        if 'Fraction' not in df.columns:
            print(f"No 'Fraction' column found in {csv_file}")
            continue

        # Mean and standard deviation
        avg_fraction = df['Fraction'].mean()
        std_fraction = df['Fraction'].std()
        n_value = int(n.split('_')[1])

        n_values.append(n_value)
        avg_fractions.append(avg_fraction)
        std_fractions.append(std_fraction)

    # Plot with error bars
    plt.errorbar(
        n_values, avg_fractions, yerr=std_fractions,
        fmt='o-', capsize=5, linewidth=2, label=label
    )

plt.xlabel('N (Receptor Count)', fontsize=12)
plt.ylabel('Average Fraction of Receptors in Cluster', fontsize=12)
plt.title('Receptor Fraction in Cluster vs N', fontsize=14)
plt.grid(True, alpha=0.3)
plt.legend()
plt.tight_layout()

output_plot = '/home/user/Desktop/Anagha/Shin_Colab/Linker_2/receptor_fraction_vs_N_combined.png'
plt.savefig(output_plot, dpi=300, bbox_inches='tight')
plt.show()

print(f"\n Combined receptor fraction vs N plot saved to:\n{output_plot}")
# Out:
#  Combined receptor fraction vs N plot saved to:
# /home/user/Desktop/Anagha/Shin_Colab/Linker_2/receptor_fraction_vs_N_combined.png

# %%
root_folder = '/home/user/Desktop/Anagha/Shin_Colab/Linker_2/No_interaction'

# Identify subfolders named N_*
n_folders = [f for f in os.listdir(root_folder)
             if os.path.isdir(os.path.join(root_folder, f)) and re.match(r'^N_\d+$', f)]
n_folders.sort(key=lambda x: int(x.split('_')[1]))  # Sort numerically by N value

n_values = []
avg_fractions = []
std_fractions = []  # standard deviation for error bars

for n in n_folders:
    folder_path = os.path.join(root_folder, n)
    csv_file = os.path.join(folder_path, 'polymer_cluster_analysis.csv')https://www.pnas.org/doi/epdf/10.1073/pnas.2017184118

    if not os.path.isfile(csv_file):
        print(f"Missing file: {csv_file}")
        continue

    try:
        df = pd.read_csv(csv_file)
    except Exception as e:
        print(f"Error reading {csv_file}: {e}")
        continue

    if 'Fraction' not in df.columns:
        print(f"No 'Fraction' column found in {csv_file}")
        continue

    # Compute mean and standard deviation of fraction for this N
    avg_fraction = df['Fraction'].mean()
    std_fraction = df['Fraction'].std()
    n_value = int(n.split('_')[1])

    n_values.append(n_value)
    avg_fractions.append(avg_fraction)
    std_fractions.append(std_fraction)

# --- Plot Fraction vs N with error bars ---
plt.figure(figsize=(8, 5))
plt.errorbar(n_values, avg_fractions, yerr=std_fractions, fmt='o-', color='crimson',
             ecolor='black', capsize=5, linewidth=2, label='Polymer Fraction')

plt.xlabel('N (Receptor Count)', fontsize=12)
plt.ylabel('Average Fraction of Polymers in Cluster', fontsize=12)
plt.title('Polymer Fraction in Cluster vs N (No_interaction)', fontsize=14)
plt.grid(True, alpha=0.3)
plt.legend()
plt.tight_layout()

# Save the plot
output_plot = os.path.join(root_folder, 'fraction_vs_N_polymer_errorbars.png')
plt.savefig(output_plot, dpi=300, bbox_inches='tight')
plt.show()

print(f"\n Polymer fraction vs N (with error bars) saved to:\n{output_plot}")
# Out:
#  Polymer fraction vs N (with error bars) saved to:
# /home/user/Desktop/Anagha/Shin_Colab/Linker_2/No_interaction/fraction_vs_N_polymer_errorbars.png

# %%
root_folder = '/home/user/Desktop/Anagha/Shin_Colab/Linker_2/eps_0.5'

# Identify subfolders named N_*
n_folders = [f for f in os.listdir(root_folder)
             if os.path.isdir(os.path.join(root_folder, f)) and re.match(r'^N_\d+$', f)]
n_folders.sort(key=lambda x: int(x.split('_')[1]))  # Sort numerically by N value

n_values = []
avg_fractions = []
std_fractions = []  # standard deviation for error bars

for n in n_folders:
    folder_path = os.path.join(root_folder, n)
    csv_file = os.path.join(folder_path, 'polymer_cluster_analysis.csv')

    if not os.path.isfile(csv_file):
        print(f"Missing file: {csv_file}")
        continue

    try:
        df = pd.read_csv(csv_file)
    except Exception as e:
        print(f"Error reading {csv_file}: {e}")
        continue

    if 'Fraction' not in df.columns:
        print(f"No 'Fraction' column found in {csv_file}")
        continue

    # Compute mean and standard deviation of fraction for this N
    avg_fraction = df['Fraction'].mean()
    std_fraction = df['Fraction'].std()
    n_value = int(n.split('_')[1])

    n_values.append(n_value)
    avg_fractions.append(avg_fraction)
    std_fractions.append(std_fraction)

# --- Plot Fraction vs N with error bars ---
plt.figure(figsize=(8, 5))
plt.errorbar(n_values, avg_fractions, yerr=std_fractions, fmt='o-', color='crimson',
             ecolor='black', capsize=5, linewidth=2, label='Polymer Fraction')

plt.xlabel('N (Receptor Count)', fontsize=12)
plt.ylabel('Average Fraction of Polymers in Cluster', fontsize=12)
plt.title('Polymer Fraction in Cluster vs N (eps_0.5)', fontsize=14)
plt.grid(True, alpha=0.3)
plt.legend()
plt.tight_layout()

# Save the plot
output_plot = os.path.join(root_folder, 'fraction_vs_N_polymer_errorbars.png')
plt.savefig(output_plot, dpi=300, bbox_inches='tight')
plt.show()

print(f"\n Polymer fraction vs N (with error bars) saved to:\n{output_plot}")
# Out:
#  Polymer fraction vs N (with error bars) saved to:
# /home/user/Desktop/Anagha/Shin_Colab/Linker_2/eps_0.5/fraction_vs_N_polymer_errorbars.png

# %%
root_folders = {
    'No Interaction': '/home/user/Desktop/Anagha/Shin_Colab/Linker_2/No_interaction',
    'ε = 0.5': '/home/user/Desktop/Anagha/Shin_Colab/Linker_2/eps_0.5'
}

plt.figure(figsize=(8, 5))

# --- Loop over each root and plot ---
for label, root_folder in root_folders.items():
    # Identify subfolders like N_1, N_20, etc.
    n_folders = [
        f for f in os.listdir(root_folder)
        if os.path.isdir(os.path.join(root_folder, f)) and re.match(r'^N_\d+$', f)
    ]
    n_folders.sort(key=lambda x: int(x.split('_')[1]))  # Sort numerically

    n_values = []
    avg_fractions = []
    std_fractions = []

    for n in n_folders:
        if n == "N_1":  # Skip N_1
            continue

        folder_path = os.path.join(root_folder, n)
        csv_file = os.path.join(folder_path, 'polymer_cluster_analysis.csv')

        if not os.path.isfile(csv_file):
            print(f"Missing file: {csv_file}")
            continue

        try:
            df = pd.read_csv(csv_file)
        except Exception as e:
            print(f"Error reading {csv_file}: {e}")
            continue

        if 'Fraction' not in df.columns:
            print(f"No 'Fraction' column found in {csv_file}")
            continue

        # Compute mean and std for this N
        avg_fraction = df['Fraction'].mean()
        std_fraction = df['Fraction'].std()
        n_value = int(n.split('_')[1])

        n_values.append(n_value)
        avg_fractions.append(avg_fraction)
        std_fractions.append(std_fraction)

    # Plot each dataset with error bars
    plt.errorbar(
        n_values, avg_fractions, yerr=std_fractions,
        fmt='o-', capsize=5, linewidth=2, label=label
    )

plt.xlabel('N (Receptor Count)', fontsize=12)
plt.ylabel('Average Fraction of Polymers in Cluster', fontsize=12)
plt.title('Polymer Fraction in Cluster vs N', fontsize=14)
plt.grid(True, alpha=0.3)
plt.legend()
plt.tight_layout()

output_plot = '/home/user/Desktop/Anagha/Shin_Colab/Linker_2/polymer_fraction_vs_N_combined.png'
plt.savefig(output_plot, dpi=300, bbox_inches='tight')
plt.show()

print(f"\nCombined polymer fraction vs N plot saved to:\n{output_plot}")
# Out:
# Combined polymer fraction vs N plot saved to:
# /home/user/Desktop/Anagha/Shin_Colab/Linker_2/polymer_fraction_vs_N_combined.png

# %%
polymer_type = 1        
bin_width = 1.0          
max_radius = 30 * math.sqrt(3)
output_csv = '/home/user/Desktop/Anagha/Shin_Colab/Linker_2/eps_0.5/N_100/polymer_radial_cumulative_counts_per_frame.csv'


bins = np.arange(0.0, max_radius + bin_width, bin_width)
bin_centers = 0.5 * (bins[:-1] + bins[1:])   # optionally use midpoints
radii_to_count = bins[1:]  # we will count cumulative up to each bin edge (exclude 0)
print(f"Number of radial bins: {len(radii_to_count)}  max_radius={max_radius:.3f} Å")
# Out:
# Number of radial bins: 52  max_radius=51.962 Å

# %%
bins = np.arange(0.0, max_radius + bin_width, bin_width)   # edges
bin_centers = 0.5 * (bins[:-1] + bins[1:])
shell_volumes = (4.0/3.0) * np.pi * (bins[1:]**3 - bins[:-1]**3)  # volume of each spherical shell

# --- load universe and residues (assume residue = chain) ---
u = mda.Universe(lammps_data, trajectory_file, format='LAMMPSDUMP')
poly_atoms = u.select_atoms(f"type {polymer_type}")
residues = poly_atoms.residues
n_chains = len(residues)
print(f"Found {n_chains} polymer residues/chains (assuming residues represent chains).")
n_bins = len(bin_centers)

# --- helper: minimum image convention for differences ---
def mic(vecs, box):
    box = np.asarray(box)
    return vecs - box * np.round(vecs / box)

# --- accumulate per-shell counts across frames ---
acc_counts = np.zeros(n_bins, dtype=float)
n_frames = 0

for ts in u.trajectory:   # you can slice e.g. u.trajectory[0:400] if desired
    # wrap polymer fragments so COMs are consistent across PBC
    poly_atoms.wrap(compound='fragments')

    # center of geometry of entire system
    cog = u.atoms.center_of_geometry()
    box = ts.dimensions[:3]

    # compute chain COMs (res.atoms.center_of_mass())
    chain_coms = np.array([res.atoms.center_of_mass() for res in residues])  # shape (n_chains, 3)

    # distance vectors from cog -> chain coms, apply MIC
    diffs = chain_coms - cog
    diffs = mic(diffs, box)
    dists = np.linalg.norm(diffs, axis=1)

    # histogram into shells (counts per shell, NOT cumulative)
    hist, _ = np.histogram(dists, bins=bins)
    acc_counts += hist
    n_frames += 1

    # optional progress
    if (ts.frame % 100) == 0:
        print(f"Processed frame {ts.frame} (total frames so far: {n_frames})")

if n_frames == 0:
    raise RuntimeError("No frames processed. Check your trajectory slice or file paths.")

# --- compute averages ---
avg_counts = acc_counts / n_frames           # average number of chains per shell
avg_density = avg_counts / shell_volumes     # average chains per Å^3 in each shell

# --- save to CSV ---
df_out = pd.DataFrame({
    "Radius(Å)": bin_centers,
    "AvgPolymersInShell": avg_counts,
    "AvgPolymerDensity(chains_per_A3)": avg_density
})
df_out.to_csv(output_table_csv, index=False)
print(f"Saved averaged radial shell counts to {output_table_csv}  (frames averaged = {n_frames})")
# Out:
# /home/user/anaconda3/lib/python3.12/site-packages/MDAnalysis/coordinates/LAMMPS.py:751: UserWarning: Reader has no dt information, set to 1.0 ps
#   ts.data["time"] = step_num * ts.dt
# Found 650 polymer residues/chains (assuming residues represent chains).
# Processed frame 0 (total frames so far: 1)
# Processed frame 100 (total frames so far: 101)
# Processed frame 200 (total frames so far: 201)
# Processed frame 300 (total frames so far: 301)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 60
#      54 # --- save to CSV ---
#      55 df_out = pd.DataFrame({
#      56     "Radius(Å)": bin_centers,
#      57     "AvgPolymersInShell": avg_counts,
#      58     "AvgPolymerDensity(chains_per_A3)": avg_density
#      59 })
# ---> 60 df_out.to_csv(output_table_csv, index=False)
#      61 print(f"Saved averaged radial shell counts to {output_table_csv}  (frames averaged = {n_frames})")
#
# NameError: name 'output_table_csv' is not defined
