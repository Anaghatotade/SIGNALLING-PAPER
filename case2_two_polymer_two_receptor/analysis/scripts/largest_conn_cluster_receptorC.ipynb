# %%
import MDAnalysis as mda
import numpy as np
import re
import matplotlib.pyplot as plt
import pandas as pd
from MDAnalysis.lib.nsgrid import FastNS
from MDAnalysis.lib import mdamath 
from collections import defaultdict
from scipy.spatial import cKDTree
import math
import os
import matplotlib.pyplot as plt

lammps_data = 'lammps.data'
trajectory_file = 'traj.lammpstrj'
u = mda.Universe(lammps_data, trajectory_file, format='LAMMPSDUMP')
# Out:
# /home/user/anaconda3/lib/python3.12/site-packages/MDAnalysis/coordinates/LAMMPS.py:749: UserWarning: Reader has no dt information, set to 1.0 ps
#   ts.data["time"] = step_num * ts.dt

# %%
total_chains = 600                                                                
polymer_typeA = 1                                       
polymer_typeB = 2 
receptor_typeC = 3                                       
receptor_typeD = 4

num_bins = 50
max_distance = 50                                                          
bins = np.linspace(0, max_distance, num_bins + 1)
bin_centers = 0.5 * (bins[:-1] + bins[1:])

z_slab = 115.0                                                              
buffer = 0.0   
                        
x_min, x_max = -40, 40
y_min, y_max = -40, 40
z_min, z_max = 32.2, 34.8

# %%
def any_common_elements(list1, list2):
    set1 = set(list1)
    for element in set1:
        if element in list2:
            return True
    return False

def partner_array(resid_interest, cutoff, universe):
    array_partner = [resid_interest]
    atom_list = universe.select_atoms(f"around {cutoff:.2f} (resid {resid_interest})")
    for atom in atom_list:
        array_partner.append(atom.resid)
    return list(set(array_partner))

def max_clu(u, total_chains):
    partners_list = [partner_array(ele, 3.0, u) for ele in range(1, total_chains + 1)]
    max_length, max_list = 0, []
    for lst in partners_list:
        if len(lst) > max_length:
            max_length = len(lst)
            max_list = lst
    chain_in_cluster = max_list
    for chains in range(total_chains):
        if any_common_elements(chain_in_cluster, partners_list[chains]):
            chain_in_cluster += partners_list[chains]
            chain_in_cluster = list(set(chain_in_cluster))
    return chain_in_cluster

def is_chain_inside_box(chain, box, buffer=0.):
    for atom in chain.atoms:
        x, y, z = atom.position
        if not (buffer < x < box[0] - buffer and buffer < y < box[1] - buffer and buffer < z < box[2] - buffer):
            return False
    return True

# %%
output_frame_csv = 'receptorC_radial_density.csv'
output_density_csv = 'receptorC_radial_density_table.csv'
output_plot = 'receptorC_radial_density.png'

receptor_typeC = 3
cutoff = 2.5
bin_width = 1.0
max_radius = 40.0 * math.sqrt(2)
slab_thickness = 2.6

u = mda.Universe(lammps_data, trajectory_file, format='LAMMPSDUMP')

class UnionFind:
    def __init__(self, n):
        self.parent = list(range(n))
        self.rank = [0] * n
    def find(self, x):
        while self.parent[x] != x:
            self.parent[x] = self.parent[self.parent[x]]
            x = self.parent[x]
        return x
    def union(self, a, b):
        ra, rb = self.find(a), self.find(b)
        if ra == rb:
            return
        if self.rank[ra] < self.rank[rb]:
            self.parent[ra] = rb
        else:
            self.parent[rb] = ra
            if self.rank[ra] == self.rank[rb]:
                self.rank[ra] += 1

def get_cell_index(pos, cell_size, box):
    return tuple((pos // cell_size).astype(int))

bins = np.arange(0, max_radius + bin_width, bin_width)
bin_centers = 0.5 * (bins[:-1] + bins[1:])
shell_volumes = np.pi * slab_thickness * (bins[1:]**2 - bins[:-1]**2)

radial_density_cluster = np.zeros(len(shell_volumes))
radial_density_all = np.zeros(len(shell_volumes))
valid_frames = 0
frame_results = []

for ts in u.trajectory:
    Lz = ts.dimensions[2]
    receptors = u.select_atoms(f"type {receptor_typeC} and prop z>{Lz - slab_thickness}")
    total_receptors = len(receptors)
    if total_receptors == 0:
        continue

    receptors.wrap(compound='fragments')
    positions = receptors.positions
    box = ts.dimensions[:3]
    cell_size = cutoff
    cell_dict = defaultdict(list)
    for i, pos in enumerate(positions):
        cell = get_cell_index(pos, cell_size, box)
        cell_dict[cell].append(i)

    neighbor_offsets = [(dx, dy, dz) for dx in [-1, 0, 1] for dy in [-1, 0, 1] for dz in [-1, 0, 1]]
    pairs = []
    for cell, atom_ids in cell_dict.items():
        for dx, dy, dz in neighbor_offsets:
            neighbor_cell = (
                (cell[0] + dx) % int(box[0] / cell_size),
                (cell[1] + dy) % int(box[1] / cell_size),
                (cell[2] + dz) % int(box[2] / cell_size)
            )
            for i in atom_ids:
                for j in cell_dict.get(neighbor_cell, []):
                    if j <= i:
                        continue
                    diff = positions[i] - positions[j]
                    diff -= box * np.round(diff / box)
                    if np.dot(diff, diff) <= cutoff**2:
                        pairs.append((i, j))

    uf = UnionFind(total_receptors)
    for i, j in pairs:
        uf.union(i, j)

    groups = defaultdict(list)
    for i in range(total_receptors):
        groups[uf.find(i)].append(i)

    largest_cluster = max(groups.values(), key=len)
    fraction = len(largest_cluster) / total_receptors
    print(f"Frame {ts.frame}: largest receptor cluster = {len(largest_cluster)} atoms, fraction = {fraction:.3f}")

    frame_results.append([ts.frame, total_receptors, len(largest_cluster), fraction])

    cluster_positions = positions[largest_cluster]
    ref_com_cluster = cluster_positions.mean(axis=0)
    distances_cluster = np.linalg.norm(cluster_positions[:, :2] - ref_com_cluster[:2], axis=1)
    hist_cluster, _ = np.histogram(distances_cluster, bins=bins)
    radial_density_cluster += hist_cluster

    ref_com_all = receptors.center_of_mass()
    distances_all = np.linalg.norm(positions[:, :2] - ref_com_all[:2], axis=1)
    hist_all, _ = np.histogram(distances_all, bins=bins)
    radial_density_all += hist_all

    valid_frames += 1

df_frame = pd.DataFrame(frame_results, columns=["Frame", "TotalReceptors", "LargestClusterSize", "Fraction"])
df_frame.to_csv(output_frame_csv, index=False)

radial_density_cluster /= (valid_frames * shell_volumes)
radial_density_all /= (valid_frames * shell_volumes)

density_table = pd.DataFrame({
    "Radius (Å)": bin_centers,
    "Cluster Density (atoms/Å³)": radial_density_cluster,
    "All Receptors Density (atoms/Å³)": radial_density_all
})
density_table.to_csv(output_density_csv, index=False)

plt.plot(bin_centers, radial_density_cluster, label="Largest Receptor Cluster", color='g')
plt.plot(bin_centers, radial_density_all, label="All Receptors", color='r', linestyle='--')
plt.xlabel("Radius (Å)")
plt.ylabel("Density (atoms/Å³)")
plt.legend()
plt.title("Radial Density Profile - Receptors (Top Slab)")
plt.savefig(output_plot, dpi=300, bbox_inches='tight')
plt.show()
# Out:
# Frame 0: largest receptor cluster = 22 atoms, fraction = 0.108
# Frame 1: largest receptor cluster = 34 atoms, fraction = 0.167
# Frame 2: largest receptor cluster = 92 atoms, fraction = 0.451
# Frame 3: largest receptor cluster = 113 atoms, fraction = 0.554
# Frame 4: largest receptor cluster = 126 atoms, fraction = 0.618
# Frame 5: largest receptor cluster = 135 atoms, fraction = 0.662
# Frame 6: largest receptor cluster = 137 atoms, fraction = 0.672
# Frame 7: largest receptor cluster = 143 atoms, fraction = 0.701
# Frame 8: largest receptor cluster = 155 atoms, fraction = 0.760
# Frame 9: largest receptor cluster = 152 atoms, fraction = 0.745
# Frame 10: largest receptor cluster = 163 atoms, fraction = 0.799
# Frame 11: largest receptor cluster = 169 atoms, fraction = 0.828
# Frame 12: largest receptor cluster = 166 atoms, fraction = 0.814
# Frame 13: largest receptor cluster = 175 atoms, fraction = 0.858
# Frame 14: largest receptor cluster = 176 atoms, fraction = 0.863
# Frame 15: largest receptor cluster = 177 atoms, fraction = 0.868
# Frame 16: largest receptor cluster = 182 atoms, fraction = 0.892
# Frame 17: largest receptor cluster = 183 atoms, fraction = 0.897
# Frame 18: largest receptor cluster = 187 atoms, fraction = 0.917
# Frame 19: largest receptor cluster = 187 atoms, fraction = 0.917
# Frame 20: largest receptor cluster = 185 atoms, fraction = 0.907
# Frame 21: largest receptor cluster = 190 atoms, fraction = 0.931
# Frame 22: largest receptor cluster = 192 atoms, fraction = 0.941
# Frame 23: largest receptor cluster = 188 atoms, fraction = 0.922
# Frame 24: largest receptor cluster = 186 atoms, fraction = 0.912
# Frame 25: largest receptor cluster = 182 atoms, fraction = 0.892
# Frame 26: largest receptor cluster = 182 atoms, fraction = 0.892
# Frame 27: largest receptor cluster = 188 atoms, fraction = 0.922
# Frame 28: largest receptor cluster = 190 atoms, fraction = 0.931
# Frame 29: largest receptor cluster = 189 atoms, fraction = 0.926
# Frame 30: largest receptor cluster = 185 atoms, fraction = 0.907
# Frame 31: largest receptor cluster = 189 atoms, fraction = 0.926
# Frame 32: largest receptor cluster = 191 atoms, fraction = 0.936
# Frame 33: largest receptor cluster = 189 atoms, fraction = 0.926
# Frame 34: largest receptor cluster = 191 atoms, fraction = 0.936
# Frame 35: largest receptor cluster = 189 atoms, fraction = 0.926
# Frame 36: largest receptor cluster = 192 atoms, fraction = 0.941
# Frame 37: largest receptor cluster = 192 atoms, fraction = 0.941
# Frame 38: largest receptor cluster = 191 atoms, fraction = 0.936
# Frame 39: largest receptor cluster = 193 atoms, fraction = 0.946
# Frame 40: largest receptor cluster = 192 atoms, fraction = 0.941
# Frame 41: largest receptor cluster = 193 atoms, fraction = 0.946
# Frame 42: largest receptor cluster = 191 atoms, fraction = 0.936
# Frame 43: largest receptor cluster = 187 atoms, fraction = 0.917
# Frame 44: largest receptor cluster = 191 atoms, fraction = 0.936
# Frame 45: largest receptor cluster = 189 atoms, fraction = 0.926
# Frame 46: largest receptor cluster = 189 atoms, fraction = 0.926
# Frame 47: largest receptor cluster = 189 atoms, fraction = 0.926
# Frame 48: largest receptor cluster = 186 atoms, fraction = 0.912
# Frame 49: largest receptor cluster = 188 atoms, fraction = 0.922
# Frame 50: largest receptor cluster = 187 atoms, fraction = 0.917
# Frame 51: largest receptor cluster = 188 atoms, fraction = 0.922
# Frame 52: largest receptor cluster = 187 atoms, fraction = 0.917
# Frame 53: largest receptor cluster = 189 atoms, fraction = 0.926
# Frame 54: largest receptor cluster = 189 atoms, fraction = 0.926
# Frame 55: largest receptor cluster = 192 atoms, fraction = 0.941
# Frame 56: largest receptor cluster = 190 atoms, fraction = 0.931
# Frame 57: largest receptor cluster = 191 atoms, fraction = 0.936
# Frame 58: largest receptor cluster = 192 atoms, fraction = 0.941
# Frame 59: largest receptor cluster = 189 atoms, fraction = 0.926
# Frame 60: largest receptor cluster = 186 atoms, fraction = 0.912
# Frame 61: largest receptor cluster = 188 atoms, fraction = 0.922
# Frame 62: largest receptor cluster = 180 atoms, fraction = 0.882
# Frame 63: largest receptor cluster = 181 atoms, fraction = 0.887
# Frame 64: largest receptor cluster = 183 atoms, fraction = 0.897
# Frame 65: largest receptor cluster = 181 atoms, fraction = 0.887
# Frame 66: largest receptor cluster = 190 atoms, fraction = 0.931
# Frame 67: largest receptor cluster = 192 atoms, fraction = 0.941
# Frame 68: largest receptor cluster = 192 atoms, fraction = 0.941
# Frame 69: largest receptor cluster = 190 atoms, fraction = 0.931
# Frame 70: largest receptor cluster = 189 atoms, fraction = 0.926
# Frame 71: largest receptor cluster = 186 atoms, fraction = 0.912
# Frame 72: largest receptor cluster = 188 atoms, fraction = 0.922
# Frame 73: largest receptor cluster = 189 atoms, fraction = 0.926
# Frame 74: largest receptor cluster = 192 atoms, fraction = 0.941
# Frame 75: largest receptor cluster = 190 atoms, fraction = 0.931
# Frame 76: largest receptor cluster = 191 atoms, fraction = 0.936
# Frame 77: largest receptor cluster = 192 atoms, fraction = 0.941
# Frame 78: largest receptor cluster = 196 atoms, fraction = 0.961
# Frame 79: largest receptor cluster = 193 atoms, fraction = 0.946
# Frame 80: largest receptor cluster = 194 atoms, fraction = 0.951
# Frame 81: largest receptor cluster = 195 atoms, fraction = 0.956
# Frame 82: largest receptor cluster = 196 atoms, fraction = 0.961
# Frame 83: largest receptor cluster = 196 atoms, fraction = 0.961
# Frame 84: largest receptor cluster = 188 atoms, fraction = 0.922
# Frame 85: largest receptor cluster = 191 atoms, fraction = 0.936
# Frame 86: largest receptor cluster = 189 atoms, fraction = 0.926
# Frame 87: largest receptor cluster = 185 atoms, fraction = 0.907
# Frame 88: largest receptor cluster = 190 atoms, fraction = 0.931
# Frame 89: largest receptor cluster = 193 atoms, fraction = 0.946
# Frame 90: largest receptor cluster = 192 atoms, fraction = 0.941
# Frame 91: largest receptor cluster = 190 atoms, fraction = 0.931
# Frame 92: largest receptor cluster = 187 atoms, fraction = 0.917
# Frame 93: largest receptor cluster = 188 atoms, fraction = 0.922
# Frame 94: largest receptor cluster = 187 atoms, fraction = 0.917
# Frame 95: largest receptor cluster = 187 atoms, fraction = 0.917
# Frame 96: largest receptor cluster = 183 atoms, fraction = 0.897
# Frame 97: largest receptor cluster = 189 atoms, fraction = 0.926
# Frame 98: largest receptor cluster = 189 atoms, fraction = 0.926
# Frame 99: largest receptor cluster = 185 atoms, fraction = 0.907
# Frame 100: largest receptor cluster = 187 atoms, fraction = 0.917
# Frame 101: largest receptor cluster = 188 atoms, fraction = 0.922
# Frame 102: largest receptor cluster = 187 atoms, fraction = 0.917
# Frame 103: largest receptor cluster = 183 atoms, fraction = 0.897
# Frame 104: largest receptor cluster = 184 atoms, fraction = 0.902
# Frame 105: largest receptor cluster = 183 atoms, fraction = 0.897
# Frame 106: largest receptor cluster = 186 atoms, fraction = 0.912
# Frame 107: largest receptor cluster = 183 atoms, fraction = 0.897
# Frame 108: largest receptor cluster = 184 atoms, fraction = 0.902
# Frame 109: largest receptor cluster = 186 atoms, fraction = 0.912
# Frame 110: largest receptor cluster = 191 atoms, fraction = 0.936
# Frame 111: largest receptor cluster = 195 atoms, fraction = 0.956
# Frame 112: largest receptor cluster = 195 atoms, fraction = 0.956
# Frame 113: largest receptor cluster = 194 atoms, fraction = 0.951
# Frame 114: largest receptor cluster = 192 atoms, fraction = 0.941
# Frame 115: largest receptor cluster = 189 atoms, fraction = 0.926
# Frame 116: largest receptor cluster = 191 atoms, fraction = 0.936
# Frame 117: largest receptor cluster = 193 atoms, fraction = 0.946
# Frame 118: largest receptor cluster = 189 atoms, fraction = 0.926
# Frame 119: largest receptor cluster = 191 atoms, fraction = 0.936
# Frame 120: largest receptor cluster = 190 atoms, fraction = 0.931
# Frame 121: largest receptor cluster = 190 atoms, fraction = 0.931
# Frame 122: largest receptor cluster = 186 atoms, fraction = 0.912
# Frame 123: largest receptor cluster = 188 atoms, fraction = 0.922
# Frame 124: largest receptor cluster = 185 atoms, fraction = 0.907
# Frame 125: largest receptor cluster = 186 atoms, fraction = 0.912
# Frame 126: largest receptor cluster = 190 atoms, fraction = 0.931
# Frame 127: largest receptor cluster = 191 atoms, fraction = 0.936
# Frame 128: largest receptor cluster = 188 atoms, fraction = 0.922
# Frame 129: largest receptor cluster = 187 atoms, fraction = 0.917
# Frame 130: largest receptor cluster = 188 atoms, fraction = 0.922
# Frame 131: largest receptor cluster = 188 atoms, fraction = 0.922
# Frame 132: largest receptor cluster = 189 atoms, fraction = 0.926
# Frame 133: largest receptor cluster = 190 atoms, fraction = 0.931
# Frame 134: largest receptor cluster = 190 atoms, fraction = 0.931
# Frame 135: largest receptor cluster = 191 atoms, fraction = 0.936
# Frame 136: largest receptor cluster = 192 atoms, fraction = 0.941
# Frame 137: largest receptor cluster = 188 atoms, fraction = 0.922
# Frame 138: largest receptor cluster = 191 atoms, fraction = 0.936
# Frame 139: largest receptor cluster = 190 atoms, fraction = 0.931
# Frame 140: largest receptor cluster = 192 atoms, fraction = 0.941
# Frame 141: largest receptor cluster = 191 atoms, fraction = 0.936
# Frame 142: largest receptor cluster = 195 atoms, fraction = 0.956
# Frame 143: largest receptor cluster = 192 atoms, fraction = 0.941
# Frame 144: largest receptor cluster = 188 atoms, fraction = 0.922
# Frame 145: largest receptor cluster = 184 atoms, fraction = 0.902
# Frame 146: largest receptor cluster = 184 atoms, fraction = 0.902
# Frame 147: largest receptor cluster = 186 atoms, fraction = 0.912
# Frame 148: largest receptor cluster = 190 atoms, fraction = 0.931
# Frame 149: largest receptor cluster = 191 atoms, fraction = 0.936
# Frame 150: largest receptor cluster = 192 atoms, fraction = 0.941
# Frame 151: largest receptor cluster = 188 atoms, fraction = 0.922
# Frame 152: largest receptor cluster = 188 atoms, fraction = 0.922
# Frame 153: largest receptor cluster = 189 atoms, fraction = 0.926
# Frame 154: largest receptor cluster = 191 atoms, fraction = 0.936
# Frame 155: largest receptor cluster = 189 atoms, fraction = 0.926
# Frame 156: largest receptor cluster = 188 atoms, fraction = 0.922
# Frame 157: largest receptor cluster = 189 atoms, fraction = 0.926
# Frame 158: largest receptor cluster = 190 atoms, fraction = 0.931
# Frame 159: largest receptor cluster = 189 atoms, fraction = 0.926
# Frame 160: largest receptor cluster = 191 atoms, fraction = 0.936
# Frame 161: largest receptor cluster = 192 atoms, fraction = 0.941
# Frame 162: largest receptor cluster = 193 atoms, fraction = 0.946
# Frame 163: largest receptor cluster = 192 atoms, fraction = 0.941
# Frame 164: largest receptor cluster = 193 atoms, fraction = 0.946
# Frame 165: largest receptor cluster = 192 atoms, fraction = 0.941
# Frame 166: largest receptor cluster = 193 atoms, fraction = 0.946
# Frame 167: largest receptor cluster = 192 atoms, fraction = 0.941
# Frame 168: largest receptor cluster = 195 atoms, fraction = 0.956
# Frame 169: largest receptor cluster = 188 atoms, fraction = 0.922
# Frame 170: largest receptor cluster = 193 atoms, fraction = 0.946
# Frame 171: largest receptor cluster = 196 atoms, fraction = 0.961
# Frame 172: largest receptor cluster = 195 atoms, fraction = 0.956
# Frame 173: largest receptor cluster = 190 atoms, fraction = 0.931
# Frame 174: largest receptor cluster = 192 atoms, fraction = 0.941
# Frame 175: largest receptor cluster = 195 atoms, fraction = 0.956
# Frame 176: largest receptor cluster = 192 atoms, fraction = 0.941
# Frame 177: largest receptor cluster = 193 atoms, fraction = 0.946
# Frame 178: largest receptor cluster = 192 atoms, fraction = 0.941
# Frame 179: largest receptor cluster = 189 atoms, fraction = 0.926
# Frame 180: largest receptor cluster = 189 atoms, fraction = 0.926
# Frame 181: largest receptor cluster = 190 atoms, fraction = 0.931
# Frame 182: largest receptor cluster = 189 atoms, fraction = 0.926
# Frame 183: largest receptor cluster = 194 atoms, fraction = 0.951
# Frame 184: largest receptor cluster = 194 atoms, fraction = 0.951
# Frame 185: largest receptor cluster = 193 atoms, fraction = 0.946
# Frame 186: largest receptor cluster = 188 atoms, fraction = 0.922
# Frame 187: largest receptor cluster = 185 atoms, fraction = 0.907
# Frame 188: largest receptor cluster = 185 atoms, fraction = 0.907
# Frame 189: largest receptor cluster = 184 atoms, fraction = 0.902
# Frame 190: largest receptor cluster = 182 atoms, fraction = 0.892
# Frame 191: largest receptor cluster = 181 atoms, fraction = 0.887
# Frame 192: largest receptor cluster = 183 atoms, fraction = 0.897
# Frame 193: largest receptor cluster = 184 atoms, fraction = 0.902
# Frame 194: largest receptor cluster = 182 atoms, fraction = 0.892
# Frame 195: largest receptor cluster = 183 atoms, fraction = 0.897
# Frame 196: largest receptor cluster = 187 atoms, fraction = 0.917
# Frame 197: largest receptor cluster = 184 atoms, fraction = 0.902
# Frame 198: largest receptor cluster = 185 atoms, fraction = 0.907
# Frame 199: largest receptor cluster = 188 atoms, fraction = 0.922
# Frame 200: largest receptor cluster = 189 atoms, fraction = 0.926
# Frame 201: largest receptor cluster = 189 atoms, fraction = 0.926
# Frame 202: largest receptor cluster = 187 atoms, fraction = 0.917
# Frame 203: largest receptor cluster = 188 atoms, fraction = 0.922
# Frame 204: largest receptor cluster = 186 atoms, fraction = 0.912
# Frame 205: largest receptor cluster = 186 atoms, fraction = 0.912
# Frame 206: largest receptor cluster = 186 atoms, fraction = 0.912
# Frame 207: largest receptor cluster = 190 atoms, fraction = 0.931
# Frame 208: largest receptor cluster = 192 atoms, fraction = 0.941
# Frame 209: largest receptor cluster = 191 atoms, fraction = 0.936
# Frame 210: largest receptor cluster = 192 atoms, fraction = 0.941
# Frame 211: largest receptor cluster = 189 atoms, fraction = 0.926
# Frame 212: largest receptor cluster = 190 atoms, fraction = 0.931
# Frame 213: largest receptor cluster = 187 atoms, fraction = 0.917
# Frame 214: largest receptor cluster = 183 atoms, fraction = 0.897
# Frame 215: largest receptor cluster = 190 atoms, fraction = 0.931
# Frame 216: largest receptor cluster = 192 atoms, fraction = 0.941
# Frame 217: largest receptor cluster = 195 atoms, fraction = 0.956
# Frame 218: largest receptor cluster = 196 atoms, fraction = 0.961
# Frame 219: largest receptor cluster = 198 atoms, fraction = 0.971
# Frame 220: largest receptor cluster = 197 atoms, fraction = 0.966
# Frame 221: largest receptor cluster = 195 atoms, fraction = 0.956
# Frame 222: largest receptor cluster = 192 atoms, fraction = 0.941
# Frame 223: largest receptor cluster = 192 atoms, fraction = 0.941
# Frame 224: largest receptor cluster = 191 atoms, fraction = 0.936
# Frame 225: largest receptor cluster = 189 atoms, fraction = 0.926
# Frame 226: largest receptor cluster = 182 atoms, fraction = 0.892
# Frame 227: largest receptor cluster = 185 atoms, fraction = 0.907
# Frame 228: largest receptor cluster = 187 atoms, fraction = 0.917
# Frame 229: largest receptor cluster = 182 atoms, fraction = 0.892
# Frame 230: largest receptor cluster = 187 atoms, fraction = 0.917
# Frame 231: largest receptor cluster = 187 atoms, fraction = 0.917
# Frame 232: largest receptor cluster = 189 atoms, fraction = 0.926
# Frame 233: largest receptor cluster = 186 atoms, fraction = 0.912
# Frame 234: largest receptor cluster = 186 atoms, fraction = 0.912
# Frame 235: largest receptor cluster = 185 atoms, fraction = 0.907
# Frame 236: largest receptor cluster = 190 atoms, fraction = 0.931
# Frame 237: largest receptor cluster = 188 atoms, fraction = 0.922
# Frame 238: largest receptor cluster = 190 atoms, fraction = 0.931
# Frame 239: largest receptor cluster = 190 atoms, fraction = 0.931
# Frame 240: largest receptor cluster = 191 atoms, fraction = 0.936
# Frame 241: largest receptor cluster = 191 atoms, fraction = 0.936
# Frame 242: largest receptor cluster = 189 atoms, fraction = 0.926
# Frame 243: largest receptor cluster = 194 atoms, fraction = 0.951
# Frame 244: largest receptor cluster = 193 atoms, fraction = 0.946
# Frame 245: largest receptor cluster = 194 atoms, fraction = 0.951
# Frame 246: largest receptor cluster = 197 atoms, fraction = 0.966
# Frame 247: largest receptor cluster = 196 atoms, fraction = 0.961
# Frame 248: largest receptor cluster = 198 atoms, fraction = 0.971
# Frame 249: largest receptor cluster = 195 atoms, fraction = 0.956
# Frame 250: largest receptor cluster = 196 atoms, fraction = 0.961
# Frame 251: largest receptor cluster = 193 atoms, fraction = 0.946
# Frame 252: largest receptor cluster = 191 atoms, fraction = 0.936
# Frame 253: largest receptor cluster = 193 atoms, fraction = 0.946
# Frame 254: largest receptor cluster = 193 atoms, fraction = 0.946
# Frame 255: largest receptor cluster = 192 atoms, fraction = 0.941
# Frame 256: largest receptor cluster = 192 atoms, fraction = 0.941
# Frame 257: largest receptor cluster = 194 atoms, fraction = 0.951
# Frame 258: largest receptor cluster = 196 atoms, fraction = 0.961
# Frame 259: largest receptor cluster = 189 atoms, fraction = 0.926
# Frame 260: largest receptor cluster = 187 atoms, fraction = 0.917
# Frame 261: largest receptor cluster = 187 atoms, fraction = 0.917
# Frame 262: largest receptor cluster = 191 atoms, fraction = 0.936
# Frame 263: largest receptor cluster = 195 atoms, fraction = 0.956
# Frame 264: largest receptor cluster = 189 atoms, fraction = 0.926
# Frame 265: largest receptor cluster = 189 atoms, fraction = 0.926
# Frame 266: largest receptor cluster = 191 atoms, fraction = 0.936
# Frame 267: largest receptor cluster = 191 atoms, fraction = 0.936
# Frame 268: largest receptor cluster = 190 atoms, fraction = 0.931
# Frame 269: largest receptor cluster = 189 atoms, fraction = 0.926
# Frame 270: largest receptor cluster = 185 atoms, fraction = 0.907
# Frame 271: largest receptor cluster = 184 atoms, fraction = 0.902
# Frame 272: largest receptor cluster = 185 atoms, fraction = 0.907
# Frame 273: largest receptor cluster = 189 atoms, fraction = 0.926
# Frame 274: largest receptor cluster = 188 atoms, fraction = 0.922
# Frame 275: largest receptor cluster = 188 atoms, fraction = 0.922
# Frame 276: largest receptor cluster = 184 atoms, fraction = 0.902
# Frame 277: largest receptor cluster = 186 atoms, fraction = 0.912
# Frame 278: largest receptor cluster = 187 atoms, fraction = 0.917
# Frame 279: largest receptor cluster = 185 atoms, fraction = 0.907
# Frame 280: largest receptor cluster = 192 atoms, fraction = 0.941
# Frame 281: largest receptor cluster = 193 atoms, fraction = 0.946
# Frame 282: largest receptor cluster = 190 atoms, fraction = 0.931
# Frame 283: largest receptor cluster = 190 atoms, fraction = 0.931
# Frame 284: largest receptor cluster = 194 atoms, fraction = 0.951
# Frame 285: largest receptor cluster = 191 atoms, fraction = 0.936
# Frame 286: largest receptor cluster = 190 atoms, fraction = 0.931
# Frame 287: largest receptor cluster = 195 atoms, fraction = 0.956
# Frame 288: largest receptor cluster = 196 atoms, fraction = 0.961
# Frame 289: largest receptor cluster = 195 atoms, fraction = 0.956
# Frame 290: largest receptor cluster = 195 atoms, fraction = 0.956
# Frame 291: largest receptor cluster = 195 atoms, fraction = 0.956
# Frame 292: largest receptor cluster = 198 atoms, fraction = 0.971
# Frame 293: largest receptor cluster = 199 atoms, fraction = 0.975
# Frame 294: largest receptor cluster = 198 atoms, fraction = 0.971
# Frame 295: largest receptor cluster = 194 atoms, fraction = 0.951
# Frame 296: largest receptor cluster = 195 atoms, fraction = 0.956
# Frame 297: largest receptor cluster = 194 atoms, fraction = 0.951
# Frame 298: largest receptor cluster = 197 atoms, fraction = 0.966
# Frame 299: largest receptor cluster = 194 atoms, fraction = 0.951
# Frame 300: largest receptor cluster = 191 atoms, fraction = 0.936
# Frame 301: largest receptor cluster = 193 atoms, fraction = 0.946
# Frame 302: largest receptor cluster = 194 atoms, fraction = 0.951
# Frame 303: largest receptor cluster = 191 atoms, fraction = 0.936
# Frame 304: largest receptor cluster = 193 atoms, fraction = 0.946
# Frame 305: largest receptor cluster = 189 atoms, fraction = 0.926
# Frame 306: largest receptor cluster = 189 atoms, fraction = 0.926
# Frame 307: largest receptor cluster = 189 atoms, fraction = 0.926
# Frame 308: largest receptor cluster = 193 atoms, fraction = 0.946
# Frame 309: largest receptor cluster = 191 atoms, fraction = 0.936
# Frame 310: largest receptor cluster = 191 atoms, fraction = 0.936
# Frame 311: largest receptor cluster = 192 atoms, fraction = 0.941
# Frame 312: largest receptor cluster = 191 atoms, fraction = 0.936
# Frame 313: largest receptor cluster = 193 atoms, fraction = 0.946
# Frame 314: largest receptor cluster = 199 atoms, fraction = 0.975
# Frame 315: largest receptor cluster = 196 atoms, fraction = 0.961
# Frame 316: largest receptor cluster = 195 atoms, fraction = 0.956
# Frame 317: largest receptor cluster = 195 atoms, fraction = 0.956
# Frame 318: largest receptor cluster = 196 atoms, fraction = 0.961
# Frame 319: largest receptor cluster = 195 atoms, fraction = 0.956
# Frame 320: largest receptor cluster = 192 atoms, fraction = 0.941
# Frame 321: largest receptor cluster = 191 atoms, fraction = 0.936
# Frame 322: largest receptor cluster = 191 atoms, fraction = 0.936
# Frame 323: largest receptor cluster = 189 atoms, fraction = 0.926
# Frame 324: largest receptor cluster = 188 atoms, fraction = 0.922
# Frame 325: largest receptor cluster = 187 atoms, fraction = 0.917
# Frame 326: largest receptor cluster = 187 atoms, fraction = 0.917
# Frame 327: largest receptor cluster = 191 atoms, fraction = 0.936
# Frame 328: largest receptor cluster = 190 atoms, fraction = 0.931
# Frame 329: largest receptor cluster = 186 atoms, fraction = 0.912
# Frame 330: largest receptor cluster = 189 atoms, fraction = 0.926
# Frame 331: largest receptor cluster = 188 atoms, fraction = 0.922
# Frame 332: largest receptor cluster = 184 atoms, fraction = 0.902
# Frame 333: largest receptor cluster = 187 atoms, fraction = 0.917
# Frame 334: largest receptor cluster = 187 atoms, fraction = 0.917
# Frame 335: largest receptor cluster = 182 atoms, fraction = 0.892
# Frame 336: largest receptor cluster = 180 atoms, fraction = 0.882
# Frame 337: largest receptor cluster = 183 atoms, fraction = 0.897
# Frame 338: largest receptor cluster = 186 atoms, fraction = 0.912
# Frame 339: largest receptor cluster = 185 atoms, fraction = 0.907
# Frame 340: largest receptor cluster = 188 atoms, fraction = 0.922
# Frame 341: largest receptor cluster = 186 atoms, fraction = 0.912
# Frame 342: largest receptor cluster = 186 atoms, fraction = 0.912
# Frame 343: largest receptor cluster = 187 atoms, fraction = 0.917
# Frame 344: largest receptor cluster = 188 atoms, fraction = 0.922
# Frame 345: largest receptor cluster = 186 atoms, fraction = 0.912
# Frame 346: largest receptor cluster = 190 atoms, fraction = 0.931
# Frame 347: largest receptor cluster = 190 atoms, fraction = 0.931
# Frame 348: largest receptor cluster = 191 atoms, fraction = 0.936
# Frame 349: largest receptor cluster = 189 atoms, fraction = 0.926
# Frame 350: largest receptor cluster = 190 atoms, fraction = 0.931
# Frame 351: largest receptor cluster = 191 atoms, fraction = 0.936
# Frame 352: largest receptor cluster = 188 atoms, fraction = 0.922
# Frame 353: largest receptor cluster = 189 atoms, fraction = 0.926
# Frame 354: largest receptor cluster = 190 atoms, fraction = 0.931
# Frame 355: largest receptor cluster = 189 atoms, fraction = 0.926
# Frame 356: largest receptor cluster = 188 atoms, fraction = 0.922
# Frame 357: largest receptor cluster = 190 atoms, fraction = 0.931
# Frame 358: largest receptor cluster = 190 atoms, fraction = 0.931
# Frame 359: largest receptor cluster = 190 atoms, fraction = 0.931
# Frame 360: largest receptor cluster = 193 atoms, fraction = 0.946
# Frame 361: largest receptor cluster = 189 atoms, fraction = 0.926
# Frame 362: largest receptor cluster = 191 atoms, fraction = 0.936
# Frame 363: largest receptor cluster = 188 atoms, fraction = 0.922
# Frame 364: largest receptor cluster = 189 atoms, fraction = 0.926
# Frame 365: largest receptor cluster = 188 atoms, fraction = 0.922
# Frame 366: largest receptor cluster = 191 atoms, fraction = 0.936
# Frame 367: largest receptor cluster = 189 atoms, fraction = 0.926
# Frame 368: largest receptor cluster = 190 atoms, fraction = 0.931
# Frame 369: largest receptor cluster = 194 atoms, fraction = 0.951
# Frame 370: largest receptor cluster = 191 atoms, fraction = 0.936
# Frame 371: largest receptor cluster = 184 atoms, fraction = 0.902
# Frame 372: largest receptor cluster = 185 atoms, fraction = 0.907
# Frame 373: largest receptor cluster = 186 atoms, fraction = 0.912
# Frame 374: largest receptor cluster = 186 atoms, fraction = 0.912
# Frame 375: largest receptor cluster = 187 atoms, fraction = 0.917
# Frame 376: largest receptor cluster = 188 atoms, fraction = 0.922
# Frame 377: largest receptor cluster = 186 atoms, fraction = 0.912
# Frame 378: largest receptor cluster = 185 atoms, fraction = 0.907
# Frame 379: largest receptor cluster = 186 atoms, fraction = 0.912
# Frame 380: largest receptor cluster = 188 atoms, fraction = 0.922
# Frame 381: largest receptor cluster = 186 atoms, fraction = 0.912
# Frame 382: largest receptor cluster = 187 atoms, fraction = 0.917
# Frame 383: largest receptor cluster = 187 atoms, fraction = 0.917
# Frame 384: largest receptor cluster = 189 atoms, fraction = 0.926
# Frame 385: largest receptor cluster = 191 atoms, fraction = 0.936
# Frame 386: largest receptor cluster = 193 atoms, fraction = 0.946
# Frame 387: largest receptor cluster = 187 atoms, fraction = 0.917
# Frame 388: largest receptor cluster = 190 atoms, fraction = 0.931
# Frame 389: largest receptor cluster = 192 atoms, fraction = 0.941
# Frame 390: largest receptor cluster = 190 atoms, fraction = 0.931
# Frame 391: largest receptor cluster = 187 atoms, fraction = 0.917
# Frame 392: largest receptor cluster = 189 atoms, fraction = 0.926
# Frame 393: largest receptor cluster = 189 atoms, fraction = 0.926
# Frame 394: largest receptor cluster = 188 atoms, fraction = 0.922
# Frame 395: largest receptor cluster = 188 atoms, fraction = 0.922
# Frame 396: largest receptor cluster = 188 atoms, fraction = 0.922
# Frame 397: largest receptor cluster = 193 atoms, fraction = 0.946
# Frame 398: largest receptor cluster = 193 atoms, fraction = 0.946
# Frame 399: largest receptor cluster = 187 atoms, fraction = 0.917

# %%
print(df_frame.columns.tolist())
